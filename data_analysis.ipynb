# %% [markdown]
# # Evaluate Classification

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Load the libaries.

# %%
from src.data_analysis import run_analysis
import pandas as pd

# %% [markdown]
# #### Load the Constants

# %%
PATH = 'data/Portuguese.csv'
MODEL = 'gpt-4' # Llama-2-13b # Llama-2-70b # gpt-3.5-turbo # gpt-4
TEMPERATURE = 0.0
N_REPETITIONS = 1
LANGUAGES = ['english', 'portuguese']

# %% [markdown]
# #### See the results

# %%
if N_REPETITIONS > 1:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}_{N_REPETITIONS}Repetitions.csv")
else:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}.csv")

df
# Out:
#       ID  year        test                theme subtheme  \
# 0      1  2022   Teórica I             Anatomia   cornea
# 1      2  2022   Teórica I             Anatomia   retina
# 2      3  2022   Teórica I             Anatomia   cornea
# 3      4  2022   Teórica I             Anatomia   cornea
# 4      5  2022   Teórica I             Anatomia   cornea
# ..   ...   ...         ...                  ...      ...
# 159  161  2022  Teórica II  Cristalino/Catarata      NaN
# 160  162  2022  Teórica II  Cristalino/Catarata      NaN
# 161  163  2022  Teórica II  Cristalino/Catarata      NaN
# 162  164  2022  Teórica II  Cristalino/Catarata      NaN
# 163  165  2022  Teórica II  Cristalino/Catarata      NaN
#
#                                             portuguese  \
# 0    Em qual região ocular células caliciformes são...
# 1    Assinale a alternativa que melhor correlaciona...
# 2    Ordene as três denominações celulares encontra...
# 3    Sobre a membrana de Descemet da córnea, é corr...
# 4    Sobre a camada lipídica do filme lacrimal, ass...
# ..                                                 ...
# 159  Após bloqueio retrobulbar para realização de c...
# 160  Sobre a biometria em olhos tamponados por óleo...
# 161  Assinale a alternativa que contém, respectivam...
# 162  Sobre a prevenção de endoftalmite em cirurgia ...
# 163  Após realizar as fraturas do núcleo com a técn...
#
#                                                english answer  \
# 0    In which ocular region are caliciform cells ph...      D
# 1    Mark the alternative that best correlates the ...      B
# 2    Order the three cell names found in the cornea...      A
# 3    Regarding Descemet's membrane of the cornea, i...      C
# 4    About the lipidic layer of the lacrimal film, ...      B
# ..                                                 ...    ...
# 159  After retrobulbar block for phacoemulsificatio...      C
# 160  Regarding biometrics in eyes covered with sili...      D
# 161  Check the alternative that contains, respectiv...      A
# 162  Regarding the prevention of endophthalmitis in...      B
# 163  After performing the core fractures with the d...      C
#
#     responses_english                                  reasoning_english  \
# 0                   A  Caliciform cells, also known as goblet cells, ...
# 1                   D  The inner nuclear layer of the retina contains...
# 2                   A  The corneal epithelium is composed of three ty...
# 3                   C  The most anterior portion of Descemet's membra...
# 4                   B  The lipidic layer of the lacrimal film contain...
# ..                ...                                                ...
# 159                 C  The symptoms described are consistent with an ...
# 160                 A  The axial length measured by ultrasound is fal...
# 161                 d  Atropine is a drug associated with the occurre...
# 162                 B  The main risk factors for endophthalmitis in c...
# 163                 C  Keeping the tip equidistant from the incision ...
#
#     responses_portuguese                               reasoning_portuguese
# 0                      A  As células caliciformes são encontradas na cór...
# 1                      D  As características descritas em III e IV corre...
# 2                      A  As células epiteliais da córnea são organizada...
# 3                      C  A porção mais anterior da membrana de Descemet...
# 4                      B  A camada lipídica do filme lacrimal é secretad...
# ..                   ...                                                ...
# 159                    B  The symptoms described are consistent with an ...
# 160                    D  A interferometria de coerência parcial é prefe...
# 161                    D  Tamsulosin is associated with intraoperative f...
# 162                    B  Os principais fatores de risco para endoftalmi...
# 163                    C  Manter a ponteira equidistante das paredes da ...
#
# [164 rows x 12 columns]

# %% [markdown]
# ### Data Analysis

# %%
TEMPERATURE = str(TEMPERATURE).replace('.', '_')

run_analysis(model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, languages=LANGUAGES)
# Out:
#      theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  anatomy             14                12     21                 66.666667
#
#    portuguese_ratio_percentage
# 0                    57.142857
#     theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  cornea              4                 5     10                      40.0
#
#    portuguese_ratio_percentage
# 0                         50.0
#         theme  match_english  match_portuguese  Total  \
# 0  embryology              1                 1      2
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                      50.0                         50.0
#       theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  genetics              2                 2      2                     100.0
#
#    portuguese_ratio_percentage
# 0                        100.0
#       theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  glaucoma              7                 7      9                 77.777778
#
#    portuguese_ratio_percentage
# 0                    77.777778
#       theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  oncology              1                 1      1                     100.0
#
#    portuguese_ratio_percentage
# 0                        100.0
#           theme  match_english  match_portuguese  Total  \
# 0  pharmacology              8                 8      9
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                 88.888889                    88.888889
#         theme  match_english  match_portuguese  Total  \
# 0  refraction             14                12     31
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                  45.16129                    38.709677
#     theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  retina              8                10     12                 66.666667
#
#    portuguese_ratio_percentage
# 0                    83.333333
#             theme  match_english  match_portuguese  Total  \
# 0  contact lenses              1                 1      3
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                 33.333333                    33.333333
#     theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  cornea              4                 5     10                      40.0
#
#    portuguese_ratio_percentage
# 0                         50.0
#          theme  match_english  match_portuguese  Total  \
# 0  cornea/lens              1                 1      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#       theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  glaucoma              7                 7      9                 77.777778
#
#    portuguese_ratio_percentage
# 0                    77.777778
#               theme  match_english  match_portuguese  Total  \
# 0  glaucoma/uveitis              1                 1      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#            theme  match_english  match_portuguese  Total  \
# 0  lens/cataract              4                 4      8
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                      50.0                         50.0
#         theme  match_english  match_portuguese  Total  \
# 0  low vision              0                 0      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                       0.0                          0.0
#                  theme  match_english  match_portuguese  Total  \
# 0  neuro-ophthalmology              4                 6      7
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                 57.142857                    85.714286
#                     theme  match_english  match_portuguese  Total  \
# 0  ocular plastic surgery              9                10     16
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     56.25                         62.5
#                              theme  match_english  match_portuguese  Total  \
# 0  oncology/ocular plastic surgery              3                 3      3
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#     theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  optics              1                 1      1                     100.0
#
#    portuguese_ratio_percentage
# 0                        100.0
#                theme  match_english  match_portuguese  Total  \
# 0  optics/refraction              1                 1      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#           theme  match_english  match_portuguese  Total  \
# 0  pharmacology              8                 8      9
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                 88.888889                    88.888889
#                    theme  match_english  match_portuguese  Total  \
# 0  pharmacology/glaucoma              1                 1      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#         theme  match_english  match_portuguese  Total  \
# 0  refraction             14                12     31
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                  45.16129                    38.709677
#                    theme  match_english  match_portuguese  Total  \
# 0  refraction/low vision              1                 1      2
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                      50.0                         50.0
#                 theme  match_english  match_portuguese  Total  \
# 0  refractive surgery              2                 2      2
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#     theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  retina              8                10     12                 66.666667
#
#    portuguese_ratio_percentage
# 0                    83.333333
#              theme  match_english  match_portuguese  Total  \
# 0  retina/oncology              1                 1      1
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                     100.0                        100.0
#         theme  match_english  match_portuguese  Total  \
# 0  strabismus              9                 5     11
#
#    english_ratio_percentage  portuguese_ratio_percentage
# 0                 81.818182                    45.454545
#      theme  match_english  match_portuguese  Total  english_ratio_percentage  \
# 0  uveitis              4                 5      8                      50.0
#
#    portuguese_ratio_percentage
# 0                         62.5

# %%
N_REPETITIONS = 1 if N_REPETITIONS < 1 else N_REPETITIONS
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv')
# Out:
#           test  year                            theme  match_english  \
# 0    Teórica I  2022                          anatomy             14
# 1    Teórica I  2022                           cornea              1
# 2    Teórica I  2022                       embryology              1
# 3    Teórica I  2022                         genetics              2
# 4    Teórica I  2022                         glaucoma              1
# 5    Teórica I  2022                         oncology              1
# 6    Teórica I  2022                     pharmacology              3
# 7    Teórica I  2022                       refraction              5
# 8    Teórica I  2022                           retina              1
# 9   Teórica II  2022                   contact lenses              1
# 10  Teórica II  2022                           cornea              3
# 11  Teórica II  2022                      cornea/lens              1
# 12  Teórica II  2022                         glaucoma              6
# 13  Teórica II  2022                 glaucoma/uveitis              1
# 14  Teórica II  2022                    lens/cataract              4
# 15  Teórica II  2022                       low vision              0
# 16  Teórica II  2022              neuro-ophthalmology              4
# 17  Teórica II  2022           ocular plastic surgery              9
# 18  Teórica II  2022  oncology/ocular plastic surgery              3
# 19  Teórica II  2022                           optics              1
# 20  Teórica II  2022                optics/refraction              1
# 21  Teórica II  2022                     pharmacology              5
# 22  Teórica II  2022            pharmacology/glaucoma              1
# 23  Teórica II  2022                       refraction              9
# 24  Teórica II  2022            refraction/low vision              1
# 25  Teórica II  2022               refractive surgery              2
# 26  Teórica II  2022                           retina              7
# 27  Teórica II  2022                  retina/oncology              1
# 28  Teórica II  2022                       strabismus              9
# 29  Teórica II  2022                          uveitis              4
#
#     match_portuguese  Total
# 0                 12     21
# 1                  1      1
# 2                  1      2
# 3                  2      2
# 4                  1      1
# 5                  1      1
# 6                  3      3
# 7                  5     12
# 8                  1      1
# 9                  1      3
# 10                 4      9
# 11                 1      1
# 12                 6      8
# 13                 1      1
# 14                 4      8
# 15                 0      1
# 16                 6      7
# 17                10     16
# 18                 3      3
# 19                 1      1
# 20                 1      1
# 21                 5      6
# 22                 1      1
# 23                 7     19
# 24                 1      2
# 25                 2      2
# 26                 9     11
# 27                 1      1
# 28                 5     11
# 29                 5      8

# %%
N_REPETITIONS = 1 if N_REPETITIONS < 1 else N_REPETITIONS
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_by_theme_{MODEL}.csv')
# Out:
#                               theme  match_english  match_portuguese  Total  \
# 0                           anatomy             14                12     21
# 1                    contact lenses              1                 1      3
# 2                            cornea              4                 5     10
# 3                       cornea/lens              1                 1      1
# 4                        embryology              1                 1      2
# 5                          genetics              2                 2      2
# 6                          glaucoma              7                 7      9
# 7                  glaucoma/uveitis              1                 1      1
# 8                     lens/cataract              4                 4      8
# 9                        low vision              0                 0      1
# 10              neuro-ophthalmology              4                 6      7
# 11           ocular plastic surgery              9                10     16
# 12                         oncology              1                 1      1
# 13  oncology/ocular plastic surgery              3                 3      3
# 14                           optics              1                 1      1
# 15                optics/refraction              1                 1      1
# 16                     pharmacology              8                 8      9
# 17            pharmacology/glaucoma              1                 1      1
# 18                       refraction             14                12     31
# 19            refraction/low vision              1                 1      2
# 20               refractive surgery              2                 2      2
# 21                           retina              8                10     12
# 22                  retina/oncology              1                 1      1
# 23                       strabismus              9                 5     11
# 24                          uveitis              4                 5      8
#
#     responses_english (%)  responses_portuguese (%)
# 0                   66.67                     57.14
# 1                   33.33                     33.33
# 2                   40.00                     50.00
# 3                  100.00                    100.00
# 4                   50.00                     50.00
# 5                  100.00                    100.00
# 6                   77.78                     77.78
# 7                  100.00                    100.00
# 8                   50.00                     50.00
# 9                    0.00                      0.00
# 10                  57.14                     85.71
# 11                  56.25                     62.50
# 12                 100.00                    100.00
# 13                 100.00                    100.00
# 14                 100.00                    100.00
# 15                 100.00                    100.00
# 16                  88.89                     88.89
# 17                 100.00                    100.00
# 18                  45.16                     38.71
# 19                  50.00                     50.00
# 20                 100.00                    100.00
# 21                  66.67                     83.33
# 22                 100.00                    100.00
# 23                  81.82                     45.45
# 24                  50.00                     62.50
