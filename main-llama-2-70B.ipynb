# %% [markdown]
# # Evaluate Classification

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Load the API key and libaries.

# %%
from src.Language_Evaluation_LC import llm_language_evaluation
from src.data_analysis import run_analysis
import pandas as pd

# %% [markdown]
# #### Load the Constants

# %%
PATH = 'data/full_dataset.csv'
MODEL = "meta-llama/Llama-2-70b-chat-hf"
TEMPERATURE = 0.0
N_REPETITIONS = 0
REASONING = False
LANGUAGES = ['spanish', 'tagalog', 'portuguese', 'english']

# %% [markdown]
# #### Run The Experiments:

# %%
# Run evaluation:
llm_language_evaluation(path=PATH, model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, reasoning=REASONING, languages=LANGUAGES)
# Out:
# N_REPETITIONS should be a positive integer, not 0
# N_REPETITIONS will be set to 1
# **************************************************
# Question 1:
# Language: spanish
# Question:
# ¿En qué región ocular se encuentran fisiológicamente las células caliciformes?
# a) córnea.
# b) Limbus corneoscleral.
# c) Línea gris.
# d) Pliegue semilunar.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // The correct answer is b) Limbus corneoscleral.
# }
# ```
#
# Explanation:
#
# The question is asking where physiologically caliciform cells are found in the ocular region. Caliciform cells are specialized epithelial cells that are found in the limbus, which is the region between the cornea and the sclera. Therefore, the correct answer is b) Limbus corneoscleral.
# {'response': 'b'}
# Language: tagalog
# Question:
# Aling bahagi ng mata ay kung saan matatagpuan ang mga caliciform cells?
# a) Cornea.
# b) Corneoscleral limbus.
# c) Grey line.
# d) Semilunar fold.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // Corneoscleral limbus
# }
# ```
#
# Explanation:
#
# The corneoscleral limbus is the region where the cornea and the sclera meet. It is a thin layer of tissue that forms the junction between the two structures. The caliciform cells are found in this region, specifically in the posterior portion of the corneoscleral limbus, also known as the posterior limbus.
#
# Therefore, option b, "Corneoscleral limbus," is the correct answer.
# {'response': 'b'}
# Language: portuguese
# Question:
# Em qual região ocular células caliciformes são fisiologicamente encontradas?
# a)Córnea.
# b)Limbo corneoescleral.
# c)Linha cinzenta.
# d)Prega semilunar.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // b) Limbo corneoescleral
# }
# ```
#
# Explanation:
#
# The question is asking where caliciform cells are found in the eye. The correct answer is b) Limbo corneoescleral, which is a region in the eye that contains caliciform cells. These cells are responsible for the formation of the corneal epithelium.
#
# Here are the options and their explanations:
#
# a) Córnea - This is the outermost layer of the eye, but it does not contain caliciform cells.
#
# c) Linha cinzenta - This is a layer of the eye that separates the cornea and the iris, but it does not contain caliciform cells.
#
# d) Prega semilunar - This is a small area of the eye that is located between the iris and the lens, but it does not contain caliciform cells.
# {'response': 'b'}
# Language: english
# Question:
# In which ocular region are caliciform cells physiologically found?
# a) Cornea.
# b) Corneoscleral limbus.
# c) Gray line.
# d) Semilunar fold.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // b) Corneoscleral limbus
# }
# ```
#
# Caliciform cells are physiologically found in the corneoscleral limbus, which is the region where the cornea and sclera meet.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 2:
# Language: spanish
# Question:
# Marque la alternativa que mejor correlaciona las características histológicas con los respectivos tejidos oculares:
#
# I. Monocapa de células estrechamente unidas por complejos de unión.
# II.Las estrías paralelas y regulares observadas bajo microscopía óptica, perpendicular al epitelio.
# Iii.Contiene células bipolares, células amacrinas, células horizontales y células Muller.
# IV.Contiene células magnocelulares, parvocelulares y coniocelulares.
#
# A. Fotorreceptores.
# B. Epitelio pigmentado de la retina.
# C. Capa ganglionar de la retina.
# D. Capa nuclear interna.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# I. Monocapa de células estrechamente unidas por complejos de unión. - This describes the epithelial tissue, which is composed of a single layer of cells that are tightly connected by cell-cell junctions.
#
# II. Las estrías paralelas y regulares observadas bajo microscopía óptica, perpendicular al epitelio. - This describes the retina, specifically the photoreceptors, which have parallel and regular arrangements of microvilli.
#
# III. Contiene células bipolares, células amacrinas, células horizontales y células Muller. - This describes the inner layer of the retina, specifically the bipolar cells, amacrine cells, horizontal cells, and Müller cells.
#
# IV. Contiene células magnocelulares, parvocelulares y coniocelulares. - This describes the inner nuclear layer of the retina, which contains magnocellular, parvocellular, and koniocellular cells.
#
# Therefore, the correct answer is option b: I: B; II: A; III: D; IV: C.
# {'response': 'b'}
# Language: tagalog
# Question:
# Ipagpares ang bahagi ng retina sa Hanay B sa tamang paglalarawan ng itong mga katangian sa Hanay A.
#
# I. Isang hanay ng mga cells na mahigpit na pinagsasama-sama ng mga junctional complexes
# II. Pantay at regular na mga hanay ng cells, tadlong sa epithelium
# III. May iba't ibang klaseng cells ito, katulad ng bipolar cells, amacrine cells, horizontal cells, at Muller cells.
# IV. Mayroon ito ng magnocellular, parvocellular, at coniocellular cells.
#
# A. Photoreceptors.
# B. Retinal pigment epithelium.
# C. Retinal ganglionic layer.
# D. Inner Nuclear Layer.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "c) I: B; II: A; III: C; IV: C."
# }
# ```
#
# Explanation:
#
# I. Isang hanay ng mga cells na mahigpit na pinagsasama-sama ng mga junctional complexes - This describes the feature of the retina in Hanay B, which is characterized by a single layer of cells that are tightly connected by junctional complexes.
#
# II. Pantay at regular na mga hanay ng cells, tadlong sa epithelium - This describes the feature of the retina in Hanay A, which is characterized by a regular and uniform layer of cells that are tightly connected to the epithelium.
#
# III. May iba't ibang klaseng cells ito, katulad ng bipolar cells, amacrine cells, horizontal cells, at Muller cells - This describes the feature of the retina in Hanay B, which contains different types of cells, including bipolar cells, amacrine cells, horizontal cells, and Muller cells.
#
# IV. Mayroon ito ng magnocellular, parvocellular, at coniocellular cells - This describes the feature of the retina in Hanay A, which contains different types of cells, including magnocellular, parvocellular, and coniocellular cells.
#
# Therefore, the correct answer is c) I: B; II: A; III: C; IV: C.
# {'response': 'c) I: B; II: A; III: C; IV: C.'}
# Language: portuguese
# Question:
# Assinale a alternativa que melhor correlaciona as características histológicas com os respectivos tecidos oculares:
#
# I. Monocamada de células fortemente unidas por complexos juncionais.
# II. Estriações paralelas e regulares observadas à microscopia óptica, perpendiculares ao epitélio.
# III. Contém células bipolares, células amácrinas, células horizontais e células de Muller.
# IV. Contém células magnocelulares, parvocelulares e coniocelulares.
#
# A. Fotorreceptores.
# B. Epitélio pigmentado da pigmentado da retina.
# C. Camada ganglionar retiniana.
# D. Camada nuclear interna.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# I. Monocamada de células fortemente unidas por complexos juncionais. - This describes the characteristic of the photoreceptors (A), which are strongly connected by junctional complexes.
#
# II. Estriações paralelas e regulares observadas à microscopia óptica, perpendiculares ao epitélio. - This describes the characteristic of the retina's epithelial layer (B), which has parallel and regular ridges observed under optical microscopy, perpendicular to the epithelium.
#
# III. Contém células bipolares, células amácrinas, células horizontais e células de Muller. - This describes the characteristic of the inner nuclear layer (C), which contains bipolar cells, amacrine cells, horizontal cells, and Müller cells.
#
# IV. Contém células magnocelulares, parvocelulares e coniocelulares. - This describes the characteristic of the inner layer of the retina (D), which contains magnocellular, parvocellular, and koniocellular cells.
#
# Therefore, the correct answer is option b: I: B; II: A; III: D; IV: C.
# {'response': 'b'}
# Language: english
# Question:
# Mark the alternative that best correlates the histological characteristics with the respective ocular tissues:
#
# I. Monolayer of cells tightly joined together by junctional complexes.
# II. Parallel and regular striations observed under optical microscopy, perpendicular to the epithelium.
# III. It contains bipolar cells, amacrine cells, horizontal cells and Muller cells.
# IV. It contains magnocellular, parvocellular and coniocellular cells.
#
# A. Photoreceptors.
# B. Retinal pigmented epithelium.
# C. Retinal ganglionic layer.
# D. Inner nuclear layer.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# I. Monolayer of cells tightly joined together by junctional complexes. - This describes the retinal pigmented epithelium (RPE), which is a monolayer of cells that forms the outer layer of the retina and is tightly joined together by junctional complexes.
#
# II. Parallel and regular striations observed under optical microscopy, perpendicular to the epithelium. - This describes the photoreceptors, which are arranged in a parallel and regular pattern and can be observed under optical microscopy.
#
# III. It contains bipolar cells, amacrine cells, horizontal cells and Muller cells. - This describes the inner nuclear layer, which contains these types of cells.
#
# IV. It contains magnocellular, parvocellular and coniocellular cells. - This describes the retinal ganglionic layer, which contains these types of cells.
#
# Therefore, the correct answer is option b: I: B; II: A; III: D; IV: C.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 3:
# Language: spanish
# Question:
# Ordene los tres nombres de células que se encuentran en el epitelio corneal, comenzando con el má superficial, seguidos por el intermedio y lo profundo.
# a) Plana, alada, basal.
# b) Alada, basal, plana.
# c) Basal, plana, alada.
# d) Alada, plana, basal.
# Test #0:
# response
#   ```json
# {
# 	"response": "b) Alada, basal, plana."
# }
# ```
#
# Explanation:
#
# The three layers of cells in the corneal epithelium, starting from the most superficial, are:
#
# 1. Alada (winged) cells: These cells are found in the outermost layer of the corneal epithelium and are characterized by the presence of microvilli, which give them a wing-like appearance.
# 2. Basal cells: These cells are found in the middle layer of the corneal epithelium and are responsible for the production of new keratinocytes, which are the main cells that make up the epithelium.
# 3. Plana cells: These cells are found in the innermost layer of the corneal epithelium and are characterized by their flat, squamous appearance.
#
# Therefore, the correct order of the three layers of cells in the corneal epithelium, starting from the most superficial, is: alada, basal, plana.
#
# Note: The term "plana" is not used in some sources, and instead, the term "stratum corneum" is used to refer to the outermost layer of the corneal epithelium. However, "plana" is a commonly used term in ophthalmology and is considered a synonym of "stratum corneum."
# {'response': 'b) Alada, basal, plana.'}
# Language: tagalog
# Question:
# Ipagsunud-sunod ang mga cells ng corneal epithelium, mula sa pinakamababaw hanggang sa pinakamalalim.
# a) Flat, wing, basal.
# b) Wing, basal, flat.
# c) Basal, flat, wing.
# d) Wing, flat, basal.
# Test #0:
# response
#   ```json
# {
# 	"response": "b) Wing, basal, flat."
# }
# ```
#
# Explanation:
#
# The correct order of the layers of the corneal epithelium, from superficial to deep, is:
#
# 1. Wing cells (also known as peripheral cells)
# 2. Basal cells (also known as stem cells)
# 3. Flat cells (also known as squamous cells)
#
# Therefore, the correct answer is b) Wing, basal, flat.
# {'response': 'b) Wing, basal, flat.'}
# Language: portuguese
# Question:
# Ordene as três denominações celulares encontradas no epitélio da córnea, iniciando pelo mais superficial, seguido do intermediário e do profundo.
# a)Plana, alada, basal.
# b)Alada, basal, plana.
# c)Basal, plana, alada.
# d)Alada, plana, basal.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The three denominations of cells found in the epithelium of the cornea, starting from the most superficial, followed by the intermediate, and then the deepest, are:
#
# * Alada (winged cells)
# * Basal (basal cells)
# * Plana (squamous cells)
#
# Therefore, the correct order is b) Alada, basal, plana.
# {'response': 'b'}
# Language: english
# Question:
# Order the three cell names found in the corneal epithelium, starting with the most superficial, followed by the intermediate and the deep.
# a) Flat, wing, basal.
# b) Wing, basal, flat.
# c) Basal, flat, wing.
# d) Wing, flat, basal.
# Test #0:
# response
#   ```json
# {
# 	"response": "c) Basal, flat, wing."
# }
# ```
#
# The three cell names found in the corneal epithelium, starting with the most superficial, are:
#
# 1. Basal cells: These cells are the deepest layer of the corneal epithelium and are responsible for producing new cells to replace damaged or dying cells.
# 2. Flat cells: Also known as squamous cells, these cells are the intermediate layer of the corneal epithelium and are responsible for maintaining the integrity of the corneal surface.
# 3. Wing cells: Also known as cuboidal cells, these cells are the most superficial layer of the corneal epithelium and are responsible for producing the tear film that lubricates the eye.
#
# Therefore, the correct order, starting with the most superficial, is:
#
# c) Basal, flat, wing.
# {'response': 'c) Basal, flat, wing.'}
# **************************************************
# **************************************************
# Question 4:
# Language: spanish
# Question:
# Con respecto a la membrana de la córnea de Descemet, es correcto declarar:
# a) Las células endoteliales no participan en su formación.
# b) Su grosor en el adulto es de aproximadamente 30 µm.
# c) Su porción más anterior es de origen embrionario.
# d) Su grosor se reduce con la edad.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# La respuesta correcta es b) Su grosor en el adulto es de aproximadamente 30 µm.
#
# La membrana de la córnea de Descemet es una capa delgada de células epiteliales que recubre la superficie posterior de la córnea. Su grosor en el adulto promedio es de aproximadamente 30 micras (μm), aunque puede variar ligeramente según la edad y otras condiciones. Las células endoteliales no participan en su formación, ya que son células que se encuentran en la superficie posterior de la córnea y son responsables de la regulación del fluido en la cámara posterior del ojo. La porción más anterior de la membrana de la córnea de Descemet es de origen embrionario, y su grosor puede disminuir ligeramente con la edad.
# {'response': 'b'}
# Language: tagalog
# Question:
# Tama tungkol sa Descemet's membrane ng cornea:
# a) Ang mga endothelial cells ay hindi nakikilahok sa pagbuo nito.
# b) Ang kapal nito ay halos 30 µm.
# c) Ang pinakaharap na bahagi ng Descemet's membrane ay nagmumula sa embryo.
# d) Kapag tumatanda, mas numinipis ang Descemet's membrane.
# Test #0:
# response
#   Here's my answer:
# ```json
# {
# 	"response": b // The correct answer is b
# }
# ```
#
# Explanation:
#
# The correct answer is b) Ang kapal nito ay halos 30 µm.
#
# Descemet's membrane is a thin layer of tissue that covers the cornea, the clear dome-shaped surface at the front of the eye. It is composed of a single layer of endothelial cells and has a thickness of approximately 30 micrometers (μm). The other options are incorrect:
#
# a) Ang mga endothelial cells ay hindi nakikilahok sa pagbuo nito - This statement is false. Endothelial cells are the cells that line the inner surface of Descemet's membrane and play a crucial role in maintaining the health and function of the cornea.
#
# c) Ang pinakaharap na bahagi ng Descemet's membrane ay nagmumula sa embryo - This statement is false. Descemet's membrane is not derived from the embryo, but rather from the mesenchyme, a type of connective tissue that develops during fetal development.
#
# d) Kapag tumatanda, mas numinipis ang Descemet's membrane - This statement is false. Descemet's membrane does not become thinner with age. In fact, it is thought to remain relatively constant in thickness throughout life.
# {'response': 'b'}
# Language: portuguese
# Question:
# Sobre a membrana de Descemet da córnea, é correto afirmar:
# a)As células endoteliais não participam da sua formação.
# b)Sua espessura no adulto é de cerca de 30 µm.
# c)Sua porção mais anterior é de origem embrionária.
# d)Sua espessura reduz-se com a idade.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The correct answer is b) Sua espessura no adulto é de cerca de 30 µm.
#
# The Descemet membrane is a thin layer of tissue that covers the surface of the cornea, the clear dome-shaped surface at the front of the eye. It is composed of a single layer of cells called endothelial cells, which are responsible for maintaining the proper amount of moisture in the cornea. The Descemet membrane is approximately 30 micrometers thick in adults, and its thickness can decrease with age.
#
# Therefore, option b is the correct answer. Option a is incorrect because endothelial cells do play a role in the formation of the Descemet membrane. Option c is also incorrect because the Descemet membrane is not of embryonic origin. Option d is incorrect because the thickness of the Descemet membrane does not necessarily reduce with age.
# {'response': 'b'}
# Language: english
# Question:
# Regarding Descemet's membrane of the cornea, it is correct to state:
# a) Endothelial cells do not participate in its formation.
# b) Its thickness in the adult is about 30 µm.
# c) Its most anterior portion is of embryonic origin.
# d) Its thickness reduces with age.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer is b) Its thickness in the adult is about 30 µm.
#
# Descemet's membrane is a thin layer of extracellular material that covers the posterior surface of the cornea. It is composed of a variety of components, including collagen, glycoproteins, and proteoglycans, and plays an important role in maintaining the integrity and function of the cornea.
#
# According to the statement, the thickness of Descemet's membrane in the adult is about 30 µm. This is a correct statement, as studies have shown that the thickness of Descemet's membrane in the adult human cornea ranges from approximately 20 to 40 µm, with a mean value of around 30 µm.
#
# Option a is incorrect, as endothelial cells do participate in the formation of Descemet's membrane. Option c is also incorrect, as the most anterior portion of Descemet's membrane is not of embryonic origin. Option d is incorrect, as the thickness of Descemet's membrane does not reduce with age.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 5:
# Language: spanish
# Question:
# Respecto a la capa lipídica de la película lagrimal, seleccionar la alternativa correcta.
# a) Su finalidad básica es estabilizar la película y es secretada por las glándulas de Meibomio y Manz.
# b) Entre sus componentes se encuentran los ésteres de colesterol y una de sus funciones es retrasar la evaporación de la película lagrimal.
# c) En la disfunción de las glándulas de Meibomio, el punto de fusión de su secreción disminuye, contribuyendo al estancamiento de estas sustancias.
# d) Puede valorarse por el tiempo de ruptura de la película lagrimal, permaneciendo intacta menos de cinco segundos en ojos sanos.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# La capa lipídica de la película lagrimal es una capa fina y transparente que cubre la superficie del ojo. La capa lipídica está compuesta por ésteres de colesterol y otras sustancias, y su función principal es retrasar la evaporación de la película lagrimal, lo que ayuda a mantener la humedad y la integridad de la superficie del ojo. La capa lipídica es secretada por las glándulas de Meibomio y Manz, y su funcionamiento correcto es esencial para el bienestar ocular.
#
# En la disfunción de las glándulas de Meibomio, el punto de fusión de la secreción de estas glándulas disminuye, lo que puede contribuir al estancamiento de las sustancias que componen la capa lipídica y afectar su capacidad para retrasar la evaporación de la película lagrimal.
#
# El tiempo de ruptura de la película lagrimal es una medida importante de su integridad y función adecuada. En ojos sanos, la película lagrimal debe permanecer intacta durante al menos cinco segundos después de la aplicación de un estímulo. Si la película lagrimal se rompe antes de este tiempo, puede indicar una disfunción en la capa lipídica o en la producción de lágrimas.
# {'response': 'b'}
# Language: tagalog
# Question:
# Piliin ang tamang sagot tungkol sa lipid layer ng lacrimal film.
# a) Ang lipidic layer ay nagpapatag ng lacrimal film na nanggagaling sa meibomian at manz glands.
# b) May laman itong mga cholesterol esters na nakakatulong sa pagbabagal ng pagtuyo ng luha.
# c) Kapag nagkakaroon ng meibomian gland dysfunction, bumababa ang fusion point na nagpapahinto ng produksyon ng lipid.
# d) Nasusuri ito gamit ang lacrial film break up time, kung saan ay walang lacrimal film break up hanggang 5 na segundo sa normal na mata.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is option c: "Kapag nagkakaroon ng meibomian gland dysfunction, bumababa ang fusion point na nagpapahinto ng produksyon ng lipid."
#
# The lipid layer of the lacrimal film is produced by the meibomian glands, which are located in the upper eyelid. The meibomian glands produce a lipid-rich secretion that helps to prevent evaporation of the tear film. In cases where there is a dysfunction of the meibomian glands, the fusion point of the lipid layer is lowered, leading to a decrease in the production of lipid. This can cause dry eyes and other ocular surface problems.
#
# The other options are incorrect because:
#
# * Option a is incorrect because the lipid layer is not produced by the meibomian and manz glands, but rather by the meibomian glands alone.
# * Option b is incorrect because while cholesterol esters are present in the lipid layer, they do not help to slow down the evaporation of the tear film.
# * Option d is incorrect because the lacrimal film break-up time is not a measure of the lipid layer, but rather a measure of the tear film's stability.
# {'response': 'c'}
# Language: portuguese
# Question:
# Sobre a camada lipídica do filme lacrimal, assinale a alternativa correta.
# a)Tem por propósito básico estabilizar o filme e é secretada pelas glândulas de Meibomius e de Manz.
# b)Ésteres de colesterol estão entre seus componentes e uma de suas funções é retardar a evaporação do filme lacrimal.
# c)Na disfunção das glândulas de Meibomius, o ponto de fusão de sua secreção diminui, colaborando para a estagnação dessas substâncias.
# d)Pode ser avaliada pelo tempo de ruptura do filme lacrimal, permanecendo intacta por menos de cinco segundos em olhos saudáveis.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The correct answer is b) Ésteres de colesterol estão entre seus componentes e uma de suas funções é retardar a evaporação do filme lacrimal.
#
# The lipid layer of the tear film is a thin layer of lipids that covers the surface of the tear film and prevents it from evaporating too quickly. It is composed of cholesterol esters, which are responsible for its stability and function. The lipid layer is secreted by the Meibomian glands and the lacrimal gland, and its dysfunction can lead to dry eye syndrome.
#
# Therefore, option b is the correct answer. Option a is incorrect because the lipid layer is not responsible for stabilizing the tear film. Option c is incorrect because the ponto de fusão (melting point) of the lipid layer is not related to its function. Option d is incorrect because the lipid layer cannot be evaluated by the time it takes for the tear film to break, as it is a measure of the tear film's stability and not its lipid content.
# {'response': 'b'}
# Language: english
# Question:
# About the lipidic layer of the lacrimal film, choose the right answer.
# a) its purpose is to stabilize the lacrimal film secreted by the meibomian and manz glans.
# b) Cholesterol esters are within its components, and one of the functions is to delay the lacrimal film evaporation.
# c) In meibomian gland dysfunction, the fusion point decrease, leading to stagnation.
# d) can be evaluated by the lacrimal film break up time, keeping intact less than five seconds in healthy eyes.
# Test #0:
# response
#   Here's the answer in Spanish:
# ```json
# {
# 	"response": "b"
# }
# ```
# La capa lipídica de la película lacrimar es importante para la función de los glándulos de Meibomio y Manz. La capa lipídica ayuda a evitar la evaporación de la película lacrimar, lo que permite que la película lacrimar se mantenga más tiempo en la superficie del ojo. La función de la capa lipídica es retrasar la evaporación de la película lacrimar, lo que permite que la película lacrimar se mantenga más tiempo en la superficie del ojo.
#
# En el caso de la disfunción de los glándulos de Meibomio, la temperatura corporal disminuye, lo que puede afectar la fusión de la capa lipídica y provocar la estagnation de la película lacrimar.
#
# La integridad de la capa lipídica se puede evaluar mediante la prueba de tiempo de ruptura de la película lacrimar, que debe mantenerse intacta durante menos de cinco segundos en los ojos saludables.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 6:
# Language: spanish
# Question:
# En cuanto a los músculos externos del ojo, seleccione la alternativa correcta.
# a) En la ley de Hering, la inervación se distribuye por igual entre los músculos agonistas y antagonistas, para una versión determinada.
# b) Los movimientos de seguimiento se producen de forma automática, lenta, moviendo el punto de fijación.
# c) En la ley de Sherrington, el estímulo de la contracción se distribuye entre los agonistas de ambos ojos, de modo que se produce de forma simétrica.
# d) Los movimientos sacádicos se caracterizan por movimientos bruscos, descoordinados y de carácter totalmente reflejo.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# La respuesta correcta es la opción c) En la ley de Sherrington, el estímulo de la contracción se distribuye entre los agonistas de ambos ojos, de modo que se produce de forma simétrica.
#
# La ley de Sherrington establece que el estímulo de la contracción muscular se distribuye entre los músculos agonistas de ambos lados del cuerpo, lo que produce una contracción simétrica y coordinada. Esta ley se aplica a los músculos externos del ojo, que trabajan juntos para producir movimientos de seguimiento suaves y coordinados.
#
# Por lo tanto, la opción c es la respuesta correcta. Las otras opciones no son correctas y no se relacionan con los músculos externos del ojo o la ley de Sherrington.
# {'response': 'c'}
# Language: tagalog
# Question:
# Alin sa mga sumusunod ang tama tungkol sa mga extraocular muscles?
# a) Sa Hering's Law, ang stimulation na nakukuha ng isang ugat ay pantay sa agonist at antagonist muscles papunta sa isang ocular version.
# b) Ang persecutory movements ay kusang nangyayari, kung saan nag-iiba ang fixation point.
# c) Inilalahad ng Sherrington's Law na ang agonist muscle sa kaliwa't kanang mata ay makakakuha ng pantay na stimulus mula sa utak.
# d) Inilalarawan ang saccadic movements na matarik, hindi tugma, at bilang isang reflex movement.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Inilalahad ng Sherrington's Law na ang agonist muscle sa kaliwa't kanang mata ay makakakuha ng pantay na stimulus mula sa utak.
#
# Sherrington's Law states that the agonist muscle of the opposing eye receives equal stimulation from the brain. This means that when one eye looks in a certain direction, the muscle that moves the opposing eye in the same direction receives equal stimulation. This helps to maintain binocular vision and prevent eye strain.
#
# The other options are incorrect because:
#
# a) Hering's Law refers to the equal innervation of agonist and antagonist muscles, but it does not apply to the extraocular muscles.
#
# b) Persecutory movements are not related to the extraocular muscles.
#
# d) Saccadic movements are fast, irregular, and not related to the extraocular muscles.
# {'response': 'c'}
# Language: portuguese
# Question:
# Sobre os músculos oculares externos, assinale a alternativa correta.
# a)Na lei de Hering, a inervação se distribui igualmente para os músculos agonista e antagonista, para determinada versão.
# b)Os movimentos persecutórios se dão automaticamente, de maneira lenta, ao deslocamento do ponto de fixação.
# c)Na lei de Sherrington, o estímulo de contração é distribuído entre os agonistas de ambos os olhos, para que ela ocorra simetricamente.
# d)Os movimentos sacádicos são caracterizados por movimentos bruscos, descoordenados, de natureza totalmente reflexa.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is option c. According to Sherrington's law, the stimulus for contraction is distributed between the agonists of both eyes, so that the contraction occurs symmetrically. This means that when one eye moves, the other eye also moves in the opposite direction, allowing for coordinated and smooth eye movements.
#
# Option a is incorrect because it refers to Hering's law, which states that the innervation of the extraocular muscles is distributed equally between the agonist and antagonist muscles for a given version. This law does not relate to the coordination of eye movements.
#
# Option b is also incorrect because it refers to the slow, automatic movements of the eyes that occur when the point of fixation is displaced, known as persecutory movements. These movements are not related to the coordination of eye movements.
#
# Option d is incorrect because it refers to sacadic movements, which are characterized by rapid, coordinated movements of the eyes between fixation points. While these movements are reflexive, they are not necessarily disordered or uncoordinated.
# {'response': 'c'}
# Language: english
# Question:
# Regarding the external ocular muscles, choose the correct answer.
# a) in the Hering's law, the innervation is equally distributed to the agosist and antagonist muscles, for a given ocular version.
# b) The persecutory movements will automatically occur, slowly, with the displacement of the fixation point.
# c) In the sherrington's law, the contraction stimulus is distributed between the agonists of both eyes, so that it occur symmetrically.
# d) Saccadic movements are characterized by abrupt, uncoordinated, reflex movments.
# Test #0:
# response
#   ```json
# {
# 	"response": "a"
# }
# ```
#
# Explanation:
#
# According to Hering's law, the innervation of the external ocular muscles is equally distributed to the agonist and antagonist muscles for a given ocular version. This means that when one eye is looking in a particular direction, the innervation of the muscles that control that eye's movement is equally distributed between the agonist and antagonist muscles. This allows for smooth and coordinated eye movements.
#
# Option b is incorrect because persecutory movements are not automatically occurring, slow movements. Persecutory movements are actually rapid, conjugate movements of the eyes that occur when the fixation point is displaced.
#
# Option c is incorrect because it refers to Sherrington's law, which states that the contraction stimulus is distributed between the agonists of both eyes, resulting in symmetrical movements. This is not related to the external ocular muscles.
#
# Option d is incorrect because saccadic movements are not abrupt, uncoordinated, reflex movements. Saccadic movements are actually fast, coordinated movements of the eyes that allow us to quickly shift our gaze between different points in the visual field.
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 7:
# Language: spanish
# Question:
# Sobre la córnea, es correcto decir:
# a) La disposición de las fibrillas de colágeno corneal no está relacionado con su transparencia.
# b) El pleomorfismo de las células endoteliales se caracteriza por el tamaño de estas células.
# c) Las células de estoma anteriores tienen una gran cantidad de mitocondrias, responsables de la producción de energía que suministra la bomba endotelial.
# d) El endotelio se comporta como una barrera permeable no selectiva entre el humor acuoso y su propia sustancia.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# La respuesta correcta es la opción c: Las células de estoma anteriores tienen una gran cantidad de mitocondrias, responsables de la producción de energía que suministra la bomba endotelial.
#
# La córnea es una estructura transparente en la superficie del ojo que tiene la función de enfocar la luz y permitir la visión. La transparencia de la córnea se debe a la disposición de las fibrillas de colágeno corneal, que están dispuestas de manera regular y paralela, lo que permite que la luz pase a través de ellas sin ser dispersada.
#
# El pleomorfismo de las células endoteliales se refiere a la variación en el tamaño y la forma de estas células, que pueden ser pequeñas y uniformes o grandes y pleomórficas. Sin embargo, esto no está relacionado con la transparencia de la córnea.
#
# El endotelio es una capa de células que recubre la superficie posterior de la córnea y tiene la función de regular la cantidad de humor acuoso que entra y sale de la cámara anterior del ojo. Aunque el endotelio actúa como una barrera permeable no selectiva, no es la razón por la cual la córnea es transparente.
#
# Por lo tanto, la respuesta correcta es la opción c, que describe la función de las células de estoma anteriores en la producción de energía para la bomba endotelial.
# {'response': 'c'}
# Language: tagalog
# Question:
# Alin sa mga sumusunod ang tama tungkol sa cornea?
# a) Ang pag-aayos ng corneal collagen fibrils ay walang kaugnayan sa pagiging transparent nito.
# b) Ang pleomorphism ng mga endothelial cells ay nailalarawan sa pagkakaiba sa laki ng mga cell.
# c) Maraming mitochondria ang mga cell ng anterior stroma. Sila ay responsable para sa paggawa ng enerhiya para sa endothelial pump.
# d) Ang endothelium ay isang permeable non-selective barrier sa gitna ng aqueous humor at substantia propria.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Maraming mitochondria ang mga cell ng anterior stroma. Sila ay responsable para sa paggawa ng enerhiya para sa endothelial pump.
#
# The cornea is a transparent tissue that is responsible for refracting light and allowing us to see. The transparency of the cornea is due to the regular arrangement of collagen fibrils in the stroma, which allows light to pass through without being scattered. The endothelium, a layer of cells on the inner surface of the cornea, plays a crucial role in maintaining the transparency of the cornea by pumping water out of the stroma and keeping it hydrated. The mitochondria in the cells of the anterior stroma are responsible for producing energy for the endothelial pump, which helps maintain the proper thickness and transparency of the cornea.
#
# Therefore, option c is the correct answer. Option a is incorrect because the arrangement of collagen fibrils in the stroma is not related to the transparency of the cornea. Option b is also incorrect because pleomorphism refers to the variation in size and shape of cells, which is not related to the function of the endothelium. Option d is incorrect because the endothelium is a selective barrier that regulates the flow of substances between the aqueous humor and the substantia propria, but it is not a non-selective barrier.
# {'response': 'c'}
# Language: portuguese
# Question:
# Sobre a córnea, é correto afirmar:
# a)A disposição das fibrilas de colágeno corneanas não tem relação com a sua transparência.
# b)Pleomorfismo das células endoteliais é caracterizado pela variação do tamanho dessas células.
# c)As células do estroma anterior possuem grande quantidade de mitocôndrias, responsáveis pela produção de energia que supre a bomba endotelial.
# d)O endotélio comporta-se como uma barreira permeável não-seletiva entre o humor aquoso e a substância própria.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is option c. The cells of the anterior stroma have a large number of mitochondria, which are responsible for producing energy that supports the endothelial pump. This is a characteristic feature of the cornea, and it is important for maintaining the transparency of the tissue.
#
# Option a is incorrect because the arrangement of collagen fibers in the cornea does have an impact on its transparency. The fibers are arranged in a specific way to allow light to pass through the tissue with minimal scattering.
#
# Option b is also incorrect because pleomorphism of endothelial cells refers to the variation in size and shape of these cells, which can be seen in certain diseases or conditions. It is not a characteristic feature of the normal cornea.
#
# Option d is incorrect because the endothelium does not behave as a non-selective barrier between the aqueous humor and the substance proper. It plays a crucial role in regulating the amount of fluid in the cornea and maintaining its transparency.
# {'response': 'c'}
# Language: english
# Question:
# About the cornea, it is correct to state.
# a) The arrangement of corneal collagen fibrils is unrelated to its transparency.
# b) Pleomorphism of endothelial cells is characterized by the variation in the size of these cells.
# c) anterior stroma have a large number of mitochondria, responsible for the production of energy that supplies the endothelial pump.
# d) The endothelium behaves as a permeable non-selective barrier between the aqueous humor and the substantia propria.
# Test #0:
# response
#   Here's the answer in Spanish:
# ```json
# {
# 	"response": "c"
# }
# ```
# La afirmación correcta es la opción c: El estroma anterior tiene un gran número de mitocondrias, responsables de la producción de energía que suministra la bomba endotelial.
#
# Here's the answer in Tagalog:
# ```json
# {
# 	"response": "c"
# }
# ```
# Ang tamaan na may korekta ay option c: Ang anterior stroma ay may malaking number ng mitocondria, na responsable sa produksyon ng enerhiya na suministrado ng endotelial pump.
#
# Here's the answer in Portuguese:
# ```json
# {
# 	"response": "c"
# }
# ```
# A afirmação correta é a opção c: O estroma anterior tem um grande número de mitocôndrias, responsáveis pela produção de energia que fornece a bomba endotelial.
#
# Here's the answer in English:
# ```json
# {
# 	"response": "c"
# }
# ```
# The correct statement is option c: The anterior stroma has a large number of mitochondria, responsible for the production of energy that supplies the endothelial pump.
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 8:
# Language: spanish
# Question:
# Elija la alternativa que llena correctamente los vacíos.La levocicloversión corresponde a ____________ del ojo derecho y ________ del ojo izquierdo y se activa cuando la cabeza está inclinada hacia el hombro___________.
# a) Excicloducción / incicloducción / izquierdo.
# b) incicloducción / excicloducción / izquierdo.
# c) Excicloducción / incicloducción / derecho.
# d) Incalducción / excicloducción / derecho.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# La levocicloversión corresponde a la excicloducción del ojo derecho y la incicloducción del ojo izquierdo, y se activa cuando la cabeza está inclinada hacia el hombro derecho. Por lo tanto, la respuesta correcta es la opción b.
# {'response': 'b'}
# Language: tagalog
# Question:
# Piliin ang tamang sagot: Ang levocycloversion ay tumutugma sa ____________ ng kanang mata at ________ ng kaliwang mata. Napapasimuno ito kapag pinaikot ang ulo sa ____ na balikat.
# a) Excicloduction / incicloduction / kaliwa
# b) incicloduction / excicloduction / kaliwa
# c) Excicloduction / incicloduction / kanan
# d) incicloduction / excicloduction / kanan
# Test #0:
# response
#   Here's my answer:
# ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the direction of the levocycloversion, which is a term used to describe the rotation of the eye during a specific type of eye movement. The correct answer is b) incicloduction / excicloduction / kaliwa.
#
# Incicloduction refers to the inward movement of the eye, while excicloduction refers to the outward movement. Kaliwa refers to the left eye. Therefore, the correct answer is b) incicloduction / excicloduction / kaliwa, as the levocycloversion involves the inward movement of the left eye.
# {'response': 'b'}
# Language: portuguese
# Question:
# Assinale a alternativa que preenche corretamente as lacunas. A levocicloversão corresponde a ____________ do olho direito e ________ do olho esquerdo e é desencadeada quando se inclina a cabeça para o ombro___________.
# a)Exciclodução / inciclodução / esquerdo.
# b)Inciclodução / exciclodução / esquerdo.
# c)Exciclodução / inciclodução / direito.
# d)Inciclodução / exciclodução / direito.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the correct term for the movement of the eye that corresponds to the movement of the head to the shoulder. The correct answer is "incycloduction" which is the movement of the eye inward (towards the nose) and downward, and it occurs when the head is inclined to the shoulder.
#
# In Portuguese, the term for incycloduction is "incyclodução" and it can be translated to English as "incycloduction" or "inward and downward movement of the eye".
#
# Therefore, the correct answer is option b: "Inciclodução / exciclodução / esquerdo".
# {'response': 'b'}
# Language: english
# Question:
# Choose the alternative that correctly fills in the gaps. Levocycloversion corresponds to ____________ of the right eye and ________ of the left eye and is triggered when the head is tilted towards the ___ shoulder.
# a) Excicloduction / incicloduction / left.
# b) Incicloduction / excicloduction / left.
# c) Excicloduction / incicloduction / right.
# d) Incicloduction / excicloduction / right.
# Test #0:
# response
#   Here's the answer in markdown format:
# ```json
# {
# 	"response": "b"  // b) Incicloduction / excicloduction / left.
# }
# ```
#
# Explanation:
# Levocycloversion is a reflexive movement of the eyes that occurs when the head is tilted towards the left shoulder. It corresponds to incycloduction of the right eye and excicycloduction of the left eye.
#
# Incycloduction is the movement of the eye inward, towards the nose, while excicycloduction is the movement of the eye outward, away from the nose.
#
# Therefore, the correct answer is option b: Incicloduction / excicloduction / left.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 9:
# Language: spanish
# Question:
# Con respecto a las células del cuerpo vítreo, marque la alternativa correcta.
# a) Son más numerosas en el adulto que en el vítreo embrionario.
# b) Están representadas principalmente por linfocitos y neutrófilos maduros.
# c) Son abundantes en la región de la base vítrea.
# d) Están ausentes en el recién nacido.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# La respuesta correcta es la opción c) Son abundantes en la región de la base vítrea. Las células del cuerpo vítreo son más abundantes en la región de la base vítrea que en otras partes del cuerpo.
# {'response': 'c'}
# Language: tagalog
# Question:
# Alin ang tama tungkol sa mga vitreous cells?
# a) Mas marami ang vitreous cells sa matatanda kumpara sa isang embryo.
# b) Karamihan sa mga cell na matatagpo sa vitreous ay lymphocytes at mature neutrophils.
# c) Sila ay sagana sa rehiyon ng vitreous base.
# d) Walang vitreous cells na matatagpo sa mga bagong panganak.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Sila ay sagana sa rehiyon ng vitreous base.
#
# The vitreous humor is a clear, gel-like substance that fills the vitreous cavity of the eye. It is composed of water, proteins, and other substances, and it plays an important role in maintaining the shape and structure of the eye. The vitreous humor is produced by cells called vitreous cells, which are found in the vitreous base, the area where the vitreous humor attaches to the retina.
#
# Option a) is incorrect because the number of vitreous cells decreases with age, not increases. Option b) is also incorrect because lymphocytes and mature neutrophils are not found in the vitreous humor. Option d) is incorrect because vitreous cells are present in the vitreous humor of newborns, although their number decreases with age.
# {'response': 'c'}
# Language: portuguese
# Question:
# Com relação às células do corpo vítreo, assinale a alternativa correta.
# a)São mais numerosos no adulto, comparativamente às do vítreo embrionário.
# b)São representadas principalmente por linfócitos e neutrófilos maduros.
# c)São abundantes na região da base vítrea.
# d)Estão ausentes no recém-nascido.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is option c) São abundantes na região da base vítrea.
#
# The cells of the vitreous body are abundant in the region of the vitreous base, which is the part of the eye where the vitreous humor is in contact with the retina. This is a characteristic feature of the vitreous body and distinguishes it from other parts of the eye.
#
# Option a) São mais numerosos no adulto, comparativamente às do vítreo embrionário is incorrect because the number of cells in the vitreous body does not change significantly during development.
#
# Option b) São representadas principalmente por linfócitos e neutrófilos maduros is incorrect because the vitreous body does not contain mature lymphocytes and neutrophils.
#
# Option d) Estão ausentes no recém-nascido is incorrect because the vitreous body is present in the newborn, although it is not fully developed at birth.
# {'response': 'c'}
# Language: english
# Question:
# Regarding the vitreous body cells, mark the correct alternative.
# a) They are more numerous in the adult than in the embryonic vitreous.
# b) They are mainly represented by lymphocytes and mature neutrophils.
# c) They are abundant in the region of the vitreous base.
# d) They are absent in the newborn.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# The correct answer is option c) They are abundant in the region of the vitreous base.
#
# According to the article "The Vitreous Body: A Review of Its Functions and Disorders" by John M. Woodcock and David G. Hwang, the vitreous body cells are indeed abundant in the region of the vitreous base, which is the part of the vitreous that is closest to the retina. The vitreous base is a specialized area that is characterized by a high concentration of cells, including fibroblasts, glial cells, and inflammatory cells.
#
# Option a) They are more numerous in the adult than in the embryonic vitreous is incorrect because the number of cells in the vitreous body decreases with age, and the embryonic vitreous contains more cells than the adult vitreous.
#
# Option b) They are mainly represented by lymphocytes and mature neutrophils is incorrect because while lymphocytes and neutrophils are present in the vitreous body, they are not the main types of cells found there.
#
# ...
# a) Chlorpromazine - iris retractors.
# b) Doxasozine - Beehler dilator.
# c) Tamsulosin - sphincterectomies.
# d) Atropine - iris expander ring.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // b) Doxasozine - Beehler dilator.
# }
# ```
#
# Explanation:
#
# Flaccid iris syndrome is a condition that occurs in the perioperative period and is characterized by a lack of mydriasis (pupil dilation) in response to usual doses of mydriatic drugs. This can make it difficult or impossible to perform certain eye surgeries.
#
# Doxasozine is a drug that has been associated with the occurrence of flaccid iris syndrome in the perioperative period. Beehler dilator is an adequate intervention to restore mydriasis in these cases.
#
# Chlorpromazine and tamsulosin have not been associated with flaccid iris syndrome, and iris retractors and sphincterectomies are not appropriate interventions to restore mydriasis. Atropine is a mydriatic drug, but it is not associated with flaccid iris syndrome, and iris expander ring is not a recognized intervention for this condition.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 163:
# Language: spanish
# Question:
# En cuanto a la prevención de endoftalmitis en cirugía de cataratas, seleccionar la alternativa correcta.
# a) En casos de contraindicación para la povidona yodada, se debe utilizar colirio antibiótico tópico durante cinco días antes del procedimiento.
# b) Los principales factores de riesgo incluyen inmunosupresión, diabetes, blefaritis, conjuntivitis, rotura de la cápsula posterior y pérdida de vítreo.
# c) Se debe adoptar el uso intracameral de gentamicina, especialmente en los casos asociados a vitrectomía previa.
# d) Los agentes etiológicos más comunes son las bacterias resultantes de una esterilización inadecuada del material quirúrgico y de las lentes intraoculares.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# La opción correcta es c) Se debe adoptar el uso intracameral de gentamicina, especialmente en los casos asociados a vitrectomía previa.
#
# La endoftalmitis es una inflamación grave y potencialmente vista amenazante que puede ocurrir después de una cirugía de cataratas. La prevención de la endoftalmitis es crucial y se han identificado varios factores de riesgo, incluyendo inmunosupresión, diabetes, blefaritis, conjuntivitis, rotura de la cápsula posterior y pérdida de vítreo.
#
# La opción a) es incorrecta ya que la povidona yodada no es un tratamiento efectivo para la prevención de la endoftalmitis. La opción b) es incorrecta ya que los principales factores de riesgo no incluyen el uso de colirio antibiótico tópico durante cinco días antes del procedimiento. La opción d) es incorrecta ya que los agentes etiológicos más comunes no son las bacterias resultantes de una esterilización inadecuada del material quirúrgico y de las lentes intraoculares.
#
# La opción c) es la correcta ya que el uso intracameral de gentamicina es una medida efectiva para prevenir la endoftalmitis, especialmente en los casos asociados a vitrectomía previa. La gentamicina es un antibiótico que se administra directamente en la cámara ocular durante el procedimiento quirúrgico y ha demostrado ser efectivo en la prevención de la endoftalmitis.
# {'response': 'c'}
# Language: tagalog
# Question:
# Alin sa mga sumusunod na pamamaraan upang mapigilan ang endophthalmitis sa operasyon sa katarata ang nagsasaad ng katotohanan?
# a) Sa mga kaso ng mga kontraindikado sa povidone-iodine, ang mga karaniwang pamatak na antibiotic ay dapat gamitin sa loob ng limang araw bago mag-opera
# b) Ang pangunahing mga kadahilanan ng peligro ay kinabibilangan ng immunosuppression, diabetes, blepharitis, conjunctivitis, pagkawasak ng posterior capsule at pagkawala ng vitreous.
# c) Ang intracameral na paggamit ng gentamicin ay inirerekomendang gawin, lalo na sa mga kaso na nauugnay sa nakaraang vitrectomy.
# d) Ang madalas na mga etilolohikal na agents ay mga mikrobyo na mula sa kakulangan sa isterilisasyon ng mga gamit pang-opera at intraocular mga lens.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The question is asking about the best way to prevent endophthalmitis in cataract surgery.
#
# Option A is incorrect because using antibiotics for five days before surgery is not a recommended practice.
#
# Option B is incorrect because immunosuppression, diabetes, blepharitis, conjunctivitis, posterior capsule rupture, and vitreous loss are not the main risk factors for endophthalmitis.
#
# Option C is correct. Intracameral gentamicin is recommended for preventing endophthalmitis, especially in cases following vitrectomy.
#
# Option D is incorrect because ethyl alcohol is not a microorganism, and it is not related to the sterilization of surgical instruments or intraocular lenses.
# {'response': 'c'}
# Language: portuguese
# Question:
# Sobre a prevenção de endoftalmite em cirurgia de catarata, assinale a alternativa correta.
# a)Em casos de contraindicação à iodopovidona, deve-se utilizar colírio de antibiótico tópico por cinco dias antes do procedimento.
# b)Os principais fatores de risco incluem imunossupressão, diabetes, blefarite, conjuntivite, rotura da cápsula posterior e perda vítrea.
# c)O uso intracameral de gentamicina deve ser adotado, principalmente nos casos associados a vitrectomia anterior.
# d)Os agentes etiológicos mais frequentes são bactérias provenientes da esterilização inadequada dos materiais cirúrgicos e lentes intraoculares.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the prevention of endophthalmitis in cataract surgery, and the correct answer is b) The main risk factors include immunosuppression, diabetes, blepharitis, conjunctivitis, posterior capsule rupture, and vitreous loss.
#
# Endophthalmitis is a serious complication of cataract surgery that can result in vision loss. The risk factors for endophthalmitis include immunosuppression, diabetes, blepharitis, conjunctivitis, posterior capsule rupture, and vitreous loss. It is important to identify and manage these risk factors to prevent the development of endophthalmitis.
#
# Option a is incorrect because iodopovidone is not a treatment for endophthalmitis, and using antibiotic eye drops for five days before the procedure is not a standard preventive measure.
#
# Option c is incorrect because while intracameral gentamicin is used in some cases of cataract surgery, it is not specifically indicated for the prevention of endophthalmitis.
#
# Option d is incorrect because while bacteria can cause endophthalmitis, the main risk factors for the development of endophthalmitis are not related to the sterilization of materials and lenses.
# {'response': 'b'}
# Language: english
# Question:
# Regarding the prevention of endophthalmitis in cataract surgery, mark the correct alternative.
# a) In cases of contraindication to povidone-iodine, topical antibiotic eye drops should be used for five days before the procedure.
# b) The main risk factors include immunosuppression, diabetes, blepharitis, conjunctivitis, rupture of the posterior capsule and vitreous loss.
# c) The intracameral use of gentamicin should be adopted, especially in cases associated with previous vitrectomy.
# d) The most frequent etiological agents are bacteria from inadequate sterilization of surgical materials and intraocular lenses.
# Test #0:
# response
#   Here's my answer:
# ```json
# {
# 	"response": "c" // c) The intracameral use of gentamicin should be adopted, especially in cases associated with previous vitrectomy.
# }
# ```
#
# Explanation:
# Endophthalmitis is a sight-threatening complication of cataract surgery that can arise from bacterial contamination during the procedure. The intracameral use of gentamicin, which is a potent antibiotic, has been shown to significantly reduce the risk of endophthalmitis, especially in cases associated with previous vitrectomy.
#
# While option a is incorrect because topical antibiotic eye drops are not effective in preventing endophthalmitis, option b is only partially correct because it lists some risk factors for endophthalmitis but does not directly address prevention. Option d is incorrect because while bacteria from inadequate sterilization of surgical materials and intraocular lenses can cause endophthalmitis, the most effective preventive measure is the intracameral use of gentamicin.
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 164:
# Language: spanish
# Question:
# Después de realizar las fracturas del núcleo con la técnica de divide y vencerás, se nota una porción blanquecina y contracción del tejido en la porción lateral de la incisión corneal, goteando solución de irrigación por el espacio formado. Entre las alternativas siguientes, ¿cuál sería eficaz para prevenir la aparición de la complicación descrita?
# a) Reducir el caudal de aspiración y realizar una incisión más estrecha.
# b) Utilice puntas de mayor diámetro y manguitos de irrigación coaxiales de menor diámetro.
# c) Mantener la punta equidistante de las paredes de la incisión y utilizar ultrasonido pulsado.
# d) Llenar la cámara anterior con viscoelástico cohesivo y utilizar ultrasonido continuo.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
# La opción c) Mantener la punta equidistante de las paredes de la incisión y utilizar ultrasonido pulsado es la más adecuada para prevenir la aparición de la complicación descrita. La técnica de divide y vencerás puede causar una lesión en la capa de epitelio pigmentario y la incisión lateral puede causar una contracción del tejido, lo que puede provocar la aparición de una porción blanquecina y goteo de solución de irrigación. La opción c) mantiene la punta de la incisión equidistante de las paredes y utiliza ultrasonido pulsado para minimizar la lesión en la capa de epitelio pigmentario y reducir la contracción del tejido, lo que puede prevenir la aparición de la complicación descrita.
# {'response': 'c'}
# Language: tagalog
# Question:
# Matapos isagawa ang core fractures gamit ang divide-and-conquer na teknik, may nakitang mamuti-mutlng bahagi at kontraksyon ng tissue sa lateral na bahagi ng corneal incision, at pagtagas ng irrigation solution sa puwang na nabuo. Alin sa mga sumusunod na pahayag ang naglalarawan ng epektibong pamamaraan upang maiwasan ang komplikasyong nabanggit?
# a) Bawasan ang aspiration flow rate at at gawing mas makitid ang paghiwa.
# b) Gumamit ng mas malapad na tipis at mas makitid na coaxial irrigation sleeves
# c) Panatilihin na equidistant ang tip mula sa incision walls at gumamit ng pulsed ultrasound.
# d) Punan ang anterior chamber ng cohesive viscoelastic na materyal at gumamit ng continuous ultrasound
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# The correct answer is option c: Panatilihin na equidistant ang tip mula sa incision walls at gumamit ng pulsed ultrasound.
#
# This answer choice suggests maintaining a consistent distance between the tip of the instrument and the incision walls, and using pulsed ultrasound to help minimize the risk of complications such as corneal perforation or irregular healing. This approach can help ensure a more controlled and precise dissection, reducing the risk of unintended tissue damage or bleeding.
#
# The other options do not accurately address the complications described in the scenario:
#
# Option a: Bawasan ang aspiration flow rate at at gawing mas makitid ang paghiwa. - This option suggests reducing the aspiration flow rate and making the incision wider, which may not directly address the issue of corneal perforation or irregular healing.
#
# Option b: Gumamit ng mas malapad na tipis at mas makitid na coaxial irrigation sleeves. - This option suggests using a longer and thicker irrigation sleeve, which may not be necessary or effective in preventing complications.
#
# Option d: Punan ang anterior chamber ng cohesive viscoelastic na materyal at gumamit ng continuous ultrasound. - This option suggests filling the anterior chamber with a cohesive viscoelastic material and using continuous ultrasound, which may not be directly related to the complications described in the scenario.
# {'response': 'c'}
# Language: portuguese
# Question:
# Após realizar as fraturas do núcleo com a técnica de dividir e conquistar, nota-se uma porção esbranquiçada e contração do tecido na porção lateral da incisão da córnea, com vazamento da solução de irrigação pelo vão formado. Entre as alternativas abaixo, qual seria eficaz em prevenir a ocorrência da complicação descrita?
# a)Reduzir a taxa de fluxo de aspiração e fazer incisão mais estreita.
# b)Usar ponteiras de maior diâmetro e luvas de irrigação coaxial de menor diâmetro.
# c)Manter a ponteira equidistante das paredes da incisão e utilizar ultrassom pulsado.
# d)Preencher a câmara anterior com viscoelástico coesivo e utilizar ultrassom contínuo.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# The correct answer is option c: Manter a ponteira equidistante das paredes da incisão e utilizar ultrassom pulsado.
#
# This complication is likely due to excessive pressure or trauma to the corneal tissue during the phacoemulsification process, which has caused edema and leakage of the irrigation solution. To prevent this complication, it is important to maintain the ponteira (phacoemulsification handpiece) at a safe distance from the walls of the incision, and to use pulsed ultrasonic energy to break up the nucleus, rather than continuous ultrasonic energy. This will help to reduce the pressure on the corneal tissue and minimize the risk of complications.
#
# Therefore, option c is the correct answer. Option a is incorrect because reducing the flow rate and making a narrower incision may not necessarily address the underlying cause of the complication. Option b is also incorrect because using larger ponteiras and coaxial irrigation sleeves may not be effective in preventing the complication. Option d is incorrect because filling the anterior chamber with viscoelastic material and using continuous ultrasonic energy may not be effective in preventing the complication, and may even exacerbate it.
# {'response': 'c'}
# Language: english
# Question:
# After performing the core fractures with the divide-and-conquer technique, a whitish portion and contraction of the tissue can be seen on the lateral portion of the corneal incision, with leakage of the irrigation solution through the gap formed. Among the alternatives below, which would be effective in preventing the occurrence of the described complication?
# a) Reduce the aspiration flow rate and make the incision narrower.
# b)Use larger diameter tips and smaller diameter coaxial irrigation sleeves.
# c) Keep the tip equidistant from the incision walls and use pulsed ultrasound.
# d) Fill the anterior chamber with cohesive viscoelastic and use continuous ultrasound.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The described complication is likely due to the leakage of irrigation solution through the gap formed between the incision walls and the tip of the phacoemulsification device. To prevent this complication, the tip should be kept equidistant from the incision walls, which can be achieved by using pulsed ultrasound. This will help to maintain a consistent distance between the tip and the incision walls, reducing the risk of leakage.
#
# Therefore, option C is the correct answer.
#
# Option A is incorrect because reducing the aspiration flow rate and making the incision narrower may not necessarily prevent the leakage of irrigation solution.
#
# Option B is incorrect because using larger diameter tips and smaller diameter coaxial irrigation sleeves may not effectively address the issue of leakage.
#
# Option D is incorrect because filling the anterior chamber with cohesive viscoelastic and using continuous ultrasound may not provide adequate support to prevent leakage during phacoemulsification.
# {'response': 'c'}
# **************************************************

# %% [markdown]
# #### See the results

# %%
import os
MODEL = os.path.basename(MODEL)

if N_REPETITIONS > 1:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}_{N_REPETITIONS}Repetitions.csv")
else:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}.csv")

df
# Out:
#       ID  year        test                theme subtheme  \
# 0      1  2022   Teórica I             Anatomia   cornea
# 1      2  2022   Teórica I             Anatomia   retina
# 2      3  2022   Teórica I             Anatomia   cornea
# 3      4  2022   Teórica I             Anatomia   cornea
# 4      5  2022   Teórica I             Anatomia   cornea
# ..   ...   ...         ...                  ...      ...
# 159  161  2022  Teórica II  Cristalino/Catarata      NaN
# 160  162  2022  Teórica II  Cristalino/Catarata      NaN
# 161  163  2022  Teórica II  Cristalino/Catarata      NaN
# 162  164  2022  Teórica II  Cristalino/Catarata      NaN
# 163  165  2022  Teórica II  Cristalino/Catarata      NaN
#
#                                             portuguese  \
# 0    Em qual região ocular células caliciformes são...
# 1    Assinale a alternativa que melhor correlaciona...
# 2    Ordene as três denominações celulares encontra...
# 3    Sobre a membrana de Descemet da córnea, é corr...
# 4    Sobre a camada lipídica do filme lacrimal, ass...
# ..                                                 ...
# 159  Após bloqueio retrobulbar para realização de c...
# 160  Sobre a biometria em olhos tamponados por óleo...
# 161  Assinale a alternativa que contém, respectivam...
# 162  Sobre a prevenção de endoftalmite em cirurgia ...
# 163  Após realizar as fraturas do núcleo com a técn...
#
#                                                spanish  \
# 0    ¿En qué región ocular se encuentran fisiológic...
# 1    Marque la alternativa que mejor correlaciona l...
# 2    Ordene los tres nombres de células que se encu...
# 3    Con respecto a la membrana de la córnea de Des...
# 4    Respecto a la capa lipídica de la película lag...
# ..                                                 ...
# 159  Tras el bloqueo retrobulbar para realizar la c...
# 160  Respecto a la biometría en ojos tamponados con...
# 161  Seleccionar la alternativa que contenga, respe...
# 162  En cuanto a la prevención de endoftalmitis en ...
# 163  Después de realizar las fracturas del núcleo c...
#
#                                                english  \
# 0    In which ocular region are caliciform cells ph...
# 1    Mark the alternative that best correlates the ...
# 2    Order the three cell names found in the cornea...
# 3    Regarding Descemet's membrane of the cornea, i...
# 4    About the lipidic layer of the lacrimal film, ...
# ..                                                 ...
# 159  After retrobulbar block for phacoemulsificatio...
# 160  Regarding biometrics in eyes covered with sili...
# 161  Check the alternative that contains, respectiv...
# 162  Regarding the prevention of endophthalmitis in...
# 163  After performing the core fractures with the d...
#
#                                                tagalog answer  \
# 0    Aling bahagi ng mata ay kung saan matatagpuan ...      D
# 1    Ipagpares ang bahagi ng retina sa Hanay B sa t...      B
# 2    Ipagsunud-sunod ang mga cells ng corneal epith...      A
# 3    Tama tungkol sa Descemet's membrane ng cornea:...      C
# 4    Piliin ang tamang sagot tungkol sa lipid layer...      B
# ..                                                 ...    ...
# 159  Matapos ang retrobulbar block para sa phacoemu...      C
# 160  Alin sa mga sumusunod na pahayag patungkol sa ...      D
# 161  Alin sa mga sumusunod na tambalan patungkol sa...      A
# 162  Alin sa mga sumusunod na pamamaraan upang mapi...      B
# 163  Matapos isagawa ang core fractures gamit ang d...      C
#
#            responses_spanish      responses_spanish_0  \
# 0                          b                        b
# 1                          b                        b
# 2    b) Alada, basal, plana.  b) Alada, basal, plana.
# 3                          b                        b
# 4                          b                        b
# ..                       ...                      ...
# 159                        c                        c
# 160                        a                        a
# 161                        a                        a
# 162                        c                        c
# 163                        c                        c
#
#                   responses_tagalog             responses_tagalog_0  \
# 0                                 b                               b
# 1    c) I: B; II: A; III: C; IV: C.  c) I: B; II: A; III: C; IV: C.
# 2             b) Wing, basal, flat.           b) Wing, basal, flat.
# 3                                 b                               b
# 4                                 c                               c
# ..                              ...                             ...
# 159                               d                               d
# 160                               c                               c
# 161                               b                               b
# 162                               c                               c
# 163                               c                               c
#
#     responses_portuguese responses_portuguese_0      responses_english  \
# 0                      b                      b                      b
# 1                      b                      b                      b
# 2                      b                      b  c) Basal, flat, wing.
# 3                      b                      b                      b
# 4                      b                      b                      b
# ..                   ...                    ...                    ...
# 159                    c                      c                      c
# 160                    a                      a                      a
# 161                    b                      b                      b
# 162                    b                      b                      c
# 163                    c                      c                      c
#
#        responses_english_0
# 0                        b
# 1                        b
# 2    c) Basal, flat, wing.
# 3                        b
# 4                        b
# ..                     ...
# 159                      c
# 160                      a
# 161                      b
# 162                      c
# 163                      c
#
# [164 rows x 18 columns]

# %% [markdown]
# ### Data Analysis

# %%
TEMPERATURE = str(TEMPERATURE).replace('.', '_')

run_analysis(model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, languages=LANGUAGES)
# Out:
# n_repetitions should be a positive integer, not 0
# n_repetitions will be set to 1
# /Users/davidrestrepo/LLMs Bias/Language/src/data_analysis.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(languages, fontsize=16)
#      theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  anatomy              5              4                 4              6
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     21                 23.809524                 19.047619
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    19.047619                 28.571429
#     theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  cornea              4              2                 4              4
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     10                      40.0                      20.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         40.0                      40.0
#         theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  embryology              1              1                 1              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      2                      50.0                      50.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         50.0                      50.0
#       theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  genetics              0              0                 0              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      2                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                      50.0
#       theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  glaucoma              3              2                 2              3
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      9                 33.333333                 22.222222
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    22.222222                 33.333333
#       theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  oncology              1              0                 0              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      1                     100.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                     100.0
#           theme  match_spanish  match_tagalog  match_portuguese  \
# 0  pharmacology              3              2                 3
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              4      9                 33.333333                 22.222222
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    33.333333                 44.444444
#         theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  refraction              9              9                 7              9
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     31                 29.032258                 29.032258
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    22.580645                 29.032258
#     theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  retina              5              4                 4              4
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     12                 41.666667                 33.333333
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    33.333333                 33.333333
#             theme  match_spanish  match_tagalog  match_portuguese  \
# 0  contact lenses              1              0                 1
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              1      3                 33.333333                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    33.333333                 33.333333
#     theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  cornea              4              2                 4              4
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     10                      40.0                      20.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         40.0                      40.0
#          theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  cornea/lens              1              1                 1              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      1                     100.0                     100.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                        100.0                     100.0
#       theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  glaucoma              3              2                 2              3
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      9                 33.333333                 22.222222
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    22.222222                 33.333333
#               theme  match_spanish  match_tagalog  match_portuguese  \
# 0  glaucoma/uveitis              0              0                 0
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              0      1                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                       0.0
#            theme  match_spanish  match_tagalog  match_portuguese  \
# 0  lens/cataract              5              3                 5
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              3      8                      62.5                      37.5
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         62.5                      37.5
#         theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  low vision              1              1                 1              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      1                     100.0                     100.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                        100.0                     100.0
#                  theme  match_spanish  match_tagalog  match_portuguese  \
# 0  neuro-ophthalmology              3              3                 3
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              4      7                 42.857143                 42.857143
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    42.857143                 57.142857
#                     theme  match_spanish  match_tagalog  match_portuguese  \
# 0  ocular plastic surgery              4              3                 5
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              4     16                      25.0                     18.75
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                        31.25                      25.0
#                              theme  match_spanish  match_tagalog  \
# 0  oncology/ocular plastic surgery              1              0
#
#    match_portuguese  match_english  Total  spanish_ratio_percentage  \
# 0                 0              1      3                 33.333333
#
#    tagalog_ratio_percentage  portuguese_ratio_percentage  \
# 0                       0.0                          0.0
#
#    english_ratio_percentage
# 0                 33.333333
#     theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  optics              0              0                 0              0
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      1                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                       0.0
#                theme  match_spanish  match_tagalog  match_portuguese  \
# 0  optics/refraction              0              1                 0
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              0      1                       0.0                     100.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                       0.0
#           theme  match_spanish  match_tagalog  match_portuguese  \
# 0  pharmacology              3              2                 3
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              4      9                 33.333333                 22.222222
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    33.333333                 44.444444
#                    theme  match_spanish  match_tagalog  match_portuguese  \
# 0  pharmacology/glaucoma              0              0                 1
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              1      1                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                        100.0                     100.0
#         theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  refraction              9              9                 7              9
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     31                 29.032258                 29.032258
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    22.580645                 29.032258
#                    theme  match_spanish  match_tagalog  match_portuguese  \
# 0  refraction/low vision              0              0                 0
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              0      2                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                       0.0
#                 theme  match_spanish  match_tagalog  match_portuguese  \
# 0  refractive surgery              1              1                 1
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              1      2                      50.0                      50.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         50.0                      50.0
#     theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  retina              5              4                 4              4
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     12                 41.666667                 33.333333
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    33.333333                 33.333333
#              theme  match_spanish  match_tagalog  match_portuguese  \
# 0  retina/oncology              0              0                 0
#
#    match_english  Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0              0      1                       0.0                       0.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                          0.0                       0.0
#         theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  strabismus              4              4                 3              4
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0     11                 36.363636                 36.363636
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                    27.272727                 36.363636
#      theme  match_spanish  match_tagalog  match_portuguese  match_english  \
# 0  uveitis              2              2                 3              1
#
#    Total  spanish_ratio_percentage  tagalog_ratio_percentage  \
# 0      8                      25.0                      25.0
#
#    portuguese_ratio_percentage  english_ratio_percentage
# 0                         37.5                      12.5

# %%
N_REPETITIONS = 1 if N_REPETITIONS < 1 else N_REPETITIONS
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv')
# Out:
#           test  year                            theme  match_spanish  \
# 0    Teórica I  2022                          anatomy              5
# 1    Teórica I  2022                           cornea              0
# 2    Teórica I  2022                       embryology              1
# 3    Teórica I  2022                         genetics              0
# 4    Teórica I  2022                         glaucoma              1
# 5    Teórica I  2022                         oncology              1
# 6    Teórica I  2022                     pharmacology              2
# 7    Teórica I  2022                       refraction              3
# 8    Teórica I  2022                           retina              0
# 9   Teórica II  2022                   contact lenses              1
# 10  Teórica II  2022                           cornea              4
# 11  Teórica II  2022                      cornea/lens              1
# 12  Teórica II  2022                         glaucoma              2
# 13  Teórica II  2022                 glaucoma/uveitis              0
# 14  Teórica II  2022                    lens/cataract              5
# 15  Teórica II  2022                       low vision              1
# 16  Teórica II  2022              neuro-ophthalmology              3
# 17  Teórica II  2022           ocular plastic surgery              4
# 18  Teórica II  2022  oncology/ocular plastic surgery              1
# 19  Teórica II  2022                           optics              0
# 20  Teórica II  2022                optics/refraction              0
# 21  Teórica II  2022                     pharmacology              1
# 22  Teórica II  2022            pharmacology/glaucoma              0
# 23  Teórica II  2022                       refraction              6
# 24  Teórica II  2022            refraction/low vision              0
# 25  Teórica II  2022               refractive surgery              1
# 26  Teórica II  2022                           retina              5
# 27  Teórica II  2022                  retina/oncology              0
# 28  Teórica II  2022                       strabismus              4
# 29  Teórica II  2022                          uveitis              2
#
#     match_tagalog  match_portuguese  match_english  Total
# 0               4                 4              6     21
# 1               0                 1              1      1
# 2               1                 1              1      2
# 3               0                 0              1      2
# 4               0                 0              0      1
# 5               0                 0              1      1
# 6               1                 2              2      3
# 7               5                 3              4     12
# 8               0                 0              0      1
# 9               0                 1              1      3
# 10              2                 3              3      9
# 11              1                 1              1      1
# 12              2                 2              3      8
# 13              0                 0              0      1
# 14              3                 5              3      8
# 15              1                 1              1      1
# 16              3                 3              4      7
# 17              3                 5              4     16
# 18              0                 0              1      3
# 19              0                 0              0      1
# 20              1                 0              0      1
# 21              1                 1              2      6
# 22              0                 1              1      1
# 23              4                 4              5     19
# 24              0                 0              0      2
# 25              1                 1              1      2
# 26              4                 4              4     11
# 27              0                 0              0      1
# 28              4                 3              4     11
# 29              2                 3              1      8

# %%
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv').sum()
# Out:
# test                Teórica ITeórica ITeórica ITeórica ITeórica IT...
# year                                                            60660
# theme               anatomycorneaembryologygeneticsglaucomaoncolog...
# match_spanish                                                      54
# match_tagalog                                                      43
# match_portuguese                                                   49
# match_english                                                      55
# Total                                                             164
# dtype: object
