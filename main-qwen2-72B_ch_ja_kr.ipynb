# %% [markdown]
# # Evaluate Classification

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Load the API key and libaries.

# %%
from src.Language_Evaluation_LC import llm_language_evaluation
from src.data_analysis import run_analysis
import pandas as pd

# %% [markdown]
# #### Load the Constants

# %%
PATH = 'data/full_dataset_translated.csv'
MODEL = "Qwen/Qwen2-72B-Instruct"
TEMPERATURE = 0.0
N_REPETITIONS = 0
REASONING = False
LANGUAGES = ['chinese', 'japanese', 'korean']
# Full:
#LANGUAGES = ['spanish', 'tagalog', 'portuguese', 'english', 'chinese', 'japanese', 'korean', 'hindi', 'french']

# %% [markdown]
# #### Run The Experiments:

# %%
# Run evaluation:
llm_language_evaluation(path=PATH, model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, reasoning=REASONING, languages=LANGUAGES)
# Out:
# N_REPETITIONS should be a positive integer, not 0
# N_REPETITIONS will be set to 1
# **************************************************
# Question 1:
# Language: chinese
# Question:
# 在哪个眼部区域生理上可以找到杯状细胞？
# a) 角膜。
# b) 角膜巩膜缘。
# c) 灰线。
# d) 半月襞。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# カリシフォルム細胞は生理的にどの眼部に存在しますか？
# a) 角膜。
# b) 角膜強膜辺縁。
# c) グレーライン。
# d) 半月襞。
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# Language: korean
# Question:
# 어느 눈 부위에서 goblet 세포가 생리적으로 발견됩니까?
# a) 각막.
# b) 각막경계.
# c) 회색선.
# d) 반월상 접힘.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 2:
# Language: chinese
# Question:
# 将以下选项与相应的眼部组织的组织学特征进行匹配：
#
# I. 由连接复合体紧密连接在一起的单层细胞。
# II. 在光学显微镜下观察到的平行且规则的条纹，垂直于上皮。
# III. 包含双极细胞、无轴突细胞、水平细胞和穆勒细胞。
# IV. 包含大细胞、小细胞和锥体细胞。
#
# A. 光感受器。
# B. 视网膜色素上皮。
# C. 视网膜神经节层。
# D. 内核层。
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# Language: japanese
# Question:
# 以下の選択肢の中から、組織学的特徴とそれに対応する眼の組織を最もよく関連付けるものを選びなさい。
#
# I. 細胞間複合体によって密接に結合された単層の細胞。
# II. 光学顕微鏡下で観察される、上皮に垂直な平行で規則的な縞模様。
# III. 双極細胞、アマクリン細胞、水平細胞、ミュラー細胞を含む。
# IV. 大細胞、小細胞、コニオ細胞を含む。
#
# A. 光受容体。
# B. 網膜色素上皮。
# C. 網膜神経節層。
# D. 内核層。
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# Language: korean
# Question:
# 조직학적 특성과 해당 안구 조직을 가장 잘 연관시키는 선택지를 표시하시오:
#
# I. 결합 복합체로 긴밀하게 연결된 단층 세포.
# II. 광학 현미경으로 관찰 시, 상피에 수직으로 나타나는 평행하고 규칙적인 줄무늬.
# III. 양극 세포, 아마크린 세포, 수평 세피, 뮐러 세포가 포함되어 있음.
# IV. 대세포, 소세포, 콘세포가 포함되어 있음.
#
# A. 광수용체.
# B. 망막 색소 상피.
# C. 망막 신경절층.
# D. 내핵층.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 3:
# Language: chinese
# Question:
# 将角膜上皮中发现的三种细胞名称按顺序排列，从最表层的开始，然后是中间层，最后是深层。
# a) 扁平细胞、翼状细胞、基底细胞。
# b) 翼状细胞、基底细胞、扁平细胞。
# c) 基底细胞、扁平细胞、翼状细胞。
# d) 翼状细胞、扁平细胞、基底细胞。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 角膜上皮に見られる3つの細胞名を、最も表面的なものから始めて、中間のもの、深いものの順に並べてください。
# a) 扁平、翼状、基底。
# b) 翼状、基底、扁平。
# c) 基底、扁平、翼状。
# d) 翼状、扁平、基底。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 각막 상피에서 발견되는 세 가지 세포 이름을 가장 표면적인 것부터 시작하여 중간, 깊은 순으로 배열하십시오.
# a) 편평, 날개, 기저.
# b) 날개, 기저, 편평.
# c) 기저, 편평, 날개.
# d) 날개, 편평, 기저.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 4:
# Language: chinese
# Question:
# 关于角膜的Descemet膜，以下说法正确的是：
# a) 内皮细胞不参与其形成。
# b) 成人的厚度约为30微米。
# c) 其最前部分来源于胚胎。
# d) 随着年龄的增长，其厚度会减少。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 角膜のデスメ膜について、以下の記述が正しいと言えます：
# a) 内皮細胞はその形成に関与していません。
# b) 成人の厚さは約30µmです。
# c) 最も前方の部分は胚性起源です。
# d) 厚さは年齢とともに減少します。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 각막의 데스메막에 관하여 다음과 같이 말할 수 있습니다:
# a) 내피세포는 그 형성에 참여하지 않습니다.
# b) 성인에서의 두께는 약 30µm입니다.
# c) 가장 앞부분은 배아기 기원입니다.
# d) 나이가 들면서 두께가 줄어듭니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 5:
# Language: chinese
# Question:
# 关于泪膜的脂质层，请选择正确的答案。
# a) 其目的是稳定由睑板腺和Manz腺分泌的泪膜。
# b) 其成分中包含胆固醇酯，其功能之一是延缓泪膜的蒸发。
# c) 在睑板腺功能障碍时，熔点降低，导致滞留。
# d) 可通过泪膜破裂时间来评估，健康眼睛中保持完整时间不少于五秒钟。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 涙膜の脂質層について、正しい答えを選んでください。
# a) その目的は、マイボーム腺とマンツ腺によって分泌される涙膜を安定させることです。
# b) コレステロールエステルが成分の一部であり、その機能の一つは涙膜の蒸発を遅らせることです。
# c) マイボーム腺機能不全では、融点が低下し、滞留を引き起こします。
# d) 涙膜破断時間によって評価され、健康な目では5秒未満で完全に保たれます。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 눈물막의 지질층에 대해 올바른 답을 선택하십시오.
# a) 그 목적은 마이봄샘과 만즈샘에서 분비된 눈물막을 안정화하는 것입니다.
# b) 그 구성 요소 중에는 콜레스테롤 에스테르가 포함되어 있으며, 그 기능 중 하나는 눈물막의 증발을 지연시키는 것입니다.
# c) 마이봄샘 기능 장애에서는 융점이 감소하여 정체를 초래합니다.
# d) 눈물막 분리 시간을 통해 평가할 수 있으며, 건강한 눈에서는 5초 미만으로 유지됩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 6:
# Language: chinese
# Question:
# 关于外眼肌，请选择正确答案。
# a) 在赫林定律中，给定眼球运动的神经支配均匀分布于拮抗肌和对抗肌。
# b) 追视运动会随着注视点的移动而自动缓慢发生。
# c) 在谢林顿定律中，刺激收缩分布在两眼的主动肌之间，以便对称发生。
# d) 眼球跳动运动以突然、无协调、反射性动作为特征。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 眼外筋に関して、正しい答えを選んでください。
# a) ヘリングの法則では、特定の眼球運動において、神経支配はアゴニストとアンタゴニストの筋肉に均等に分配されます。
# b) 追従運動は、固視点の移動に伴い、自動的にゆっくりと発生します。
# c) シェリントンの法則では、両眼のアゴニストに対する収縮刺激が分配され、それによって対称的に発生します。
# d) 瞬目運動は、突然の、非調整の、反射的な動きによって特徴づけられます。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 외안근에 관하여 올바른 답을 고르시오.
# a) 헤링의 법칙에서는 주어진 안구운동에 대해 작용근과 길항근에 신경 자극이 동등하게 분배됩니다.
# b) 추적 운동은 고정점의 이동에 따라 자동적으로, 천천히 일어납니다.
# c) 셔링턴의 법칙에서는 양쪽 눈의 작용근에 자극이 분배되어 대칭적으로 일어납니다.
# d) 돌발적인 움직임은 갑작스럽고, 조정되지 않은, 반사적인 움직임으로 특징지어집니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 7:
# Language: chinese
# Question:
# 关于角膜，以下说法正确的是：
# a) 角膜胶原纤维的排列与其透明度无关。
# b) 内皮细胞的多形性以这些细胞大小的变异为特征。
# c) 前基质含有大量线粒体，负责产生供应内皮泵的能量。
# d) 内皮层表现为房水和实质之间的非选择性渗透屏障。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 角膜について、以下の記述が正しいと言えます。
# a) 角膜コラーゲン線維の配列はその透明性とは関係がありません。
# b) 内皮細胞の多形性は、これらの細胞のサイズの変化によって特徴づけられます。
# c) 前部ストローマには多くのミトコンドリアがあり、内皮ポンプに供給されるエネルギーの生成に責任があります。
# d) 内皮は、房水と実質本体の間で選択性のない透過性のバリアとして振る舞います。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 각막에 대해 올바르게 진술한 것은 다음과 같습니다.
# a) 각막 콜라겐 섬유의 배열은 그 투명성과 관련이 없습니다.
# b) 내피세포의 다형성은 이 세포들의 크기 변화를 특징으로 합니다.
# c) 전방 기질은 많은 수의 미토콘드리아를 가지고 있으며, 이는 내피 펌프에 에너지를 공급하는 데 필요한 에너지를 생산하는 데 책임이 있습니다.
# d) 내피는 방수체와 실질 사이에서 선택적이지 않은 투과성 장벽으로 작용합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 8:
# Language: chinese
# Question:
# 选择正确填补空缺的选项。左旋转对应于右眼的__________和左眼的__________，当头部向___肩膀倾斜时会触发。
# a) 外旋 / 内旋 / 左
# b) 内旋 / 外旋 / 左
# c) 外旋 / 内旋 / 右
# d) 内旋 / 外旋 / 右
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# Language: japanese
# Question:
# 正しい選択肢を選び、空欄を埋めてください。Levocycloversionは右目の__________と左目の__________に対応し、頭が___肩に傾いたときに引き起こされます。
# a) Excicloduction / incicloduction / 左
# b) Incicloduction / excicloduction / 左
# c) Excicloduction / incicloduction / 右
# d) Incicloduction / excicloduction / 右
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 다음 빈칸을 올바르게 채우는 대안을 선택하십시오. Levocycloversion은 오른쪽 눈의 ____________과 왼쪽 눈의 ____________에 해당하며, 머리가 ___ 어깨 쪽으로 기울어질 때 발생합니다.
# a) Excicloduction / incicloduction / 왼쪽.
# b) Incicloduction / excicloduction / 왼쪽.
# c) Excicloduction / incicloduction / 오른쪽.
# d) Incicloduction / excicloduction / 오른쪽.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 9:
# Language: chinese
# Question:
# 关于玻璃体细胞，请标记正确的选项。
# a) 成人的玻璃体细胞比胚胎玻璃体中的更多。
# b) 它们主要由淋巴细胞和成熟的中性粒细胞组成。
# c) 它们在玻璃体基底区域丰富。
# d) 新生儿中不存在这些细胞。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 硝子体細胞に関して、正しい選択肢をマークしてください。
# a) 成人の硝子体において、胚生期の硝子体よりも多く存在します。
# b) 主にリンパ球と成熟した好中球で表されます。
# c) 硝子体基部の領域に豊富に存在します。
# d) 新生児には存在しません。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 유리체 세포에 관한 다음 문장 중 올바른 것을 표시하시오.
# a) 성인의 유리체에서는 배아기 유리체보다 더 많다.
# b) 주로 림프구와 성숙한 호중구로 대표된다.
# c) 유리체 기저부 지역에서 풍부하다.
# d) 신생아에게서는 존재하지 않는다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 10:
# Language: chinese
# Question:
# 关于眼肌的生理学，请标出正确的选项。
# a) 肌肉收缩与钙的可用性无关。
# b) 肌肉纤维是一种多核细胞。
# c) 每次肌肉收缩都是由一次独特的肌动蛋白-肌球蛋白桥的形成和破坏过程引起的。
# d) 肌肉松弛主要依赖于钠的可用性。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 眼球運動筋の生理に関して、正しい選択肢をマークしてください。
# a) 筋収縮はカルシウムの可用性とは無関係です。
# b) 筋繊維は多核細胞です。
# c) 各筋収縮はアクチン・ミオシンブリッジの形成と破壊のユニークなサイクルの結果です。
# d) 筋弛緩は主にナトリウムの可用性に依存します。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 안구 운동 근육의 생리학과 관련하여 올바른 대안을 표시하십시오.
# a) 근육 수축은 칼슘의 유무와 독립적입니다.
# b) 근섬유는 다핵 세포입니다.
# c) 각 근육 수축은 액틴-미오신 브리지의 형성과 파괴의 유일한 주기의 결과입니다.
# d) 근육 이완은 주로 나트륨의 유무에 의존합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 11:
# Language: chinese
# Question:
# 关于晶状体，请标记正确的选项。
# a) 尽管其体积随年龄增长而增加，但其重量保持不变。
# b) 其纤维的蛋白水解是其细胞生长的主要机制。
# c) 其蛋白质的合成发生在细胞分化为纤维的过程中。
# d) 其蛋白质合成在整个生命过程中持续进行，从儿童时期到老年保持稳定的可塑性和弹性。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# レンズに関して、正しい選択肢をマークしてください。
# a) 年齢とともに体積は増加するが、重量は一定である。
# b) 繊維のプロテオリシスがその細胞成長の主なメカニズムである。
# c) そのタンパク質の合成は、細胞が繊維に分化する際に行われる。
# d) そのタンパク質合成は一生を通じて継続し、幼少期から老化に至るまで安定した可塑性と弾力性を維持する。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 렌즈와 관련하여 올바른 대안을 표시하십시오.
# a) 나이가 들어감에 따라 부피는 증가하지만, 무게는 일정하게 유지됩니다.
# b) 섬유의 단백질 분해는 세포 성장의 주요 메커니즘입니다.
# c) 세포가 섬유로 분화하는 동안 그 단백질의 합성이 일어납니다.
# d) 그 단백질 합성은 평생 동안 지속되어 어린 시절부터 노화에 이르기까지 안정적인 유연성과 탄력성을 유지합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 12:
# Language: chinese
# Question:
# 一位患有关节病的患者多年来一直使用大剂量的氯喹。人们认为这种药物可能会导致视网膜色素上皮功能障碍，因为：
# a) 它阻碍了黑色素的合成。
# b) 它阻碍了光感受器外段盘片的吞噬作用。
# c) 它阻碍了细胞内离子的运输。
# d) 它促进了光感受器与脉络膜之间的强烈热交换。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 関節症の患者が何年もの間、高用量のクロロキンを使用しています。この薬は網膜色素上皮の機能不全を引き起こすと考えられています。その理由は以下の通りです：
# a) メラニンの合成を妨げる。
# b) 光受容体外節のディスクの貪食を妨げる。
# c) 細胞内イオンの輸送を妨げる。
# d) 光受容体と脈絡膜間の激しい熱交換を促進する。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 관절염 환자가 수년간 고용량의 클로로퀸을 사용해 왔습니다. 이 약물이 망막 색소 상피의 기능 장애를 일으킬 수 있다고 믿어집니다. 왜냐하면:
# a) 멜라닌의 합성을 방해합니다.
# b) 광수용체 외부 부분의 디스크의 식균작용을 방해합니다.
# c) 세포 내 이온의 이동을 방해합니다.
# d) 광수용체와 맥락막 사이의 강렬한 열 교환을 촉진합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 13:
# Language: chinese
# Question:
# 关于脉络膜中的血流，可以说：
# a) 它负责视网膜的全部营养供应。
# b) 它负责视网膜内层消耗的95%的葡萄糖。
# c) 参与光感受器的热调节。
# d) 前毛细血管括约肌防止血液在如黄斑等重要区域的过度流动。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 網膜の脈絡膜における血流について、以下のように述べることができます：
# a) 網膜のすべての栄養を担当しています。
# b) 網膜の内側部分で消費されるグルコースの95％を担当しています。
# c) 光受容体の熱調節に関与しています。
# d) 前毛細血管括約筋は、黄斑などの貴重な領域での血流の過剰流を防ぎます。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 맥락막의 혈류에 관하여 다음과 같이 말할 수 있습니다:
# a) 망막의 모든 영양을 담당합니다.
# b) 망막 내부에서 소비되는 포도당의 95%를 담당합니다.
# c) 광수용체의 온도 조절에 참여합니다.
# d) 전모세포 괄약근은 황반과 같은 귀중한 부위에서 혈류의 과다를 방지합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 14:
# Language: chinese
# Question:
# 关于脉络膜胚胎学，以下说法正确的是：
# a) 首先形成的是脉络膜毛细血管层，随后形成大血管。
# b) 基底膜形成布鲁氏膜，位于脉络膜毛细血管层和萨特勒层之间。
# c) 中间血管层是最后形成的，从睫状体向赤道发展。
# d) 脉络膜基质主要由中胚层细胞产生。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 網膜の胚生に関して、以下の記述が正しいと言えます：
# a) 脈絡膜毛細血管網が最初に形成され、その後に大血管が形成されます。
# b) 基底膜がブルッヒ膜を起源とし、脈絡膜毛細血管網とザットラー層の間に位置します。
# c) 中間血管層は最後に形成され、毛様体から赤道方向へ発達します。
# d) 脈絡膜間質は主に中胚葉細胞から生成されます。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 맥락막의 발생학에 관하여 다음과 같이 말하는 것이 옳습니다:
# a) 맥락망막은 가장 먼저 형성되며, 그 후에 큰 혈관들이 형성됩니다.
# b) 기저막은 브루흐막을 형성하며, 이는 맥락망막과 잣틀러층 사이에 위치합니다.
# c) 중간 혈관층은 마지막으로 형성되며, 섬모체에서 적도 방향으로 발달합니다.
# d) 맥락막 기질은 주로 중배엽 세포에서 생성됩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 15:
# Language: chinese
# Question:
# 关于眼部胚胎学，以下说法是正确的：
# a) 角膜上皮来源于神经嵴细胞。
# b) 出生时，角膜和巩膜具有相同的曲率半径。
# c) 鲍曼层在怀孕的第一至第二个月之间出现。
# d) 角膜由表面外胚层和神经嵴细胞发育而来。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 眼の発生学に関して、以下の記述が正しいと言えます：
# a) 角膜上皮は神経堤細胞から生じる。
# b) 出生時、角膜と強膜は同じ曲率半径を持つ。
# c) ボウマン膜は妊娠初期から2ヶ月目の間に現れる。
# d) 角膜は外胚葉表面と神経堤細胞から発達する。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 눈의 발생학에 관하여 다음과 같이 말할 수 있습니다:
# a) 각막 상피는 신경 외배엽 세포에서 발생합니다.
# b) 출생 시, 각막과 공막은 같은 곡률 반경을 가집니다.
# c) 보우만층은 임신 첫 달과 두 번째 달 사이에 나타납니다.
# d) 각막은 외배엽 표면과 신경 외배엽 세포에서 발달합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 16:
# Language: chinese
# Question:
# 关于常染色体显性遗传病，以下说法正确的是：
# a) 通常在多次妊娠中观察到这些疾病。
# b) 男性往往比女性受影响更严重。
# c) 同一家庭中受影响的人患病的严重程度总是相同的。
# d) 只有女性传递突变。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# However, the correct answer is not listed in the options provided. For autosomal dominant diseases, it is not necessarily true that they are observed in multiple pregnancies (A), that males are always more severely affected than females (B), or that the severity of the disease is always the same in affected individuals within the same family (C). Option (D) is also incorrect, as both males and females can pass on the mutation. The correct statement about autosomal dominant diseases is that only one copy of the mutated gene is required for an individual to be affected. If you need a correct answer in the given format, it would be:
#
# ```json
# {
# 	"response": "None of the above"
# }
# ```
# {'response': 'b'}
# Language: japanese
# Question:
# 次の自動優性遺伝病について、正しいのは以下のどれですか：
# a) 一般的に、複数の妊娠で観察されます。
# b) 男性は女性よりも影響を受けやすい傾向があります。
# c) 同じ家族の影響を受けた人々の間で病気の重症度は常に同じです。
# d) 突然変異は女性のみが伝えます。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 자가 열성 유전 질환에 대해 다음과 같이 말할 수 있습니다:
# a) 일반적으로 여러 임신에서 관찰됩니다.
# b) 남성이 여성보다 더 많이 영향을 받는 경향이 있습니다.
# c) 같은 가족의 영향을 받은 사람들 사이에서 질병의 심각성이 항상 같습니다.
# d) 돌연변이는 오직 여성만이 전달합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 17:
# Language: chinese
# Question:
# 关于线粒体遗传病，以下说法正确的是：
# b) 遗传只通过母系进行。
# d) 莱伯遗传性视神经病变是一种与线粒体DNA相关的疾病，它通常导致先天性失明，并且在不同性别的患者中以相同的比例发生。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# ミトコンドリア遺伝病に関して、以下の記述が正しいと言えます：
# a) ダルトン症はミトコンドリアDNAに関連した病気の一例です。→ 不正解
# b) 遺伝は母系を通じてのみ起こります。→ 正解
# c) 病気に影響を受けた男性患者は、すべての子孫に表現型を伝えます。→ 不正解
# d) レーバー遺伝性視神経症はミトコンドリアDNAに関連した病気の一例で、通常は先天性の盲目を引き起こし、両性に同じ割合で影響を与えます。→ 正解
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'b'}
# Language: korean
# Question:
# 미토콘드리아 유전 질환에 관해서는 다음과 같이 말할 수 있습니다:
# a) 색맹은 미토콘드리아 DNA와 관련된 질환이라고 말하는 것은 옳지 않습니다.
# b) 유전은 모계를 통해서만 일어납니다.
# c) 질병에 영향을 받은 남성 환자는 모든 자녀에게 표현형을 전달하지 않습니다.
# d) 레버 유전성 시신경병증은 미토콘드리아 DNA와 관련된 질환의 예로, 보통 선천적 실명을 일으키며 두 성별의 환자에게 같은 비율로 영향을 미칩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 18:
# Language: chinese
# Question:
# 以下哪个镜片最能有效矫正简单近视散光？
# a) -3.00 球面屈光度 +1.00 柱面屈光度 X 90°。
# b) +1.00 球面屈光度 -1.00 柱面屈光度 X 90°。
# c) -3.00 球面屈光度 +3.00 柱面屈光度 X 180°。
# d) 0.00 球面屈光度 +1.00 柱面屈光度 X 180°。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 以下のレンズのうち、単純近視性乱視を最もよく矯正するのはどれですか？
# a) -3.00 球面ジオプター + 1.00 円柱ジオプター X 90°。
# b) +1.00 球面ジオプター -1.00 円柱ジオプター X 90°。
# c) -3.00 球面ジオプター + 3.00 円柱ジオプター X 180°。
# d) 0.00 球面ジオプター +1.00 円柱ジオプター X 180°。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 아래 렌즈 중 단순 근시 난시를 가장 잘 교정하는 것은 무엇입니까?
# a) -3.00 구면 디옵터 + 1.00 원통 디옵터 X 90°.
# b) +1.00 구면 디옵터 -1.00 원통 디옵터 X 90°.
# c) -3.00 구면 디옵터 + 3.00 원통 디옵터 X 180°.
# d) 0.00 구면 디옵터 +1.00 원통 디옵터 X 180°.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 19:
# Language: chinese
# Question:
# 这个问题涉及的是斯图姆锥面上最小混淆圈的焦距，对于一个+1.00 OD +2.00 DC X 180°的球柱镜。选项包括：
# a) 0米。
# b) 0.5米。
# c) 1米。
# d) 2米。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# +1.00 OD +2.00 DC X 180°の球面筒状レンズのシュトゥルムの円錐体における最小混乱の円の焦点距離は何ですか？
# a) 0 m。
# b) 0.5 m。
# c) 1 m。
# d) 2 m。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 원의 최소 혼란의 초점 거리는 스트룸의 콘에서 +1.00 OD +2.00 DC X 180° 구면 원통 렌즈에 대해 얼마입니까?
# a) 0 m.
# b) 0.5 m.
# c) 1 m.
# d) 2 m.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 20:
# Language: chinese
# Question:
# 位于2米远的一个物体通过一个2焦距的凸透镜形成的像点距离透镜多远？
# a) 2.0米。
# b) 1.5米。
# c) 0.67米。
# d) 0.4米。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 2メートル離れた位置にある物体点が2ディオプターの凸レンズによってどの距離で像を形成しますか？
# a) 2.0 m
# b) 1.5 m
# c) 0.67 m
# d) 0.4 m
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 물체가 2디옵터의 볼록 렌즈로부터 2미터 떨어져 있을 때, 이미지는 렌즈로부터 얼마나 떨어진 거리에 형성됩니까?
# a) 2.0 m.
# b) 1.5 m.
# c) 0.67 m.
# d) 0.4 m.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 21:
# Language: chinese
# Question:
# 以下哪个十进制对数（logMAR）值对应于正常视力（1.0）？
# a) -1。
# b) 0。
# c) 1。
# d) 2。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 次のうち、小数対数（logMAR）で表された正常な視力（1.0）に対応する値はどれですか？
# a) -1
# b) 0
# c) 1
# d) 2
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 다음 중 소수 로그 (logMAR)에서 정상 시력 (1.0)에 해당하는 값은 무엇입니까?
# a) -1.
# b) 0.
# c) 1.
# d) 2.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 22:
# Language: chinese
# Question:
# 两个相互垂直的偏振滤光片之间的光学效应是什么？
# a) 透射率减少了50%。
# b) 透射率增加了50%。
# c) 没有光线传输。
# d) 没有光能量损失。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 二つの偏光フィルターが互いに垂直に配置された場合の光学効果は何ですか？
# a) 透過率が50％減少します。
# b) 透過率が50％増加します。
# c) 光の透過がない。
# d) 光エネルギーの損失がない。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 두 개의 서로 수직인 폴라로이드 필터의 보간으로 인해 발생하는 광학 효과는 무엇입니까?
# a) 전송이 50% 감소합니다.
# b) 전송이 50% 증가합니다.
# c) 빛의 전송이 없습니다.
# d) 빛 에너지의 손실이 없습니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 23:
# Language: chinese
# Question:
# 在以下哪种材料中光速最慢？
# a) 空气。
# b) 钻石。
# c) 玻璃。
# d) 光速不受介质影响，恒定不变。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 以下のどの物質中で光の速度が最も遅いですか？
# a) 空気。
# b) ダイヤモンド。
# c) ガラス。
# d) 光の速度は媒質に関係なく一定です。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 다음 재료 중에서 빛의 속도가 가장 낮은 것은 어디입니까?
# a) 공기.
# b) 다이아몬드.
# c) 유리.
# d) 빛의 속도는 매질에 관계없이 일정합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 24:
# Language: chinese
# Question:
# 选择哪个对应于凸面镜的反射。
# a) 使用普拉西多盘的角膜镜检查。
# b) 剃须镜。
# c) 牙医镜。
# d) 反射式车头灯。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 凸面鏡からの反射に該当するものを選んでください。
# a) プラシドディスクを用いた角膜形状検査。
# b) 髭剃り用の鏡。
# c) 歯科医の鏡。
# d) 反射型ヘッドランプ。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 다음 중 볼록 거울에서의 반사에 해당하는 것을 선택하십시오.
# a) 플라시도 디스크를 사용한 각막계측법.
# b) 면도용 거울.
# c) 치과 의사의 거울.
# d) 반사식 헤드램프.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 25:
# Language: chinese
# Question:
# 一只会聚透镜将来自1米远的光源聚焦在50厘米处。这个透镜有多大的功率？
# a) +1屈光度。
# b) +2屈光度。
# c) +3屈光度。
# d) +4屈光度。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 収束レンズは、1メートル離れた光源からの光を50センチメートルの距離で焦点に合わせます。このレンズのパワーはどれくらいですか？
# a) +1ディオプター。
# b) +2ディオプター。
# c) +3ディオプター。
# d) +4ディオプター。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 수렴 렌즈가 1m 떨어진 광원에서 나온 빛을 50cm 거리에 초점을 맞춥니다. 이 렌즈의 세기는 얼마입니까?
# a) +1 디옵터.
# b) +2 디옵터.
# c) +3 디옵터.
# d) +4 디옵터.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 26:
# Language: chinese
# Question:
# 如果我们测量从眼球中取出后角膜后表面的像的焦距，我们将得到以下数值（考虑角膜前曲率为7.7毫米；角膜后曲率为6.8毫米；角膜基质的折射率为1.376以及空气的折射率为1.00）：
# a) +5.00屈光度
# b) 0.00屈光度
# c) -5.00屈光度
# d) -55.00屈光度
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 眼球から角膜の後面を取り除いた後、その像の焦点力を測定すると、以下の値になるでしょう（角膜の前面の曲率を7.7mm、後面の曲率を6.8mm、角膜基質の屈折率を1.376、空気の屈折率を1.00として考えてください）：
# a) +5.00ディオプトリー
# b) 0.00ディオプトリー
# c) -5.00ディオプトリー
# d) -55.00ディオプトリー
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 만약 우리가 안구에서 각막의 후면을 제거한 후 그 이미지의 초점력을 측정한다면, 다음과 같은 값을 가질 것입니다 (각막의 전방 곡률을 7.7mm, 후방 곡률을 6.8mm, 각막 기질의 굴절률을 1.376, 공기의 굴절률을 1.00으로 가정하면):
# a) +5.00 디옵터.
# b) 0.00 디옵터.
# c) -5.00 디옵터.
# d) -55.00 디옵터.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 27:
# Language: chinese
# Question:
# 当减少一个未能适应以下处方眼镜的患者的圆柱度处方时，-1.50球面屈光度 <<>> -3.50圆柱屈光度 X 180°，保持球面等效的可能处方是：
# a) -2.50球面屈光度 <<>> -2.50圆柱屈光度 X 180°。
# b) +1.50球面屈光度 <<>> -2.50圆柱屈光度 X 180°。
# c) -4.50球面屈光度 <<>> +2.50圆柱屈光度 X 90°。
# d) -2.50球面屈光度 <<>> +3.00圆柱屈光度 X 90°。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 以下の処方でメガネに適応できなかった患者のシリンダー処方を減らす場合、球面等価を維持する可能性のある処方は次のとおりです：
# a) -2.50 球面屈折度 < > -2.50 シリンダー屈折度 X 180°。
# b) +1.50 球面屈折度 < > -2.50 シリンダー屈折度 X 180°。
# c) -4.50 球面屈折度 < > +2.50 シリンダー屈折度 X 90°。
# d) -2.50 球面屈折度 < > +3.00 シリンダー屈折度 X 90°。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 환자가 다음 처방의 안경에 적응하지 못했을 때 원통 처방을 줄이는 경우, 구면 동등을 유지하는 가능한 처방은 다음과 같습니다:
# a) -2.50 구면 디옵터 < > -2.50 원통 디옵터 X 180°.
# b) +1.50 구면 디옵터 < > -2.50 원통 디옵터 X 180°.
# c) -4.50 구면 디옵터 < > +2.50 원통 디옵터 X 90°.
# d) -2.50 구면 디옵터 < > +3.00 원통 디옵터 X 90°.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 28:
# Language: chinese
# Question:
# 光线在距离棱镜50厘米的地方，相对于视轴偏移了20毫米。这个棱镜的屈光度（以棱镜屈光度计）是多少？
# a) 0.4。
# b) 2.5。
# c) 4。
# d) 10。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 光線がプリズムによって視軸から20mm逸れ、距離50cmの地点でどのように変化するかを示します。プリズムの屈折力はプリズム・ディオプターでどれくらいですか？
# a) 0.4
# b) 2.5
# c) 4
# d) 10
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 빛의 광선이 프리즘에서 50cm 떨어진 거리에서 시각 축으로부터 20mm 만큼 편향되었습니다. 프리즘의 굴절력은 프리즘 디옵터로 얼마입니까?
# a) 0.4.
# b) 2.5.
# c) 4.
# d) 10.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 29:
# Language: chinese
# Question:
# 考虑到古尔斯特兰德的示意眼，视网膜上形成的图像的特点是什么？
# a) 实际的，倒置的。
# b) 虚拟的，倒置的。
# c) 实际的，正向的。
# d) 虚拟的，正向的。
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# Language: japanese
# Question:
# ガルストランドの模式眼を考慮すると、網膜上に形成される像の特徴は何ですか？
# a) 実像、倒立。
# b) 虚像、倒立。
# c) 実像、正立。
# d) 虚像、正立。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# Gullstrand의 개략적인 눈을 고려할 때, 망막에 형성된 이미지의 특성은 무엇입니까?
# a) 실제, 뒤집힘.
# b) 가상, 뒤집힘.
# c) 실제, 정방향.
# d) 가상, 정방향.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 30:
# Language: chinese
# Question:
# 将抗菌药物分类与其主要作用部位匹配。
#
# I- 头孢菌素
# II- 四环素
# III- 喹诺酮
# IV- 大环内酯
#
# A- 蛋白质合成（30s抑制剂）
# B- 蛋白质合成（50s抑制剂）
# C- DNA回旋酶
# D- 细胞壁合成
#
# a) I: A; II: D; III: D; IV: B.
# b) I: D; II: A; III: C; IV: B.
# c) I: A; II: D; III: B; IV: C.
# d) I: D; II: B; III: A; IV: C.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 抗菌薬のクラスをそれぞれの主な作用部位に合わせてください。
#
# I- セファロスポリン
# II- テトラサイクリン
# III- キノロン
# IV- マクロライド
#
# A- タンパク質合成阻害（30Sサブユニット）
# B- タンパク質合成阻害（50Sサブユニット）
# C- DNAジャイレース
# D- 細胞壁合成
#
# a) I: A; II: D; III: D; IV: B.
# b) I: D; II: A; III: C; IV: B.
# c) I: A; II: D; III: B; IV: C.
# d) I: D; II: B; III: A; IV: C.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 항균제의 종류를 각각의 주요 작용 부위와 연결하세요.
#
# I- 세팔로스포린
# II- 테트라사이클린
# III- 퀴놀론
# IV- 마크로라이드
#
# A- 단백질 합성 억제 (30s 억제제)
# B- 단백질 합성 억제 (50s 억제제)
# C- DNA 자이라제
# D- 세포벽 합성
#
# a) I: A; II: D; III: D; IV: B.
# b) I: D; II: A; III: C; IV: B.
# c) I: A; II: D; III: B; IV: C.
# d) I: D; II: B; III: A; IV: C.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 31:
# Language: chinese
# Question:
# 一位患有干燥综合症的患者在非眼科医生开出以下药物后，口腔症状（唾液分泌增加）开始改善：
# a) 布莫尼定，但出现了点状瞳孔缩小和视力下降。
# b) 曲卡因，但出现了传统的视网膜脱落。
# c) 阿托品，但出现了中度散瞳和调节困难。
# d) 毛果芸香碱，但出现了调节性痉挛。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# シェーグレン症候群の患者が、非眼科医が処方した後、口腔症状（唾液の分泌増加）の改善を見せ始めました：
# a) ブリモニジンを処方されたが、点状縮瞳と視力低下が進行しました。
# b) テトラカインを処方されたが、従来の網膜剥離が進行しました。
# c) アトロピンを処方されたが、中程度の散瞳と調節困難が進行しました。
# d) ピロカルピンを処方されたが、調節痙攣が進行しました。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 쇼그렌 증후군을 앓고 있는 환자가 비안과 전문의의 처방 후 구강 증상(침 분비 증가)이 개선되기 시작했습니다:
# a) 브리모니딘을 처방받았으나, 점상 미오시스와 시력 저하가 진행되었습니다.
# b) 테트라카인을 처방받았으나, 전통적인 망막 분리가 진행되었습니다.
# c) 아트로핀을 처방받았으나, 중간 정도의 동공 확대와 조절 능력 장애가 진행되었습니다.
# d) 필로카핀을 처방받았으나, 조절 경련이 진행되었습니다.
# Test #0:
# response
# ```json
# {
# 	"response": "c"
# }
# ```
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 32:
# Language: chinese
# Question:
# 关于组织纤溶酶原激活因子的使用，正确的说法是：
# a) 在房水间隙使用此药物是被禁止的。
# b) 激活纤溶酶成为纤溶原有助于血液的降解。（这一选项表述有误，应为纤溶酶原转化为纤溶酶）
# c) 激活纤溶酶原为纤溶酶有助于血液的降解。
# d) 其主要适应症是玻璃体空间的出血。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 組織プラスミノーゲン活性化因子の使用について、以下の記述が正しいと言えます：
# a) この薬剤は眼内隔室内での使用が禁止されています。
# b) プラスミンをプラミノーゲンに活性化することは血液の分解に役立ちます。（誤り）
# c) プラスミノーゲンをプラスミンに活性化することは血液の分解に役立ちます。
# d) 主な適応症は硝子体内出血です。（誤り）
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 조직 플라스미노겐 활성화 인자의 사용과 관련하여 다음과 같이 말하는 것이 올바릅니다:
# a) 이 약물은 안구 내방에서 사용이 금지되어 있습니다.
# b) 플라스민을 플라스미노겐으로 활성화시키는 것은 혈액의 분해를 돕습니다.
# c) 플라스미노겐을 플라스민으로 활성화시키는 것은 혈액의 분해를 돕습니다.
# d) 주요 적응증은 유리체 공간에서의 출혈입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 33:
# Language: chinese
# Question:
# 关于在小梁切除术中使用丝裂霉素-C，以下说法正确的是：
# b) 巩膜变薄、无血管泡、术后疼痛和角膜水肿是与其使用相关的并发症。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 緑内障手術におけるミトマイシンCの使用について、以下の記述が正しいと言えます：
# a) ピリミジン類似体であるため、その作用はチミンの合成を阻害し、DNA/RNAの生成を防ぐことに由来します。
# b) 強膜の薄化、無血管性の水疱、術後の痛み、角膜浮腫は、その使用に関連する合併症です。
# c) 妊娠中の女性では、線維化の傾向が高まるため、濃度を増やすべきです。
# d) 黒色皮膚の患者には使用すべきではありません。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 트라베큐렉토미에서 미토마이신-C 사용과 관련하여 다음과 같이 말할 수 있습니다:
# a) 피리미딘 유사체이기 때문에, 그 작용은 티민 합성의 차단에서 비롯되어 DNA/RNA의 생산을 방지합니다.
# b) 각막 부종, 수술 후 통증, 무혈관성 블렙, 공막 얇아짐은 그 사용과 관련된 합병증입니다.
# c) 임신부에서는 섬유화 경향이 더 크기 때문에 농도를 증가시켜야 합니다.
# d) 멜라노더믹 환자에게는 사용해서는 안 됩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 34:
# Language: chinese
# Question:
# 患有增生性糖尿病视网膜病变的患者将会辅以玻璃体内抗VEGF治疗。我们可以指出：
# a) 应优先抑制VEGF的B亚型，因为它们是主要的新血管形成者。
# b) Ranibizumab能抑制所有VEGF-B亚型，但不抑制VEGF-A。
# c) Bevacizumab不允许VEGF-A亚型与其受体结合。
# d) 不再使用pegaptanib，因为该药物不能穿透视网膜层。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 増殖性糖尿病性網膜症の患者は、硝子体内抗VEGF治療を補完することになります。以下の点を述べることができます：
# a) VEGFのBアイソフォームの阻害を優先すべきです。これは、それらが主な新しい血管の形成者であるからです。
# b) ラニビズマブはすべてのVEGF-Bアイソフォームを阻害しますが、VEGF-Aは阻害しません。
# c) ベバシズマブはVEGF-Aアイソフォームがその受容体に結合するのを許可しません。
# d) ペガプタニブの使用はもはや行われていません。この薬は網膜層に浸透しないためです。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 증식성 당뇨병성 망막병증을 가진 환자들은 유리체 내 항-VEGF 치료를 보완할 것입니다. 다음과 같이 말할 수 있습니다:
# a) VEGF의 B 아이소폼은 주요 신생 혈관 형성자이므로, 이들의 억제에 우선순위를 두어야 합니다.
# b) 라니비주맙은 모든 VEGF-B 아이소폼을 억제하지만, VEGF-A는 억제하지 않습니다.
# c) 베바시주맙은 VEGF-A 아이소폼이 그들의 수용체에 결합하는 것을 허용하지 않습니다.
# d) 페가프타닙의 사용은 더 이상 사용되지 않습니다, 왜냐하면 이 약물은 망막 층을 관통하지 않기 때문입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 35:
# Language: chinese
# Question:
# 考虑到结膜肿瘤，以下哪个参数的存在用于区分结膜上皮内瘤变和侵袭性癌症？
# a) 细胞异型性。
# b) 涉及上皮的全部厚度。
# c) 异常核仁数量增加。
# d) 基底膜的侵犯。
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# Language: japanese
# Question:
# 結膜腫瘍を考慮すると、以下のどのパラメーターの存在が結膜異形成と浸潤性癌とを区別するために使用されますか？
# a) 細胞異型性。
# b) 上皮の全層への関与。
# c) 異型核小体の数の増加。
# d) 基底膜の浸潤。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 결막 종양을 고려할 때, 아래의 어떤 요소가 결막 이형성증과 침윤성 암종을 구분하는 데 사용됩니까?
# a) 세포 이형성.
# b) 상피 전층의 관여.
# c) 비정상적인 핵소체의 수 증가.
# d) 기저막의 침범.
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# **************************************************
# **************************************************
# Question 36:
# Language: chinese
# Question:
# 荧光素标记的单克隆抗体（FITC）针对外膜细胞壁蛋白，对于下列哪种病原体是更好的诊断方法？
# a) 沙眼衣原体（C. trachomatis）。
# b) 棘阿米巴属（Acanthamoeba sp.）。
# c) 隐球菌属（Cryptococcus sp.）。
# d) 脑膜炎奈瑟菌（Neisseria meningitidis）。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 蛍光イソチオシアネート（FITC）で標識された単クローン抗体は、以下のリストのうちどの病原体の診断方法として優れていますか？
# a) C. trachomatis.
# b) Acanthamoeba sp.
# c) Cryptococcus sp.
# d) Neisseria meningitidis.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 형광 표지 단클론 항체(FITC)는 아래 나열된 어떤 병원체의 외막 세포벽 단백질을 대상으로 할 때 더 나은 진단 방법이 됩니까?
# a) C. trachomatis.
# b) Acanthamoeba sp.
# c) Cryptococcus sp.
# d) Neisseria meningitidis.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 37:
# Language: chinese
# Question:
# 角膜的主要神经支配是由哪种睫状神经完成的？
# a) 短前。
# b) 短后。
# c) 长前。
# d) 长后。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 角膜の神経支配は主にどの毛様体神経によって行われますか？
# a) 短い前方の。
# b) 短い後方の。
# c) 長い前方の。
# d) 長い後方の。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# 注：この場合、答えは角膜の神経支配は主に三叉神経の第一枝（短い前方の毛様体神経）によって行われますので、「A」が正しい選択肢です。しかし、選択肢のラベル（A, B, C, D）は日本語の質問に直接関連していません。そのため、この回答は形式的なもので、選択肢のラベルと質問の内容の間の直接的な関連性を示すものではありません。
# {'response': 'A'}
# Language: korean
# Question:
# 각막의 신경 공급은 주로 어떤 섬모 신경에 의해 이루어집니까?
# a) 짧은 전방.
# b) 짧은 후방.
# c) 긴 전방.
# d) 긴 후방.
# Test #0:
# response
# ```json
# {
# 	"response": "c"
# }
# ```
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 38:
# Language: chinese
# Question:
# 以下哪个眼外肌由动眼神经上支支配？
# a) 上斜肌。
# b) 下直肌。
# c) 内直肌
# d) 上直肌。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 次のうち、動眼神経上部枝によって支配されている眼外筋はどれですか？
# a) 上斜筋
# b) 下直筋
# c) 内側直筋
# d) 上直筋
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 다음 중 안구 운동 신경의 상부 분지에 의해 지배되는 외안근은 어느 것입니까?
# a) 상사근.
# b) 하직근.
# c) 내직근
# d) 상직근.
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# **************************************************
# **************************************************
# Question 39:
# Language: chinese
# Question:
# 根据解剖学知识，选择最可能的选项。
# a) 筛骨骨折可能导致眼眶气肿。
# b) 眼眶外侧部分骨折可能导致眼眶内出血，由于前后筛骨动脉破裂。
# c) 眼眶底部骨折可能导致咀嚼动作受损，因为损害了三叉神经的一个分支——上颌神经。
# d) 泪骨骨折可能通过损害泪神经，减少主泪腺的泪液分泌。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 解剖学的知識に基づいて、最も可能性の高い選択肢を選びなさい。
# a) 筛骨の骨折は眼窩気腫を引き起こす可能性があります。
# b) 眼窩の外側部分の骨折は、前後の筛骨動脈の破裂により眼窩内出血を引き起こす可能性があります。
# c) 眼窩底の骨折は、三叉神経の枝である上顎神経の損傷により、咀嚼運動の障害を引き起こす可能性があります。
# d) 涙骨の骨折は、涙神経を損傷することにより、主涙腺による涙の分泌を減少させる可能性があります。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 해부학적 지식에 기반하여 가장 가능성이 높은 대안을 선택하십시오.
# a) 사골의 골절은 안와기종을 일으킬 수 있습니다.
# b) 안와의 외측 부분의 골절은 전후 사골동맥의 파열로 인해 안와 내 출혈을 일으킬 수 있습니다.
# c) 안와 바닥의 골절은 삼차신경의 분지인 상악신경의 손상으로 인해 저작 운동의 장애를 일으킬 수 있습니다.
# d) 누낭골의 골절은 누낭신경의 손상으로 인해 주 누낭샘의 눈물 분비 감소를 초래할 수 있습니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 40:
# Language: chinese
# Question:
# 角膜透明度的影响因素有很多，但主要的因素是：
# d) 胶原纤维的排列方式规则、均匀且彼此平行。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 角膜の透明性に寄与する要因は多数ありますが、主なものは以下の通りです：
# a) 接着性プロテオグリカンの不在が、緩い線維間隙を増加させ、光の自由な通過を可能にします。
# b) 低い代謝要求により、極めて細かいストローマ毛細血管の網目による栄養が可能になります。
# c) デスメ膜の高浸透圧特性が、ストローマの水分保持を減少させます。
# d) コラーゲン線維が規則的で均一、お互いに平行に配置されています。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 각막의 투명성에 기여하는 요인은 많지만 주요 요인은 다음과 같습니다:
# d) 콜라겐 섬유의 규칙적이고 균일하며 서로 평행한 배열입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 41:
# Language: chinese
# Question:
# 标记关于眼球后段解剖的正确选项。
# a) 两条长睫状神经在眼球赤道处出现，大约在十二点和六点钟位置，这解释了在全视网膜光凝术中这些象限更敏感于痛感。
# b) 视网膜色素上皮弥漫性萎缩的人在眼底检查中，视网膜下的漩涡状动脉给出了“虎纹”花纹的蕾丝状外观。
# c) 在锯齿状缘（ora serrata）处，有小的径向子午线褶皱紧邻齿状突，可能在其基部有一个小的萎缩性视网膜孔，无需封闭。
# d) 中央凹小凹（foveola），由于高浓度的感光细胞导致较高的代谢活动，呈现由上下颞弓吻合形成的密集血管网络。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 眼の後部の解剖に関する正しい選択肢をマークしてください。
# a) 2つの長い毛様神経が眼の赤道部で、おおよそ12時と6時の位置で現れることが、全光凝固術中にこれらの象限での痛みの感受性が高まる理由を説明しています。
# b) 網膜色素上皮の拡散性萎縮を持つ人々の眼底検査で、網膜下の渦巻き動脈がレースのような「タイガー」外観を与えます。
# c) オラ・セラータには、小さな放射状の子午線の折り目が歯状過程の隣にあり、最終的にはその基部に小さな萎縮性網膜穴がありますが、これは遮断する必要はありません。
# d) 高い濃度の光受容体のために大きな代謝活動を示す部位であるフォヴェオラは、上下の側頭弓の吻合によって形成される激しい血管網を示します。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 눈의 후방 부분의 해부학에 관한 올바른 대안을 표시하십시오.
# a) 두 개의 긴 섬유 신경이 눈의 적도에서 대략 12시와 6시 방향에서 나타나는 것은 이 사분면에서의 통증 감도가 팬포토코아굴레이션 동안 더 크다는 것을 설명합니다.
# b) 망막 색소 상피의 확산 위축을 가진 사람들의 안저 검사에서 레이스 같은 "호랑이" 모양을 나타내는 맥락막 아래 정맥 동맥.
# c) 오라 세라타에서는 치아 모양 과정 옆에 작은 방사상 경선 주름이 있으며, 결국 그 기저부에 작은 위축성 망막 구멍이 있어 차단할 필요가 없습니다.
# d) 고농도의 광수용체로 인해 더 큰 대사 활동을 하는 포베올라는 상부 및 하부 측두 동맥의 문합에 의해 형성된 강렬한 혈관 네트워크를 나타냅니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 42:
# Language: chinese
# Question:
# 标记关于房角窦解剖的正确选项：
# a) 舒瓦尔贝线对应于巩膜刺的角膜镜投影。
# b) 睫状体带通常无法通过角膜镜观察到。
# c) 达到舒瓦尔贝线的小梁状虹膜突通常不出现在正常眼中；当发现时，它们表明之前有虹膜睫状体炎。
# d) 房水的排流主要发生在色素较多的小梁网的后部。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# カメラル洞の解剖に関する正しい選択肢を選びなさい。
# a) シュヴァルベ線は強膜棘の角膜鏡的投影に対応します。
# b) 毛様体帯は通常、角膜鏡検査では見ることができません。
# c) 正常な目にはシュヴァルベ線に達する網状虹彩過程は存在せず、見つかった場合は以前の虹彩毛様体炎を示唆します。
# d) 房水の排水流は主に色素の多い網膜の後部で発生します。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 카메룰러 부비동의 해부학에 관한 올바른 대안을 표시하십시오.
# a) 슈발베 선은 공막 돌기의 각막경 투영에 해당합니다.
# b) 섬모체 밴드는 일반적으로 각막경으로 볼 수 없습니다.
# c) 정상적인 눈에는 슈발베 선에 도달하는 섬모 모양의 홍채 과정이 없으며, 발견될 경우 이전의 홍채모양체염을 나타냅니다.
# d) 방수의 배수 흐름은 주로 색소가 더 많은 섬유주망의 후부에서 발생합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 43:
# Language: chinese
# Question:
# 以下句子描述的是人眼的哪个结构？
#
# 1- 葡萄膜道最前端的延伸。
# 2- 由血管、结缔组织和黑色素细胞组成。
# 3- 呈现色素上皮，其细胞的基底末端面向后房。
# 4- 具有交感神经支配的平滑肌纤维。
#
# a) 睫状体。
# b) 虹膜。
# c) 房角窦。
# d) 视网膜色素上皮的脉络膜道。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 以下の文は人間の目のどの構造に関連していますか？
#
# 1- 最も前方に位置する脈絡膜の延長部。
# 2- 血管、結合組織、メラノサイトで形成される。
# 3- 細胞の基底端が後房に面している色素上皮を持つ。
# 4- 交感神経の支配を受ける平滑筋繊維がある。
#
# a) 毛様体
# b) 虹彩
# c) 房角洞
# d) 視神経乳頭の脈絡膜経路
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 아래 문장들은 인간의 눈 구조 중 어느 것을 나타내나요?
#
# 1- 포도막의 가장 앞쪽 연장부.
# 2- 혈관, 결합 조직 및 멜라노사이트로 구성됨.
# 3- 세포의 기저부가 후방방으로 향하는 색소 상피를 나타냄.
# 4- 교감신경의 평활근 섬유를 가지고 있음.
#
# a) 섬모체
# b) 홍채
# c) 방수강
# d) 오라 세라타의 맥락막 트랙
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 44:
# Language: chinese
# Question:
# 关于视网膜的解剖结构，请选择下列选项中正确对应两栏的选项：
#
# I - 外网状层
# II - 外界限
# III - 内核层
# IV - 内界限
# V - 神经纤维层
#
# A - 与玻璃体接触
# B - 位于感光细胞和双极细胞之间
# C - 包含无轴突细胞和水平细胞
# D - 穆勒细胞过程
# E - 包含神经节细胞的轴突
#
# a) A: II; B: III; C: I; D: V; I: IV.
# b) A: IV; B: I; C: III; D: II; E: V.
# c) A: IV; B: V; C: III; D: I; I: II.
# d) A: V; B: II; C: III; D: IV; E: I.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 網膜の解剖に関して、以下の二つの列の正しい対応を含む選択肢を選びなさい：
#
# I - 外側神経節層
# II - 外側限界
# III - 内側核層
# IV - 内側限界
# V - 神経繊維層
#
# A - 硝子体と接触している
# B - 光受容体と二重極細胞の間にある
# C - アマクリン細胞と水平細胞を含む
# D - ミュラー細胞の過程
# E - 神経節細胞の軸索を含む
#
# a) A: II; B: III; C: I; D: V; I: IV.
# b) A: IV; B: I; C: III; D: II; E: V.
# c) A: IV; B: V; C: III; D: I; I: II.
# d) A: V; B: II; C: III; D: IV; E: I.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 망막의 해부학에 관하여, 아래 두 열 사이의 올바른 연관성을 포함하는 대안을 선택하십시오:
#
# I - 외측 신경총층
# II - 외부 한계
# III - 내핵층
# IV - 내부 한계
# V - 신경섬유층
#
# A- 유리체와 접촉한다
# B- 광수용체와 이중극 세포 사이에 있다
# C- 아마크린 세포와 수평 세포를 포함한다
# D - 뮐러 세포의 과정
# E- 신경절 세포의 축삭을 포함한다
#
# a) A: II; B: III; C: I; D: V; I: IV.
# b) A: IV; B: I; C: III; D: II; E: V.
# c) A: IV; B: V; C: III; D: I; I: II.
# d) A: V; B:II; C: III; D: IV; E:I.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 45:
# Language: chinese
# Question:
# 晶状体未摘除的患者在行小梁切除术后15小时内出现了显著的眼内压增高和无晶体眼。可以正确地说：
# a) 这种严重的眼部状况在无晶体眼患者中更为常见。
# b) 在术后即刻使用局部散瞳剂是这种状况的一个风险因素。
# c) 如果有通畅的虹膜切开，这种情况就不会发生。
# d) 通常，这种状况发生在前后径比一般人群小的眼睛中。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 眼内レンズを持たない患者が眼圧の著しい上昇とアタラミアを発症し、眼内切開術後15時間で進行しました。以下の記述が正しいと言えますか：
#
# a) この重度の眼疾患は無水晶体眼の患者により一般的です。
# b) 術後直後の局所的な散瞳剤の使用は、この状態のリスク因子です。
# c) 既存の虹彩切開があれば、この状態は発生しません。
# d) 通常、この状態は一般の人口よりも前後径が小さい眼で発生します。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 수정체가 있는 환자가 섬유주절제술 후 15시간 만에 안압이 현저하게 증가하고 수정체가 없는 상태로 진행되었습니다. 다음 중 올바른 것은:
# a) 이러한 심각한 안구 상태는 무수정체 환자에서 더 흔합니다.
# b) 수술 직후 기간 동안 국소적으로 사용하는 동공확장제는 이 상태의 위험 요소입니다.
# c) 이미 홍채절개술이 이루어진 경우 이러한 상황은 발생하지 않습니다.
# d) 일반적으로 이 상태는 일반 인구보다 전후 직경이 작은 눈에서 발생합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 46:
# Language: chinese
# Question:
# 关于类固醇诱导的青光眼，以下说法是正确的：
# a) 发生在所有年龄段。
# b) 低浓度的皮质类固醇不会增加眼内压。
# c) 青光眼通常是闭角型。
# d) 由于使用口服皮质类固醇而不是眼药水的形式，其发生频率更高。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# ステロイド誘発性緑内障について、以下の記述が正しいと言えます：
# a) すべての年齢で発生します。
# b) 低濃度のコルチコステロイドは眼内圧を上昇させません。
# c) 緑内障は通常、閉塞隅角型です。
# d) 点眼薬の形での使用よりも、経口コルチコステロイドの使用による方が頻繁です。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 스테로이드 유발 녹내장에 대해 다음과 같이 말하는 것이 올바릅니다:
# a) 모든 연령에서 발생합니다.
# b) 저농도의 코르티코스테로이드는 안압을 증가시키지 않습니다.
# c) 일반적으로 녹내장은 폐쇄각입니다.
# d) 경구용 코르티코스테로이드 사용으로 인해 더 자주 발생하는 것이 아니라 안약 형태로 더 자주 발생합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 47:
# Language: chinese
# Question:
# 以下哪种视野缺损最能与局部性的视神经盘周围神经纤维层（Hoyt征象）在下颞部的损失相对应？
# a) 下颞盲点中心。
# b) 上鼻部。
# c) 楔形上颞部。
# d) 下垂直部。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 以下の視野欠損のうち、下側側頭部の周乳頭神経線維層の局所的な損失（ホイトの徴候）と最も相関するのはどれですか？
# a) 下側側頭盲点中心
# b) 上側鼻側
# c) 楔形の上側側頭
# d) 下側垂直
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# Language: korean
# Question:
# 다음 중 하부 측두부의 주변 유두 신경 섬유층의 국소적 손실(호이트 징후)과 가장 잘 상관관계가 있는 시야 결손은 무엇입니까?
# a) 하부 측두 맹중심.
# b) 상부 비강.
# c) 쐐기 모양의 상부 측두.
# d) 하부 수직.
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 48:
# Language: chinese
# Question:
# 血黄素性青光眼是由以下原因引起的：
# a) 巩膜网板中巨噬细胞的积聚。
# b) 巩膜网板中无法进行移行的血细胞的积聚。
# c) 巩膜网板中存在于血红蛋白中的铁的积聚。
# d) 新鲜红细胞、纤维蛋白和血浆堵塞巩膜网板。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# ヘモシデローシス緑内障は以下の原因によって引き起こされます：
# a) 眼房角の網目構造におけるマクロファージの蓄積。
# b) 眼房角の網目構造における走化性を持たない血球の蓄積。
# c) 眼房角の網目構造におけるヘモグロビン中の鉄の蓄積。
# d) 新鮮な赤血球、フィブリン、プラズマによる眼房角の網目構造の詰まり。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 헤모시데로틱 녹내장은 다음과 같은 원인으로 발생합니다:
# a) 섬유주름망에 대식세포가 축적됩니다.
# b) 섬유주름망에 이동 능력이 없는 혈구가 축적됩니다.
# c) 섬유주름망에 헤모글로빈에 존재하는 철분이 축적됩니다.
# d) 섬유주름망이 신선한 적혈구, 섬유소, 혈장으로 막힙니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 49:
# Language: chinese
# Question:
# 原发性开角型青光眼的经典危险因素包括：
# a) 亚洲人，家族史阳性，年轻人。
# b) 眼内压升高，白种人，年龄在25至45岁之间。
# c) 眼内压升高，黑种人，家族史阳性。
# d) 女性，角膜厚度增加，眼内压波动大。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 原発性開放隅角緑内障の発症における典型的なリスクファクターは以下の通りです：
# a) アジア人、家族歴の有無、若年者。
# b) 眼圧の上昇、白人、25歳から45歳の年齢。
# c) 眼圧の上昇、黒人、家族歴の有無。
# d) 女性、角膜の厚さの増加、眼圧の大きな変動。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 원발 개방각 녹내장 발병의 전형적인 위험 요인은 다음과 같습니다:
# a) 아시아인, 가족력 양성, 젊은 사람들.
# b) 안압 상승, 백인, 25세에서 45세 사이의 나이.
# c) 안압 상승, 흑인, 가족력 양성.
# d) 여성, 각막 두께 증가, 큰 변동을 보이는 안압.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 50:
# Language: chinese
# Question:
# 男性患者，25岁，反复出现眼压高（40至60毫米汞柱），无痛，单侧，持续时间短，无视力丧失。最可能的诊断是什么？
# a) 福克斯异色性葡萄膜炎。
# b) 急性青光眼发作，伴隆起虹膜。
# c) 急性青光眼发作，伴平台虹膜。
# d) 青光眼周期性危机。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 男性患者、25歳、反復する眼圧高値（40～60mmHg）、無痛、片側性、短時間、視力喪失なし。最も可能性の高い診断は何ですか？
# a) フックス異色性虹彩炎。
# b) 急性緑内障の発作、ボンベ虹彩。
# c) 急性緑内障の発作、プラトー虹彩。
# d) 緑内障周期性危機。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 남성 환자, 25세, 반복적인 안압 상승(40~60mmHg 사이), 통증 없음, 일측성, 짧은 지속 기간, 시력 손실 없음. 가장 가능성 있는 진단은 무엇입니까?
# a) 푹스 이색성 포도막염.
# b) 급성 녹내장 발작과 함께 있는 봉투 모양 홍채.
# c) 급성 녹내장 발작과 함께 있는 플라토 모양 홍채.
# d) 녹내장성 주기적 위기.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 51:
# Language: chinese
# Question:
# 一位60岁的糖尿病患者抱怨右眼疼痛和视力下降。在眼科检查中，视力为0.1，眼压为45毫米汞柱，角膜水肿，虹膜新生血管，经验角镜检查四个象限均为开放角，杯盘比为0.3，且有增殖性糖尿病视网膜病变。在开始降压治疗后，患者有良好的反应。在以下选项中，哪一种是最合适的后续行动方案？
# a) 环形光凝固术。
# b) 引流植入物。
# c) 全视网膜光凝固术。
# d) 使用丝裂霉素C的小梁切除术。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 60歳の糖尿病患者が、右目の痛みと視力低下を訴えています。眼科検査では、視力が0.1、眼圧が45 mmHg、角膜浮腫、虹彩新生血管、全象限で開放角を示す隅角鏡検査、カップ/ディスク比が0.3、増殖性糖尿病性網膜症が確認されました。降圧治療を開始した後、患者は良好な反応を示しました。以下の選択肢の中で、最も適切な行動方針はどれでしょうか？
# a) サイクロフォト凝固
# b) ドレナージインプラント
# c) 全網膜光凝固
# d) ミトマイシンCを用いたトラベクレクトミー
# Test #0:
# response
# ```json
# {
# 	"response": "c"
# }
# ```
# {'response': 'c'}
# Language: korean
# Question:
# 60세 당뇨병 환자가 오른쪽 눈의 통증과 시력 저하를 호소합니다. 안과 검사에서 시력은 0.1, 안압은 45 mmHg, 각막 부종, 홍채 신생혈관, 모든 사분면에서 개방각을 보이는 각막경 검사, cup/disc 비율 0.3, 증식성 당뇨망막병증이 관찰되었습니다. 저혈압 치료를 시작한 후 환자는 좋은 반응을 보였습니다. 아래 옵션 중 가장 적절한 행동 과정은 무엇입니까?
# a) 순환광응고.
# b) 배액 임플란트.
# c) 전망막 광응고.
# d) 미토마이신 C와 함께 하는 섬유주절제술.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 52:
# Language: chinese
# Question:
# 在以下选项中，哪一项最能提示青光眼？
# a) 两眼杯盘比不对称0.2。
# b) 神经颞侧区有α区周边视神经萎缩。
# c) 双侧视神经盘凹陷/盘比为0.5。
# d) 视神经杯/盘比为0.4，伴有下颞侧凹槽。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 以下の選択肢の中で、緑内障の最も示唆的な所見はどれですか？
# a) 両目のカップの非対称性が0.2。
# b) 神経の側頭部にアルファゾーンを伴う周辺乳頭萎縮。
# c) 両側の掘り込み/ディスク比が0.5。
# d) 下側頭部にノッチがある場合の視神経カップ/ディスク比が0.4。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 아래 옵션 중 녹내장을 가장 시사하는 소견은 무엇입니까?
# a) 두 눈 사이의 컵핑 비대칭이 0.2입니다.
# b) 신경의 측두부에 알파 존이 있는 주위 유두 위축.
# c) 양측 굴착/디스크 비율이 0.5입니다.
# d) 하부 측두 노치가 있는 시신경 컵/디스크 비율이 0.4입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 53:
# Language: chinese
# Question:
# 局部使用α-2激动剂眼药水，如布莫尼定酒石酸盐，在以下哪种情况下应避免使用？
# a) 两岁以下的儿童。
# b) 肾结石。
# c) 哮喘。
# d) 镰状细胞性贫血。
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# Language: japanese
# Question:
# α-2作動薬の点眼薬、例えばブリモニジン酒石酸塩の局所使用は、以下のどの状況で避けるべきですか？
# a) 2歳未満の子供。
# b) 腎結石。
# c) 喘息。
# d) 鎌状赤血球貧血。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 알파-2-작용제 안약, 예를 들어 브리모니딘 타르트레이트의 국소 사용은 다음 상황에서 피해야 합니다.
# a) 2세 미만의 어린이.
# b) 신장 결석.
# c) 천식.
# d) 겸상 적혈구 빈혈.
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 54:
# Language: chinese
# Question:
# 哪项发现最常与先天性原发性青光眼相关联？
# a) 视神经水肿。
# b) Descemet膜破裂。
# c) 晶状体脱位。
# d) 帐篷状周边前联合粘连。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 一次性先天性緑内障で最も一般的に関連する所見はどれですか？
# a) 視神経の浮腫。
# b) デスメ膜の破裂。
# c) レンズの脱臼。
# d) テント状の周辺前部癒着。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 주요 선천성 녹내장과 가장 흔히 관련된 소견은 무엇입니까?
# a) 시신경 부종.
# b) 데스메막의 파열.
# c) 수정체 탈구.
# d) 천막 모양의 말초 전방 유착.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 55:
# Language: chinese
# Question:
# 关于小孔试验，以下说法是正确的：
# a) 如果患者的视力没有改善，那么可能是弱视。
# b) 由于瞳孔缩小，减少了焦距深度。
# c) 减少了视网膜上的散光圈。
# d) 小孔的大小应在4到5毫米之间。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# ピンホールテストに関して、以下の記述が正しいと言えます：
# a) 患者の視力が改善されない場合、それは弱視の症例である。
# b) 瞳孔の縮小により焦点の深さが減少する。
# c) 網膜上の拡散円を減少させる。
# d) ピンホールのサイズは4mmから5mmの間であるべきである。
# Test #0:
# response
# ```json
# {
# ...
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 異常網膜対応に関して、正しい選択肢をマークしてください。
# a) それは単眼感覚適応の現象です。
# b) 小角偏位でより頻繁に起こります。
# c) 斜視手術後の二重視の保護因子と考えられています。
# d) 斜視手術後の再発防止の保護因子と考えられています。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 이상 망막 대응에 관하여 올바른 선택지를 표시하시오.
# a) 이것은 단안 감각 적응의 현상입니다.
# b) 이것은 작은 각도의 편차에서 더 자주 발생합니다.
# c) 이것은 사시 수술 후기의 복시에 대한 보호 요인으로 간주됩니다.
# d) 이것은 사시 수술 후기의 재발 방지에 대한 보호 요인으로 간주됩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 149:
# Language: chinese
# Question:
# 以下哪种并发症在注射肉毒杆菌毒素到内直肌后最为常见？
# a) 眼睑下垂。
# b) 眼眶后出血。
# c) 瞳孔散大。
# d) 瞳孔缩小。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 次のうち、内側直筋にボツリヌス毒素を注射した後に最も頻繁に発生する合併症はどれですか？
# a) 眼瞼下垂。
# b) 眼窩後出血。
# c) 散瞳。
# d) 縮瞳。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 다음 중 보툴리눔 독소를 내직근에 주입한 후 가장 흔한 합병증은 무엇입니까?
# a) 눈꺼풀 처짐.
# b) 안와 후방 출혈.
# c) 동공 확대.
# d) 동공 수축.
# Test #0:
# response
# ```json
# {
# 	"response": "a"
# }
# ```
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 150:
# Language: chinese
# Question:
# 关于由单眼（感觉性）视力低下引起的外斜视，请标出正确的选项。
# a) 它约占所有成人外斜视病例的2%。
# b) 配戴棱镜是首选治疗方法。
# c) 它通常与正常的立体视觉相关联。
# d) 偏斜度随时间增加是常见的。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 単眼（感覚的）視力低下による外斜視について、正しい選択肢をマークしてください。
# a) 成人の外斜視の約2％を占めます。
# b) プリズムの処方が治療の選択肢です。
# c) 通常、正常な立体視と関連しています。
# d) 時間の経過とともに偏位が増加することが一般的です。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 단안(감각적) 시력 저하로 인한 외사시에 대해 올바른 대안을 표시하십시오.
# a) 성인 외사시의 약 2%를 차지합니다.
# b) 프리즘 처방이 선택적 치료입니다.
# c) 보통 정상적인 입체시와 관련이 있습니다.
# d) 시간이 지남에 따라 편차가 증가하는 것이 일반적입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 151:
# Language: chinese
# Question:
# 斜视最常见的恶性头部位置补偿发生在以下哪种偏斜中？
# a) 部分调节性。
# b) 不共同性。
# c) 间歇性外斜视。
# d) 指挥官。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 斜視のために頭部を不自然な位置にすることが最も頻繁に起こるのは、以下のどの偏位ですか？
# a) 部分的に調節性のある。
# b) 不一致の。
# c) 断続的な外斜視。
# d) 指揮官。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 사시를 보상하기 위한 악성 머리 위치는 다음 편차 중 어느 것에서 가장 자주 발생합니까?
# a) 부분적으로 조절 가능함.
# b) 일관성 없음.
# c) 간헐적 외사시.
# d) 지휘관들.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 152:
# Language: chinese
# Question:
# 在Maddox测试中，将Maddox圆柱体放置在患者的眼前，右眼前是红色的，左眼前是无色的，两者都垂直放置。患者在观察一个光点时，报告看到红线向逆时针倾斜（从患者的角度看）。这最有可能是：
# a) 右眼内旋
# b) 右眼外旋
# c) 左眼内旋
# d) 左上斜肌功能亢进
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# Language: japanese
# Question:
# マドックス試験中、赤いマドックスシリンダーを右目の前に、無色のシリンダーを左目の前に、どちらも垂直に配置しました。患者は光点を観察した際、赤い線が反時計回りに傾いて見えると報告しました（患者の視点から）。これは最も可能性が高いのは：
# a) 右目の内旋
# b) 右目の外旋
# c) 左目の内旋
# d) 左上斜筋の過活動
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 매독스 검사 동안, 매독스 실린더가 환자의 눈 앞에 배치되었는데, 빨간색은 오른쪽 눈 앞에, 무색은 왼쪽 눈 앞에 세로로 배치되었습니다. 환자가 빛의 점을 관찰하면서, 빨간 선이 반시계 방향으로 기울어져 보인다고 보고했습니다 (환자의 관점에서). 가장 가능성이 높은 것은:
# a) 오른쪽 눈의 안구내회전
# b) 오른쪽 눈의 안구외회전
# c) 왼쪽 눈의 안구내회전
# d) 왼쪽 상사근의 과기능
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 153:
# Language: chinese
# Question:
# 关于泪腺多形性腺瘤，请标记正确的选项。
# a) 计算机断层扫描显示异质性和界限不清的病变。
# b) 最常见的情况是快速增长的肿块。
# c) 触诊时，肿瘤通常无痛。
# d) 女性更常见。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 涙腺の多形腺腫に関して、正しい選択肢をマークしてください。
# a) CTスキャンでは、異質で不明瞭な境界の病変が示されます。
# b) 最も一般的な状態は、急速に進行する成長の塊です。
# c) 触診では、腫瘍は一般的に無痛です。
# d) 女性により一般的です。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 눈물샘의 다형성 선종에 관하여 올바른 선택지를 표시하십시오.
# a) 컴퓨터 단층 촬영은 이질적이고 경계가 불분명한 병변을 보여줍니다.
# b) 가장 흔한 상태는 빠르게 진행하는 성장 덩어리입니다.
# c) 촉진 시, 종양은 일반적으로 통증이 없습니다.
# d) 여성에게 더 흔합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 154:
# Language: chinese
# Question:
# 关于白血病的眼眶侵犯，请标出正确的选项。
# a) 治疗通常对放疗不敏感。
# b) 治疗通常对化疗不敏感。
# c) 颗粒细胞肉瘤是与淋巴细胞性白血病最常相关的眼眶浸润。
# d) 影像检查显示的眼眶肿块通常会损害骨结构。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 白血病における眼窩の関与について、正しい選択肢をマークしてください。
# a) 治療は一般に放射線療法に対して感受性がありません。
# b) 治療は一般に化学療法に対して感受性がありません。
# c) 顆粒球性肉腫は、リンパ性白血病に最も頻繁に関連する眼窩浸潤です。
# d) 画像検査では、通常、骨構造を損なう眼窩の腫瘍が示されます。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: korean
# Question:
# 백혈병에서의 안와 침범에 관하여, 올바른 대안을 표시하십시오.
# a) 치료는 일반적으로 방사선 치료에 민감하지 않습니다.
# b) 치료는 일반적으로 화학 요법에 민감하지 않습니다.
# c) 과립구 육종은 림프구성 백혈병과 가장 자주 관련된 안와 침투입니다.
# d) 영상 검사는 일반적으로 뼈 구조를 손상시키는 안와 종양을 보여줍니다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 155:
# Language: chinese
# Question:
# 关于丛状眼眶神经纤维瘤，请标记正确的选项：
# a) 它恶性变的情况很少见。
# b) 在神经纤维瘤病患者中很少见。
# c) 它的预后良好，手术后复发率低。
# d) 它是无血管的，手术中肿瘤出血很少。
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: japanese
# Question:
# 次の文章を日本語に翻訳してください。
#
# 「神経線維腫症に関連する多形性眼窩神経線維腫について、正しい選択肢をマークしてください：
# a) 悪性変化は稀です。
# b) 神経線維腫症の患者にはめったに見られません。
# c) 手術後の再発率が低く、予後が良好です。
# d) 腫瘍は無血管であり、手術中の出血は稀です。」
# Test #0:
# response
# ```json
# {
# 	"response": "A"
# }
# ```
# {'response': 'A'}
# Language: korean
# Question:
# 다음 중 맞는 대안을 표시하십시오.
# a) 악성 변성은 드물다.
# b) 신경섬유종증 환자에서 거의 보이지 않는다.
# c) 수술 후 재발률이 낮아 예후가 좋다.
# d) 혈관이 없어 수술 중 종양에서 출혈이 드물다.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 156:
# Language: chinese
# Question:
# 以下哪种结膜的恶性上皮肿瘤最常见于鞘膜区？
# a) 黑色素瘤。
# b) 卡波西肉瘤。
# c) 鳞状细胞癌。
# d) 基底细胞癌。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 以下の悪性上皮腫瘍のうち、結膜の辺縁部に最も一般的に発生するのはどれですか？
# a) メラノーマ。
# b) カポジ肉腫。
# c) 扁平上皮癌。
# d) 基底細胞癌。
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# Language: korean
# Question:
# 결막의 악성 상피 종양 중에서 가장 흔하게 각막 경계부에서 발생하는 것은 무엇입니까?
# a) 흑색종.
# b) 카포시 육종.
# c) 편평세포암.
# d) 기저세포암.
# Test #0:
# response
# ```json
# {
# 	"response": "c"
# }
# ```
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 157:
# Language: chinese
# Question:
# 选择包含与白内障发展相关的三个因素的选项。
# a) 高度近视，长期使用维生素C和饮酒。
# b) 低能量辐射，长期使用皮质类固醇和暴露于蓝光。
# c) 吸烟，暴露于紫外线和之前的玻璃体切除术。
# d) 眼部创伤，糖尿病和高度远视。
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# Language: japanese
# Question:
# 以下の選択肢の中から、白内障の発症に関連する3つの要因が含まれているものを選んでください。
# a) 高度近視、ビタミンCの長期使用、アルコール消費。
# b) 低エネルギー放射線、コルチコステロイドの長期使用、ブルーライトへの露出。
# c) 喫煙、紫外線への露出、以前の硝子体切除術。
# d) 眼の外傷、糖尿病、高度遠視。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 다음 중 백내장 발생과 관련된 세 가지 요인을 포함하고 있는 대안을 확인하세요.
# a) 고도근시, 비타민 C의 장기간 사용 및 알코올 섭취.
# b) 저에너지 방사선, 코르티코스테로이드의 장기간 사용 및 청색광 노출.
# c) 흡연, 자외선 노출 및 이전의 유리체 절제술.
# d) 눈 부상, 당뇨병 및 고도원시.
# Test #0:
# response
# ```json
# {
# 	"response": "C"
# }
# ```
# {'response': 'C'}
# **************************************************
# **************************************************
# Question 158:
# Language: chinese
# Question:
# 关于先天性和婴儿期白内障，请判断以下陈述的真实性（真（T）或假（F）），并标出正确选项。
#
# I - 当不透明度双侧且严重时，第一只眼和第二只眼之间的手术间隔应尽可能短，通常不超过一周。
# II - 在完全不透明的情况下，应尽早进行手术，最好在三到四个月大之间。
# III - 先天性白内障是产科医院红光反射测试变化的最常见原因。
# IV - 出生时正常的红光反射足以在两岁之前的随访中早期检测先天性异常。
#
# a) I: 真；II: 假；III: 真；IV: 假。
# b) I: 假；II: 真；III: 假；IV: 真。
# c) I: 假；II: 假；III: 真；IV: 假。
# d) I: 真；II: 真；III: 真；IV: 真。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# I - True. When the opacity is bilateral and severe, it is crucial to minimize the interval between surgeries on the first and second eye to prevent amblyopia and to promote equal visual input to both eyes. The interval generally does not exceed one week.
#
# II - True. In cases of total opacities, early surgery is critical to allow light entry and visual development. Surgery is preferably performed between three and four months of age to optimize visual outcomes and reduce the risk of amblyopia.
#
# III - True. Congenital cataract is a common cause of an abnormal red reflex test in newborns, which is often detected during routine screening in maternity hospitals.
#
# IV - False. While a normal red reflex at birth is a good sign, it is not sufficient alone for the early detection of all congenital anomalies. Continuous and comprehensive follow-up examinations are necessary to identify and manage any developing conditions up to two years of age and beyond.
#
# Correct answer: d) I: True; II: True; III: True; IV: True.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 선천성 및 유아기 백내장에 대해 아래의 진술을 참(T) 또는 거짓(F)으로 판단하고 올바른 대안을 표시하십시오.
#
#  I - 혼탁이 양측성이고 심각한 경우, 첫 번째 눈과 두 번째 눈의 수술 간격은 최소화되어야 하며 일반적으로 일주일을 넘지 않습니다.
#  II - 전체적인 혼탁의 경우, 수술은 가능한 한 빨리, 선호적으로는 세에서 네 달 사이에 수행되어야 합니다.
#  III - 선천성 백내장은 산부인과에서 적목 반사 검사의 변화를 일으키는 가장 흔한 원인입니다.
#  IV - 출생 시 정상적인 적목 반사는 2년까지의 추적 관찰에서 선천성 이상을 조기에 발견하기에 충분합니다.
#
# a) I: 참; II: 거짓; III: 참; IV: 거짓.
# b) I: 거짓; II: 참; III: 거짓; IV: 참.
# c) I: 거짓; II: 거짓; III: 참; IV: 거짓.
# d) I: 참; II: 참; III: 참; IV: 참.
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# **************************************************
# **************************************************
# Question 159:
# Language: chinese
# Question:
# 关于晶状体发育的先天异常和失败，请标记正确的选项。
# a) 在微球形晶状体中观察到的间歇性瞳孔阻塞是由于虹膜在晶状体中间周边的接触，这是由于侧向直径增加所致。
# b) Marfan综合症中的晶状体脱位通常是上方和颞侧的，可能会引起由屈光不对称引起的弱视。
# c) 在半乳糖血症中，红光反射测试中可以观察到类似“油滴”的中央阴影，这在其他疾病中不会出现。
# d) 在同型半胱氨酸尿症中，晶状体位移通常是双侧的、对称的，并且在出生时就存在。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 先天異常と水晶体の発達障害に関して、正しい選択肢をマークしてください。
# a) ミクロスフェロファキーで観察される間欠的な瞳孔ブロックは、側方径の増加により虹彩が水晶体の中間周辺に触れるために起こります。
# b) マルファン症候群における水晶体脱臼は、通常、上方および側方に最も多く見られ、屈折不正による弱視を引き起こす可能性があります。
# c) ガラクトース血症では、赤色反射検査で「オイルドロップ」に似た中央の影が観察されることがありますが、他の疾患では起こりません。
# d) ホモシスチン尿症では、水晶体の変位は通常、両側性で対称的で、出生時から存在します。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 레이젠스의 선천적 이상 및 발달 실패와 관련하여 올바른 대안을 표시하십시오.
# a) 미세구형안에서 관찰되는 간헐적 동공 차단은 수정체의 측면 직경이 증가함에 따라 홍채가 수정체의 중간 주변부와 접촉하기 때문에 발생합니다.
# b) 마르판 증후군에서 수정체 탈구는 대개 상방 및 측두방향으로 가장 흔하며 굴절 비대칭으로 인한 약시를 유발할 수 있습니다.
# c) 갈락토세미아에서는 다른 질병에서는 발생하지 않는 "오일 방울"과 유사한 중앙 그림자가 적목 반사 검사에서 관찰될 수 있습니다.
# d) 호모시스티뉴리아에서는 수정체 이탈이 보통 양측성이며 대칭적이고 출생 시부터 존재합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 160:
# Language: chinese
# Question:
# 在白内障超声乳化手术中进行眼眶后阻滞后，患者在麻醉注射后五分钟内出现意识逐渐丧失、癫痫发作和呼吸停止。选择正确描述此案例中最可能的并发症及其可能的预防措施的选项。
# a) 眼内注射 - 观察眼球和针头的联合移动后再注射。
# b) 血管内注射 - 手术前停用抗凝血剂或抗血小板药物。
# c) 蛛网膜下腔注射 - 针头插入深度不超过30毫米。
# d) 眼眶后出血 - 注射前抽吸并检查是否有血性内容物。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 白内障乳化手術のための後眼窩ブロック後、患者は麻酔注射後5分で意識の進行性喪失、発作、呼吸停止を起こしました。この場合で最も可能性の高い合併症とその予防策を正しく説明している選択肢を選んでください。
# a) 眼球内注射 - 注射前に眼球と針の共同運動を観察する。
# b) 血管内注射 - 手術前に抗凝固剤または抗血小板剤の使用を中止する。
# c) くも膜下腔への注射 - 針を30mm未満の深さで挿入する。
# d) 後眼窩出血 - 注射前に吸引して血液成分の有無を確認する。
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# Language: korean
# Question:
# 백내장 초음파 파쇄술을 위한 후안구 봉쇄 후, 환자는 마취 주사 후 5분 만에 의식 상실, 발작 및 호흡 정지가 점진적으로 진행되었습니다. 이 경우 가장 가능성이 높은 합병증과 예방 조치를 올바르게 설명한 대안을 확인하십시오.
# a) 안구 내 주입 - 주사하기 전에 안구와 바늘의 공동 움직임을 관찰하십시오.
# b) 혈관 내 주입 - 수술 전 항응고제 또는 항혈소판제를 중단하십시오.
# c) 지주막하 공간 주입 - 바늘을 30mm 이하로 삽입하십시오.
# d) 후안구 출혈 - 주입 전에 흡인하여 혈액성분의 존재를 확인하십시오.
# Test #0:
# response
# ```json
# {
# 	"response": "b"
# }
# ```
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 161:
# Language: chinese
# Question:
# 关于用硅油覆盖的眼睛的生物测量学，可以正确地说：
# a) 通过超声测量的轴向长度与实际值相比被错误地减少了。
# b) 低相干反射测量法在这种情况下不能使用。
# c) 前房深度测量必须在仰卧位进行。
# d) 在这些情况下，部分相干干涉测量法比超声波测量法更可取。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# シリコンオイルで覆われた目の生体計測に関して、以下の記述が正しいと言えます：
# a) 超音波による軸長の測定は、実際の値に比べて誤って短く測定されます。
# b) 低コヒーレンス反射計はこの状況では使用できません。
# c) 前房深度の測定は仰向けの位置で行う必要があります。
# d) この場合、部分コヒーレンス干渉計は超音波よりも好ましいです。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 실리콘 오일로 덮인 눈의 생체 인식에 관하여 다음과 같이 말할 수 있습니다:
# a) 초음파로 측정된 축 길이는 실제 값에 비해 잘못 감소되었다고 볼 수 있습니다.
# b) 저간섭성 반사계측법은 이 상황에서 사용할 수 없습니다.
# c) 전방심도 측정은 반드시 누운 자세에서 수행되어야 합니다.
# d) 부분적인 일관성 간섭계측법이 이러한 경우 초음파 검사보다 선호됩니다.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 162:
# Language: chinese
# Question:
# 检查包含围手术期发生松弛性虹膜综合症的药物以及在这些情况下恢复散瞳的适当干预措施的选项。
# a) 氯丙嗪 - 虹膜牵引器。
# b) 多沙唑嗪 - Beehler扩瞳器。
# c) 坦索罗辛 - 括约肌切除术。
# d) 阿托品 - 虹膜扩张环。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# 選択肢の中で、術中に弛緩性虹彩症候群の発生に関連する薬剤と、これらの場合に散瞳を回復する適切な介入をそれぞれ含むものを選んでください。
# a) クロルプロマジン - 虹彩リトラクター。
# b) ドキサゾシン - ビーラー拡張器。
# c) タムスロシン - 括約筋切除。
# d) アトロピン - 虹彩拡張リング。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 수술 기간 동안 편평 홍채 증후군의 발생과 관련된 약물과 이러한 경우 동공 확대를 복원하는 적절한 개입을 각각 포함하는 대안을 확인하십시오.
# a) 클로르프로마진 - 홍채 리트랙터.
# b) 독사조신 - 비흘러 확대기.
# c) 탐술로신 - 괄약근 절제술.
# d) 아트로핀 - 홍채 확장 링.
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# **************************************************
# **************************************************
# Question 163:
# Language: chinese
# Question:
# 关于白内障手术中预防眼内炎的措施，请选择正确的选项。
# a) 如果对碘伏有禁忌症，应在手术前五天使用局部抗生素眼药水。
# b) 主要风险因素包括免疫抑制、糖尿病、睑炎、结膜炎、后囊破裂和玻璃体丢失。
# c) 应采用房水间使用庆大霉素，特别是在之前有玻璃体切除术的病例中。
# d) 最常见的病原体是由于手术材料和人工晶状体的不当消毒导致的细菌。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: japanese
# Question:
# 白内障手術における眼内炎の予防について、正しい選択肢をマークしてください。
# a) ポビドンヨードに対する禁忌がある場合は、手術の5日前から局所的に抗生物質の点眼薬を使用すべきです。
# b) 主なリスク因子には、免疫抑制、糖尿病、眼瞼炎、結膜炎、後嚢の破裂、硝子体喪失が含まれます。
# c) 以前の硝子体切除術と関連する場合には、特にジェンタマイシンの眼内投与を採用すべきです。
# d) 最も頻繁な病原体は、手術用材料や眼内レンズの不適切な滅菌からの細菌です。
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# Language: korean
# Question:
# 백내장 수술에서 안내염 예방과 관련하여 올바른 대안을 표시하십시오.
# a) 포비돈 요오드에 대한 금기 사항이 있는 경우, 수술 전 5일 동안 국소 항생제 안약을 사용해야 합니다.
# b) 주요 위험 요인에는 면역 억제, 당뇨병, 안검염, 결막염, 후방 캡슐 파열 및 유리체 손실이 포함됩니다.
# c) 이전 유리체 절제술과 관련된 경우에는 안구 내 젠타마이신 사용이 채택되어야 합니다.
# d) 가장 흔한 원인균은 수술 재료와 안구 내 렌즈의 부적절한 멸균으로 인한 박테리아입니다.
# Test #0:
# response
# ```json
# {
# 	"response": "B"
# }
# ```
# {'response': 'B'}
# **************************************************
# **************************************************
# Question 164:
# Language: chinese
# Question:
# 在使用分离征服技术进行核心断裂后，可以看到角膜切口侧部有白色部分和组织收缩，并且灌注液通过形成的间隙泄漏。在下列选项中，哪一种方法能有效防止上述并发症的发生？
# a) 降低吸引流速并使切口更窄。
# b) 使用更大直径的尖端和更小直径的同轴灌注套管。
# c) 保持尖端与切口壁等距离并使用脉冲超声。
# d) 用凝聚性粘弹体填充前房并使用连续超声。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: japanese
# Question:
# コアフラクチャーを分割統治法で行った後、角膜切開の側部に白っぽい部分と組織の収縮が見られ、形成された隙間から灌流液が漏れ出ています。以下の選択肢の中で、記述された合併症の発生を防ぐのに効果的なものはどれでしょうか？
# a) 吸引流量を減らし、切開を狭くする。
# b) より大きな直径のチップとより小さな直径の同軸灌流スリーブを使用する。
# c) チップを切開壁から等距離に保ち、パルス超音波を使用する。
# d) 前房を凝集性ビスコエラスティックで満たし、連続超音波を使用する。
# Test #0:
# response
# ```json
# {
# 	"response": "D"
# }
# ```
# {'response': 'D'}
# Language: korean
# Question:
# 분할 정복 기법으로 핵 파절을 수행한 후, 각막 절개의 측면 부분에서 하얀 부분과 조직의 수축이 관찰되며, 형성된 틈을 통해 관류 용액이 새는 것을 볼 수 있습니다. 아래 대안 중에서 설명된 합병증의 발생을 방지하는 데 효과적인 것은 무엇입니까?
# a) 흡입 유량을 줄이고 절개를 좁게 합니다.
# b) 더 큰 직경의 팁과 더 작은 직경의 동축 관류 슬리브를 사용합니다.
# c) 팁을 절개 벽에서 동일한 거리를 유지하고 펄스 초음파를 사용합니다.
# d) 전방을 응집성 점탄성 물질로 채우고 연속 초음파를 사용합니다.
# Test #0:
# response
# ```json
# {
# 	"response": "d"
# }
# ```
# {'response': 'd'}
# **************************************************

# %% [markdown]
# #### See the results

# %%
import os
MODEL = os.path.basename(MODEL)

if N_REPETITIONS > 1:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}_{N_REPETITIONS}Repetitions.csv")
else:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}.csv")

df
# Out:
#       ID  year        test                theme subtheme  \
# 0      1  2022   Teórica I             Anatomia   cornea
# 1      2  2022   Teórica I             Anatomia   retina
# 2      3  2022   Teórica I             Anatomia   cornea
# 3      4  2022   Teórica I             Anatomia   cornea
# 4      5  2022   Teórica I             Anatomia   cornea
# ..   ...   ...         ...                  ...      ...
# 159  161  2022  Teórica II  Cristalino/Catarata      NaN
# 160  162  2022  Teórica II  Cristalino/Catarata      NaN
# 161  163  2022  Teórica II  Cristalino/Catarata      NaN
# 162  164  2022  Teórica II  Cristalino/Catarata      NaN
# 163  165  2022  Teórica II  Cristalino/Catarata      NaN
#
#                                             portuguese  \
# 0    Em qual região ocular células caliciformes são...
# 1    Assinale a alternativa que melhor correlaciona...
# 2    Ordene as três denominações celulares encontra...
# 3    Sobre a membrana de Descemet da córnea, é corr...
# 4    Sobre a camada lipídica do filme lacrimal, ass...
# ..                                                 ...
# 159  Após bloqueio retrobulbar para realização de c...
# 160  Sobre a biometria em olhos tamponados por óleo...
# 161  Assinale a alternativa que contém, respectivam...
# 162  Sobre a prevenção de endoftalmite em cirurgia ...
# 163  Após realizar as fraturas do núcleo com a técn...
#
#                                                spanish  \
# 0    ¿En qué región ocular se encuentran fisiológic...
# 1    Marque la alternativa que mejor correlaciona l...
# 2    Ordene los tres nombres de células que se encu...
# 3    Con respecto a la membrana de la córnea de Des...
# 4    Respecto a la capa lipídica de la película lag...
# ..                                                 ...
# 159  Tras el bloqueo retrobulbar para realizar la c...
# 160  Respecto a la biometría en ojos tamponados con...
# 161  Seleccionar la alternativa que contenga, respe...
# 162  En cuanto a la prevención de endoftalmitis en ...
# 163  Después de realizar las fracturas del núcleo c...
#
#                                                english  \
# 0    In which ocular region are caliciform cells ph...
# 1    Mark the alternative that best correlates the ...
# 2    Order the three cell names found in the cornea...
# 3    Regarding Descemet's membrane of the cornea, i...
# 4    About the lipidic layer of the lacrimal film, ...
# ..                                                 ...
# 159  After retrobulbar block for phacoemulsificatio...
# 160  Regarding biometrics in eyes covered with sili...
# 161  Check the alternative that contains, respectiv...
# 162  Regarding the prevention of endophthalmitis in...
# 163  After performing the core fractures with the d...
#
#                                                tagalog answer  \
# 0    Aling bahagi ng mata ay kung saan matatagpuan ...      D
# 1    Ipagpares ang bahagi ng retina sa Hanay B sa t...      B
# 2    Ipagsunud-sunod ang mga cells ng corneal epith...      A
# 3    Tama tungkol sa Descemet's membrane ng cornea:...      C
# 4    Piliin ang tamang sagot tungkol sa lipid layer...      B
# ..                                                 ...    ...
# 159  Matapos ang retrobulbar block para sa phacoemu...      C
# 160  Alin sa mga sumusunod na pahayag patungkol sa ...      D
# 161  Alin sa mga sumusunod na tambalan patungkol sa...      A
# 162  Alin sa mga sumusunod na pamamaraan upang mapi...      B
# 163  Matapos isagawa ang core fractures gamit ang d...      C
#
#                                                chinese  \
# 0    在哪个眼部区域生理上可以找到杯状细胞？\na) 角膜。\nb) 角膜巩膜缘。\nc) 灰线。...
# 1    将以下选项与相应的眼部组织的组织学特征进行匹配：\n\nI. 由连接复合体紧密连接在一起的单...
# 2    将角膜上皮中发现的三种细胞名称按顺序排列，从最表层的开始，然后是中间层，最后是深层。\na)...
# 3    关于角膜的Descemet膜，以下说法正确的是：\na) 内皮细胞不参与其形成。\nb) 成...
# 4    关于泪膜的脂质层，请选择正确的答案。\na) 其目的是稳定由睑板腺和Manz腺分泌的泪膜。\...
# ..                                                 ...
# 159  在白内障超声乳化手术中进行眼眶后阻滞后，患者在麻醉注射后五分钟内出现意识逐渐丧失、癫痫发作和...
# 160  关于用硅油覆盖的眼睛的生物测量学，可以正确地说：\na) 通过超声测量的轴向长度与实际值相比...
# 161  检查包含围手术期发生松弛性虹膜综合症的药物以及在这些情况下恢复散瞳的适当干预措施的选项。\n...
# 162  关于白内障手术中预防眼内炎的措施，请选择正确的选项。\na) 如果对碘伏有禁忌症，应在手术前...
# 163  在使用分离征服技术进行核心断裂后，可以看到角膜切口侧部有白色部分和组织收缩，并且灌注液通过形...
#
#                                               japanese  \
# 0    カリシフォルム細胞は生理的にどの眼部に存在しますか？\na) 角膜。\nb) 角膜強膜辺縁。...
# 1    以下の選択肢の中から、組織学的特徴とそれに対応する眼の組織を最もよく関連付けるものを選びなさ...
# 2    角膜上皮に見られる3つの細胞名を、最も表面的なものから始めて、中間のもの、深いものの順に並べ...
# 3    角膜のデスメ膜について、以下の記述が正しいと言えます：\na) 内皮細胞はその形成に関与して...
# 4    涙膜の脂質層について、正しい答えを選んでください。\na) その目的は、マイボーム腺とマンツ...
# ..                                                 ...
# 159  白内障乳化手術のための後眼窩ブロック後、患者は麻酔注射後5分で意識の進行性喪失、発作、呼吸停...
# 160  シリコンオイルで覆われた目の生体計測に関して、以下の記述が正しいと言えます：\na) 超音波...
# 161  選択肢の中で、術中に弛緩性虹彩症候群の発生に関連する薬剤と、これらの場合に散瞳を回復する適切...
# 162  白内障手術における眼内炎の予防について、正しい選択肢をマークしてください。\na) ポビドン...
# 163  コアフラクチャーを分割統治法で行った後、角膜切開の側部に白っぽい部分と組織の収縮が見られ、形...
#
#                                                 korean responses_chinese  \
# 0    어느 눈 부위에서 goblet 세포가 생리적으로 발견됩니까?\na) 각막.\nb) ...                 D
# 1    조직학적 특성과 해당 안구 조직을 가장 잘 연관시키는 선택지를 표시하시오:\n\nI...                 b
# 2    각막 상피에서 발견되는 세 가지 세포 이름을 가장 표면적인 것부터 시작하여 중간, ...                 A
# 3    각막의 데스메막에 관하여 다음과 같이 말할 수 있습니다:\na) 내피세포는 그 형성...                 B
# 4    눈물막의 지질층에 대해 올바른 답을 선택하십시오.\na) 그 목적은 마이봄샘과 만즈...                 B
# ..                                                 ...               ...
# 159  백내장 초음파 파쇄술을 위한 후안구 봉쇄 후, 환자는 마취 주사 후 5분 만에 의식...                 B
# 160  실리콘 오일로 덮인 눈의 생체 인식에 관하여 다음과 같이 말할 수 있습니다:\na)...                 D
# 161  수술 기간 동안 편평 홍채 증후군의 발생과 관련된 약물과 이러한 경우 동공 확대를 ...                 D
# 162  백내장 수술에서 안내염 예방과 관련하여 올바른 대안을 표시하십시오.\na) 포비돈 ...                 B
# 163  분할 정복 기법으로 핵 파절을 수행한 후, 각막 절개의 측면 부분에서 하얀 부분과 ...                 D
#
#     responses_chinese_0 responses_japanese responses_japanese_0  \
# 0                     D                  d                    d
# 1                     b                  b                    b
# 2                     A                  A                    A
# 3                     B                  B                    B
# 4                     B                  B                    B
# ..                  ...                ...                  ...
# 159                   B                  d                    d
# 160                   D                  D                    D
# 161                   D                  D                    D
# 162                   B                  B                    B
# 163                   D                  D                    D
#
#     responses_korean responses_korean_0
# 0                  B                  B
# 1                  b                  b
# 2                  A                  A
# 3                  B                  B
# 4                  B                  B
# ..               ...                ...
# 159                b                  b
# 160                D                  D
# 161                D                  D
# 162                B                  B
# 163                d                  d
#
# [164 rows x 19 columns]

# %% [markdown]
# ### Data Analysis

# %%
TEMPERATURE = str(TEMPERATURE).replace('.', '_')

run_analysis(model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, languages=LANGUAGES)
# Out:
# n_repetitions should be a positive integer, not 0
# n_repetitions will be set to 1
# /Users/davidrestrepo/LLMs Bias/Language/src/data_analysis.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(languages, fontsize=16)
#      theme  match_chinese  match_japanese  match_korean  Total  \
# 0  anatomy             14              11             9     21
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 66.666667                  52.380952
#
#    korean_ratio_percentage
# 0                42.857143
#     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  cornea              6               3             1     10
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      60.0                       30.0
#
#    korean_ratio_percentage
# 0                     10.0
#         theme  match_chinese  match_japanese  match_korean  Total  \
# 0  embryology              1               1             1      2
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      50.0                       50.0
#
#    korean_ratio_percentage
# 0                     50.0
#       theme  match_chinese  match_japanese  match_korean  Total  \
# 0  genetics              0               2             1      2
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                       0.0                      100.0
#
#    korean_ratio_percentage
# 0                     50.0
#       theme  match_chinese  match_japanese  match_korean  Total  \
# 0  glaucoma              5               4             4      9
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 55.555556                  44.444444
#
#    korean_ratio_percentage
# 0                44.444444
#       theme  match_chinese  match_japanese  match_korean  Total  \
# 0  oncology              1               1             1      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                      100.0
#
#    korean_ratio_percentage
# 0                    100.0
#           theme  match_chinese  match_japanese  match_korean  Total  \
# 0  pharmacology              7               7             3      9
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 77.777778                  77.777778
#
#    korean_ratio_percentage
# 0                33.333333
#         theme  match_chinese  match_japanese  match_korean  Total  \
# 0  refraction             16              14            13     31
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 51.612903                   45.16129
#
#    korean_ratio_percentage
# 0                41.935484
#     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  retina              6              10             5     12
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      50.0                  83.333333
#
#    korean_ratio_percentage
# 0                41.666667
#             theme  match_chinese  match_japanese  match_korean  Total  \
# 0  contact lenses              1               0             0      3
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 33.333333                        0.0
#
#    korean_ratio_percentage
# 0                      0.0
#     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  cornea              6               3             1     10
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      60.0                       30.0
#
#    korean_ratio_percentage
# 0                     10.0
#          theme  match_chinese  match_japanese  match_korean  Total  \
# 0  cornea/lens              1               0             1      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                        0.0
#
#    korean_ratio_percentage
# 0                    100.0
#       theme  match_chinese  match_japanese  match_korean  Total  \
# 0  glaucoma              5               4             4      9
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 55.555556                  44.444444
#
#    korean_ratio_percentage
# 0                44.444444
#               theme  match_chinese  match_japanese  match_korean  Total  \
# 0  glaucoma/uveitis              1               1             1      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                      100.0
#
#    korean_ratio_percentage
# 0                    100.0
#            theme  match_chinese  match_japanese  match_korean  Total  \
# 0  lens/cataract              4               3             4      8
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      50.0                       37.5
#
#    korean_ratio_percentage
# 0                     50.0
#         theme  match_chinese  match_japanese  match_korean  Total  \
# 0  low vision              0               0             0      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                       0.0                        0.0
#
#    korean_ratio_percentage
# 0                      0.0
#                  theme  match_chinese  match_japanese  match_korean  Total  \
# 0  neuro-ophthalmology              3               4             3      7
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 42.857143                  57.142857
#
#    korean_ratio_percentage
# 0                42.857143
#                     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  ocular plastic surgery              9               9             9     16
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     56.25                      56.25
#
#    korean_ratio_percentage
# 0                    56.25
#                              theme  match_chinese  match_japanese  \
# 0  oncology/ocular plastic surgery              2               2
#
#    match_korean  Total  chinese_ratio_percentage  japanese_ratio_percentage  \
# 0             1      3                 66.666667                  66.666667
#
#    korean_ratio_percentage
# 0                33.333333
#     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  optics              1               1             0      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                      100.0
#
#    korean_ratio_percentage
# 0                      0.0
#                theme  match_chinese  match_japanese  match_korean  Total  \
# 0  optics/refraction              1               1             1      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                      100.0
#
#    korean_ratio_percentage
# 0                    100.0
#           theme  match_chinese  match_japanese  match_korean  Total  \
# 0  pharmacology              7               7             3      9
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 77.777778                  77.777778
#
#    korean_ratio_percentage
# 0                33.333333
#                    theme  match_chinese  match_japanese  match_korean  Total  \
# 0  pharmacology/glaucoma              1               0             1      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                        0.0
#
#    korean_ratio_percentage
# 0                    100.0
#         theme  match_chinese  match_japanese  match_korean  Total  \
# 0  refraction             16              14            13     31
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 51.612903                   45.16129
#
#    korean_ratio_percentage
# 0                41.935484
#                    theme  match_chinese  match_japanese  match_korean  Total  \
# 0  refraction/low vision              0               0             0      2
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                       0.0                        0.0
#
#    korean_ratio_percentage
# 0                      0.0
#                 theme  match_chinese  match_japanese  match_korean  Total  \
# 0  refractive surgery              2               1             1      2
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                     100.0                       50.0
#
#    korean_ratio_percentage
# 0                     50.0
#     theme  match_chinese  match_japanese  match_korean  Total  \
# 0  retina              6              10             5     12
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      50.0                  83.333333
#
#    korean_ratio_percentage
# 0                41.666667
#              theme  match_chinese  match_japanese  match_korean  Total  \
# 0  retina/oncology              0               0             0      1
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                       0.0                        0.0
#
#    korean_ratio_percentage
# 0                      0.0
#         theme  match_chinese  match_japanese  match_korean  Total  \
# 0  strabismus              6               5             5     11
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                 54.545455                  45.454545
#
#    korean_ratio_percentage
# 0                45.454545
#      theme  match_chinese  match_japanese  match_korean  Total  \
# 0  uveitis              3               2             3      8
#
#    chinese_ratio_percentage  japanese_ratio_percentage  \
# 0                      37.5                       25.0
#
#    korean_ratio_percentage
# 0                     37.5

# %%
N_REPETITIONS = 1 if N_REPETITIONS < 1 else N_REPETITIONS
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv')
# Out:
#           test  year                            theme  match_chinese  \
# 0    Teórica I  2022                          anatomy             14
# 1    Teórica I  2022                           cornea              1
# 2    Teórica I  2022                       embryology              1
# 3    Teórica I  2022                         genetics              0
# 4    Teórica I  2022                         glaucoma              1
# 5    Teórica I  2022                         oncology              1
# 6    Teórica I  2022                     pharmacology              3
# 7    Teórica I  2022                       refraction              6
# 8    Teórica I  2022                           retina              1
# 9   Teórica II  2022                   contact lenses              1
# 10  Teórica II  2022                           cornea              5
# 11  Teórica II  2022                      cornea/lens              1
# 12  Teórica II  2022                         glaucoma              4
# 13  Teórica II  2022                 glaucoma/uveitis              1
# 14  Teórica II  2022                    lens/cataract              4
# 15  Teórica II  2022                       low vision              0
# 16  Teórica II  2022              neuro-ophthalmology              3
# 17  Teórica II  2022           ocular plastic surgery              9
# 18  Teórica II  2022  oncology/ocular plastic surgery              2
# 19  Teórica II  2022                           optics              1
# 20  Teórica II  2022                optics/refraction              1
# 21  Teórica II  2022                     pharmacology              4
# 22  Teórica II  2022            pharmacology/glaucoma              1
# 23  Teórica II  2022                       refraction             10
# 24  Teórica II  2022            refraction/low vision              0
# 25  Teórica II  2022               refractive surgery              2
# 26  Teórica II  2022                           retina              5
# 27  Teórica II  2022                  retina/oncology              0
# 28  Teórica II  2022                       strabismus              6
# 29  Teórica II  2022                          uveitis              3
#
#     match_japanese  match_korean  Total
# 0               11             9     21
# 1                1             0      1
# 2                1             1      2
# 3                2             1      2
# 4                1             1      1
# 5                1             1      1
# 6                3             2      3
# 7                5             5     12
# 8                1             0      1
# 9                0             0      3
# 10               2             1      9
# 11               0             1      1
# 12               3             3      8
# 13               1             1      1
# 14               3             4      8
# 15               0             0      1
# 16               4             3      7
# 17               9             9     16
# 18               2             1      3
# 19               1             0      1
# 20               1             1      1
# 21               4             1      6
# 22               0             1      1
# 23               9             8     19
# 24               0             0      2
# 25               1             1      2
# 26               9             5     11
# 27               0             0      1
# 28               5             5     11
# 29               2             3      8

# %%
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv').sum()
# Out:
# test              Teórica ITeórica ITeórica ITeórica ITeórica IT...
# year                                                          60660
# theme             anatomycorneaembryologygeneticsglaucomaoncolog...
# match_chinese                                                    91
# match_japanese                                                   82
# match_korean                                                     68
# Total                                                           164
# dtype: object
