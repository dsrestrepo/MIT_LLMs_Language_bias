# %% [markdown]
# # Evaluate Classification

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Load the API key and libaries.

# %%
from src.Language_Evaluation_LC import llm_language_evaluation
from src.data_analysis import run_analysis
import pandas as pd

# %% [markdown]
# #### Load the Constants

# %%
PATH = 'data/full_dataset_translated.csv'
MODEL = "meta-llama/Llama-2-70b-chat-hf"
TEMPERATURE = 0.0
N_REPETITIONS = 0
REASONING = False
LANGUAGES = ['hindi', 'french']

# %% [markdown]
# #### Run The Experiments:

# %%
# Run evaluation:
llm_language_evaluation(path=PATH, model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, reasoning=REASONING, languages=LANGUAGES)
# Out:
# N_REPETITIONS should be a positive integer, not 0
# N_REPETITIONS will be set to 1
# **************************************************
# Question 1:
# Language: hindi
# Question:
# Caliciform koṣikāeṁ kis netra kṣetra meṁ kriyātmak rūp se pāī jātī haiṁ?
# a) Korneā.
# b) Korneosklēral limbas.
# c) Grē rēkhā.
# d) Arddhchandrākār fold.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the structure that connects the cornea and the sclera in the eye. The correct answer is b) Corneoscleral limbus.
#
# The other options are not correct:
#
# * a) Cornea is the transparent outer layer of the eye, but it is not the structure that connects the cornea and the sclera.
# * c) The iris (Grē rēkhā) is the colored part of the eye that controls the amount of light entering the eye, but it is not the structure that connects the cornea and the sclera.
# * d) The anterior chamber angle (Arddhchandrākār fold) is the angle between the cornea and the iris, but it is not the structure that connects the cornea and the sclera.
# {'response': 'b'}
# Language: french
# Question:
# Dans quelle région oculaire trouve-t-on physiologiquement des cellules caliciformes ?
# a) Cornée.
# b) Limbes cornéoscléral.
# c) Ligne grise.
# d) Repli semi-lunaire.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"  // Option b: Limbes cornéoscléral
# }
# ```
#
# Explanation:
#
# Les cellules caliciformes sont des cellules spécialisées de la région oculaire qui produisent des protéines impliquées dans la formation de la membrane basale de la cornée. Ces cellules sont trouvées dans les limbes cornéoscléraux, qui sont des replis de la conjonctive qui entourent la cornée. Les limbes cornéoscléraux sont composés de deux couches de tissu : la couche externe, appelée épithélium pneumatique, et la couche interne, appelée stroma conjonctif. Les cellules caliciformes sont situées dans la couche interne, en contact avec la cornée.
#
# La cornée (option a) est la couche transparente de tissu à la surface de l'œil, mais elle ne contient pas de cellules caliciformes. La ligne grise (option c) est une zone de transition entre la cornée et l'iris, mais elle ne contient pas non plus de cellules caliciformes. Le repli semi-lunaire (option d) est une structure de la conjonctive qui se trouve à la jonction de la cornée et de l'iris, mais il n'est pas associé à la présence de cellules caliciformes.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 2:
# Language: hindi
# Question:
# Nimnlikhit path ka romanized hindi mein anuvaad karein:
#
# Mark the alternative that best correlates the histological characteristics with the respective ocular tissues:
#
# I. Monolayer of cells tightly joined together by junctional complexes.
# II. Parallel and regular striations observed under optical microscopy, perpendicular to the epithelium.
# III. It contains bipolar cells, amacrine cells, horizontal cells and Muller cells.
# IV. It contains magnocellular, parvocellular and coniocellular cells.
#
# A. Photoreceptors.
# B. Retinal pigmented epithelium.
# C. Retinal ganglionic layer.
# D. Inner nuclear layer.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
#
# Romanized Hindi:
# Vikalp ko chinhit karein jo histological visheshtao ko sambandhit aankhon ke tissues ke sath sabse achhi tarah se milata hai:
#
# I. Ek parat ke kooshikayein jo junctional complexes ke dwara ek saath jodi hui hain.
# II. Optical microscopy ke neeche parallel aur regular striations dekhe gaye, jo epithelium ke perpendicular hain.
# III. Isme bipolar cells, amacrine cells, horizontal cells aur Muller cells shamil hain.
# IV. Isme magnocellular, parvocellular aur coniocellular cells shamil hain.
#
# A. Photoreceptors.
# B. Retinal pigmented epithelium.
# C. Retinal ganglionic layer.
# D. Inner nuclear layer.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# I. Monolayer of cells tightly joined together by junctional complexes - This description matches with the characteristics of the retinal pigmented epithelium (RPE), which is a monolayer of cells that forms the outer layer of the retina and is tightly joined together by tight junctions.
#
# II. Parallel and regular striations observed under optical microscopy, perpendicular to the epithelium - This description matches with the characteristics of the photoreceptors, which are arranged in a parallel and regular pattern and can be observed under optical microscopy.
#
# III. It contains bipolar cells, amacrine cells, horizontal cells and Muller cells - This description matches with the characteristics of the inner nuclear layer, which contains these types of cells.
#
# IV. It contains magnocellular, parvocellular and coniocellular cells - This description matches with the characteristics of the retinal ganglionic layer, which contains these types of cells.
#
# Therefore, the correct answer is option b: I: B; II: A; III: D; IV: C.
# {'response': 'b'}
# Language: french
# Question:
# Marquez l'alternative qui corrèle le mieux les caractéristiques histologiques avec les tissus oculaires respectifs :
#
# I. Couche monocellulaire de cellules étroitement jointes par des complexes jonctionnels.
# II. Striations parallèles et régulières observées en microscopie optique, perpendiculaires à l'épithélium.
# III. Contient des cellules bipolaires, des cellules amacrines, des cellules horizontales et des cellules de Muller.
# IV. Contient des cellules magnocellulaires, parvocellulaires et coniocellulaires.
#
# A. Photorécepteurs.
# B. Épithélium pigmentaire rétinien.
# C. Couche ganglionnaire rétinienne.
# D. Couche nucléaire interne.
#
# a) I: A, II: C; III: D; IV: B.
# b) I: B; II:A; III: D; IV: C.
# c) I: B; II: A; III: C; IV: C.
# d) I: C; II: A; III: D; IV: B.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# I. The description matches the characteristics of the retinal pigment epithelium (RPE), which is a monolayer of cells that are tightly joined by tight junctions.
#
# II. The description matches the appearance of the RPE under optical microscopy, which shows parallel and regular striations perpendicular to the epithelium.
#
# III. The RPE contains bipolar cells, amacrine cells, horizontal cells, and Müller cells.
#
# IV. The RPE does not contain magnocellular, parvocellular, or coniocellular cells.
#
# Therefore, the correct answer is option B: Épithélium pigmentaire rétinien.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 3:
# Language: hindi
# Question:
# Corneal epithelium mein paayi jaane waali teen koshikaon ke naam ko sabse upar se shuru karke, beech waali aur sabse neeche waali kram mein likhiye.
# a) Flat, wing, basal.
# b) Wing, basal, flat.
# c) Basal, flat, wing.
# d) Wing, flat, basal.
# Test #0:
# response
#   ```json
# {
# 	"response": "c) Basal, flat, wing."
# }
# ```
#
# Explanation:
#
# The correct order of the three layers of the corneal epithelium, starting from the innermost layer, is:
#
# 1. Basal layer
# 2. Flat layer
# 3. Wing layer
#
# Therefore, the correct answer is option c) Basal, flat, wing.
# {'response': 'c) Basal, flat, wing.'}
# Language: french
# Question:
# Classez les trois noms de cellules trouvés dans l'épithélium cornéen, en commençant par le plus superficiel, suivi de l'intermédiaire et du profond.
# a) Plates, ailes, basales.
# b) Ailes, basales, plates.
# c) Basales, plates, ailes.
# d) Ailes, plates, basales.
# Test #0:
# response
#   ```json
# {
# 	"response": "c) Basales, plates, ailes."
# }
# ```
#
# The three names of cells found in the stratified squamous epithelium, listed from most superficial to deepest, are:
#
# * Basal cells (c)
# * Plate cells (a)
# * Auxiliary cells (b)
#
# Therefore, the correct answer is option c.
# {'response': 'c) Basales, plates, ailes.'}
# **************************************************
# **************************************************
# Question 4:
# Language: hindi
# Question:
# Descemet's membrane ke sambandh mein, yah kehna sahi hai:
# a) Endothelial cells iske nirman mein bhag nahi lete.
# b) Vayask mein iski motai lagbhag 30 µm hoti hai.
# c) Iska sabse aage ka hissa embryonic utpatti ka hai.
# d) Iski motai umr ke sath kam hoti hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# Descemet's membrane is a thin layer of tissue that covers the surface of the cornea, the clear dome-shaped surface at the front of the eye. It is composed of a single layer of endothelial cells and is responsible for maintaining the proper amount of moisture in the cornea.
#
# Option b is the correct answer. The thickness of Descemet's membrane is around 30 µm, which is relatively thin compared to other tissues in the body.
#
# Option a is incorrect because endothelial cells do play a role in the formation of Descemet's membrane.
#
# Option c is incorrect because Descemet's membrane is not the outermost layer of the cornea, but rather a thin layer beneath the epithelial layer.
#
# Option d is incorrect because the thickness of Descemet's membrane does not decrease with age.
# {'response': 'b'}
# Language: french
# Question:
# Concernant la membrane de Descemet de la cornée, il est correct de dire :
# a) Les cellules endothéliales ne participent pas à sa formation.
# b) Son épaisseur chez l'adulte est d'environ 30 µm.
# c) Sa partie la plus antérieure est d'origine embryonnaire.
# d) Son épaisseur diminue avec l'âge.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# La réponse correcte est la option b) Son épaisseur chez l'adulte est d'environ 30 µm.
#
# La membrane de Descemet est une fine couche de tissu conjonctif qui recouvre la surface postérieure de la cornée. Elle est composée de plusieurs couches de cellules, notamment des cellules endothéliales, qui participent à sa formation. Chez l'adulte, l'épaisseur de la membrane de Descemet est d'environ 30 µm.
#
# La partie la plus antérieure de la membrane de Descemet est d'origine embryonnaire, mais elle ne est pas la réponse la plus pertinente à cette question. L'épaisseur de la membrane de Descemet ne diminue pas nécessairement avec l'âge, bien que la cornée elle-même puisse subir des changements avec le temps.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 5:
# Language: hindi
# Question:
# Lacrimal film ke lipidic layer ke baare mein, sahi uttar chuniye.
# a) iska uddeshya lacrimal film ko sthir karna hai jo meibomian aur manz glans dwara utsarjit hota hai.
# b) Cholesterol esters iske ghatakon mein shamil hain, aur iska ek kaam lacrimal film ke evaporation ko deri karna hai.
# c) Meibomian gland dysfunction mein, fusion point kam ho jata hai, jo rukawat ka karan banta hai.
# d) ise lacrimal film break up time se moolyaankan kiya ja sakta hai, swasth aankhon mein paanch second se kam samay tak akhand rahte hue.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the role of cholesterol esters in the lacrimal film.
#
# Option A is incorrect because the lacrimal film's lipid layer is not responsible for stabilizing the tear film.
#
# Option C is incorrect because meibomian gland dysfunction can lead to a decrease in the fusion point, but it does not directly affect the lacrimal film's evaporation.
#
# Option D is incorrect because the lacrimal film's break-up time is not directly related to the cholesterol esters in the lacrimal film.
#
# Therefore, the correct answer is option B, which states that cholesterol esters play a role in the lacrimal film's evaporation.
# {'response': 'b'}
# Language: french
# Question:
# À propos de la couche lipidique du film lacrymal, choisissez la bonne réponse.
# a) Son but est de stabiliser le film lacrymal sécrété par les glandes de Meibomius et de Manz.
# b) Les esters de cholestérol font partie de ses composants, et l'une de ses fonctions est de retarder l'évaporation du film lacrymal.
# c) En cas de dysfonctionnement de la glande de Meibomius, le point de fusion diminue, entraînant une stagnation.
# d) Peut être évaluée par le temps de rupture du film lacrymal, restant intacte moins de cinq secondes dans des yeux sains.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
# La bonne réponse est la option b) Les esters de cholestérol font partie de ses composants, et l'une de ses fonctions est de retarder l'évaporation du film lacrymal.
#
# La couche lipidique du film lacrymal est une fine couche de lipides qui recouvre la surface de l'œil. Elle est produite par les glandes de Meibomius et de Manz, et elle joue un rôle important dans la protection de l'œil en réduisant l'évaporation de l'eau et en empêchant les corps étrangers de pénétrer dans l'œil. Les esters de cholestérol sont des composants importants de la couche lipidique, et ils ont une fonction de retardation de l'évaporation du film lacrymal, ce qui permet de maintenir une quantité suffisante de liquide sur la surface de l'œil pour une vision claire et confortable.
#
# Les autres options ne sont pas correctes :
#
# * La option a) est incorrecte car la couche lipidique n'a pas pour but de stabiliser le film lacrymal sécrété par les glandes de Meibomius et de Manz, mais plutôt de le protéger et de le maintenir.
# * La option c) est incorrecte car le point de fusion de la couche lipidique n'a pas d'incidence sur la stagnation du film lacrymal en cas de dysfonctionnement de la glande de Meibomius.
# * La option d) est incorrecte car le temps de rupture du film lacrymal n'est pas une méthode appropriée pour évaluer la fonction de la couche lipidique du film lacrymal.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 6:
# Language: hindi
# Question:
# External ocular muscles ke baare mein, sahi uttar chuniye.
# a) Hering ke niyam mein, innervation ko ek nirdharit ocular version ke liye agonist aur antagonist muscles mein barabar vitrit kiya jata hai.
# b) Persecutory movements apne aap, dheere dheere, fixation point ke displacement ke saath hote hain.
# c) Sherrington ke niyam mein, contraction stimulus dono aankhon ke agonists ke beech vitrit hota hai, taaki yeh symmetrically ho sake.
# d) Saccadic movements ko achanak, asamanvayit, reflex movements ke roop mein pehchana jata hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The question is asking about the correct explanation of external ocular muscles.
#
# Option A is incorrect because Hering's law states that the direction of the eye movement is determined by the direction of the visual stimulus, not the innervation of the muscles.
#
# Option B is incorrect because persecutory movements are not related to the displacement of the fixation point.
#
# Option C is correct because Sherrington's law states that the contraction of the external ocular muscles is symmetrical, with the agonist muscle contracting to move the eye in one direction and the antagonist muscle contracting to move the eye in the opposite direction.
#
# Option D is incorrect because saccadic movements are not related to the external ocular muscles.
# {'response': 'c'}
# Language: french
# Question:
# Concernant les muscles oculaires externes, choisissez la bonne réponse.
# a) Selon la loi de Hering, l'innervation est également distribuée aux muscles agonistes et antagonistes, pour une version oculaire donnée.
# b) Les mouvements de poursuite se produiront automatiquement, lentement, avec le déplacement du point de fixation.
# c) Selon la loi de Sherrington, le stimulus de contraction est distribué entre les agonistes des deux yeux, de manière à ce qu'il se produise symétriquement.
# d) Les mouvements saccadiques sont caractérisés par des mouvements réflexes brusques, non coordonnés.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
# La réponse correcte est la option c, Selon la loi de Sherrington, le stimulus de contraction est distribué entre les agonistes des deux yeux, de manière à ce qu'il se produise symétriquement.
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 7:
# Language: hindi
# Question:
# Cornea ke baare mein, yeh kehna sahi hai.
# a) Corneal collagen fibrils ka arrangement uski transparency se sambandhit nahi hai.
# b) Endothelial cells ka pleomorphism in cells ke size mein variation se pehchana jaata hai.
# c) Anterior stroma mein mitochondria ki badi sankhya hoti hai, jo endothelial pump ko energy pradan karne ke liye utpaadan karti hai.
# d) Endothelium ek permeable non-selective barrier ke roop mein vyavhaar karta hai jo aqueous humor aur substantia propria ke beech hota hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is option c. The statement "Anterior stroma mein mitochondria ki badi sankhya hoti hai, jo endothelial pump ko energy pradan karne ke liye utpaadan karti hai" is true. The anterior stroma contains a high concentration of mitochondria, which provide energy to the endothelial pump, allowing it to function properly.
#
# Option a is incorrect because the arrangement of corneal collagen fibrils is not related to the transparency of the cornea.
#
# Option b is incorrect because endothelial cells do not exhibit pleomorphism in terms of cell size.
#
# Option d is incorrect because the endothelium does not function as a permeable non-selective barrier between the aqueous humor and the substantia propria.
# {'response': 'c'}
# Language: french
# Question:
# À propos de la cornée, il est correct de déclarer :
# a) L'arrangement des fibrilles de collagène de la cornée n'est pas lié à sa transparence.
# b) Le pléomorphisme des cellules endothéliales est caractérisé par la variation de la taille de ces cellules.
# c) Le stroma antérieur contient un grand nombre de mitochondries, responsables de la production d'énergie qui alimente la pompe endothéliale.
# d) L'endothélium se comporte comme une barrière perméable non sélective entre l'humeur aqueuse et la substance propre.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# The correct answer is c) Le stroma antérieur contient un grand nombre de mitochondries, responsables de la production d'énergie qui alimente la pompe endothéliale.
#
# Explanation:
#
# The stroma anterior, also known as the anterior stroma, is a layer of connective tissue located in the front part of the cornea. It is rich in mitochondria, which are responsible for producing energy that powers the endothelial pump. This pump helps maintain the proper thickness of the cornea and ensures that it remains transparent.
#
# Option a is incorrect because the arrangement of collagen fibers in the cornea is indeed related to its transparency. The tightly packed, parallel arrangement of these fibers allows light to pass through the cornea with minimal scattering, contributing to its transparency.
#
# Option b is incorrect because while there is some variation in the size of endothelial cells, this is not the primary characteristic of the pleomorphism of these cells.
#
# Option d is incorrect because while the endothelium does act as a barrier between the aqueous humor and the substance proper, it is not a non-selective barrier. It plays a critical role in regulating the flow of nutrients and waste products into and out of the cornea.
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 8:
# Language: hindi
# Question:
# Vikalp ko chunein jo sahi roop se khaali jagah ko bharta hai. Levocycloversion ____________ daahine aankh ka aur ________ baayen aankh ka aur yeh tab shuru hota hai jab sir ko ___ kandhe ki taraf jhukaya jata hai.
# a) Excicloduction / incicloduction / baayen.
# b) Incicloduction / excicloduction / baayen.
# c) Excicloduction / incicloduction / daahine.
# d) Incicloduction / excicloduction / daahine.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# Levocycloversion is a term used to describe the movement of the eye towards the nasal side. It is a combination of two words - "levo" meaning "left" and "cyclo" meaning "circle". The correct answer is option c) Excicloduction / incicloduction / daahine.
#
# Excicloduction refers to the movement of the eye away from the nasal side, while incicloduction refers to the movement of the eye towards the temporal side. Daahine refers to the nasal side. Therefore, the correct sequence of events is:
#
# 1. Excicloduction (movement away from the nasal side)
# 2. Incicloduction (movement towards the temporal side)
# 3. Daahine (nasal side)
#
# This sequence is important to understand the movement of the eye and to identify any abnormalities in the eye's movement.
# {'response': 'c'}
# Language: french
# Question:
# Choisissez l'alternative qui remplit correctement les lacunes. La levocycloversion correspond à ____________ de l'œil droit et ________ de l'œil gauche et est déclenchée lorsque la tête est inclinée vers l'épaule ___.
# a) Excicloduction / incicloduction / gauche.
# b) Incicloduction / excicloduction / gauche.
# c) Excicloduction / incicloduction / droite.
# d) Incicloduction / excicloduction / droite.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer is b) Incicloduction / excicloduction / gauche.
#
# La levocycloversion est un mouvement oculomoteur qui permet de suivre un objet en mouvement avec l'œil gauche et droit respectivement. Il est déclenché lorsque la tête est inclinée vers l'épaule gauche. Donc, la réponse correcte est b) Incicloduction / excicloduction / gauche.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 9:
# Language: hindi
# Question:
# Vitreous body cells ke baare mein, sahi vikalp chunein.
# a) Yeh vyask mein embryonic vitreous se zyada sankhya mein hote hain.
# b) Yeh mukhya roop se lymphocytes aur mature neutrophils dwara pratinidhit hote hain.
# c) Yeh vitreous base ke kshetra mein prachur matra mein hote hain.
# d) Yeh navjat shishu mein anupasthit hote hain.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# Vitreous body cells are produced in the embryonic vitreous, specifically in the vitreous base. They are not produced in the lymphatic system or mature neutrophils. Therefore, option b is the correct answer.
#
# In Hindi:
#
# वित्रियस बॉडी के लिए, सही विकल्प चुनें:
#
# a) यह व्यास में एम्ब्र्याऊनिक वित्रियस से ज्यादा संख्या में होते हैं।
#
# b) यह मुख्य रूप से लिम्फाई से और मेजर न्यूट्रॉफिल्स द्वारा प्रतिनिधित होते हैं।
#
# c) यह वित्रियस बेस के क्षेत्र में प्रचुर मात्रा में होते हैं।
#
# d) यह नवजात शिशु में अनुपस्थित होते हैं।
# {'response': 'b'}
# Language: french
# Question:
# Concernant les cellules du corps vitré, cochez l'alternative correcte.
# a) Elles sont plus nombreuses chez l'adulte que dans le vitré embryonnaire.
# b) Elles sont principalement représentées par des lymphocytes et des neutrophiles matures.
# c) Elles sont abondantes dans la région de la base du vitré.
# d) Elles sont absentes chez le nouveau-né.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Elles sont abondantes dans la région de la base du vitré.
#
# The cells of the vitreous body are abundant in the region of the base of the vitreous, which is the part of the eye that is closest to the lens. This is a characteristic feature of the vitreous body and distinguishes it from other parts of the eye.
#
# Option a is incorrect because the number of cells in the vitreous body decreases with age, not increases.
#
# Option b is incorrect because the cells in the vitreous body are not primarily composed of lymphocytes and mature neutrophils. The vitreous body contains a variety of cell types, including fibroblasts, collagen fibers, and hyaluronic acid, but lymphocytes and neutrophils are not the main components.
#
# Option d is incorrect because the vitreous body is present in newborns, although it is not fully developed at birth.
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 10:
# Language: hindi
# Question:
# Oculomotor muscles ki physiology ke sambandh mein, sahi vikalp chinhit karein.
# a) Muscle contraction calcium ki uplabdhata se swatantra hoti hai.
# b) Muscle fiber ek bahunukleated cell hai.
# c) Pratyek muscle contraction actin-myosin bridges ke ek vishisht cycle ke nirmaan aur vinash ka parinaam hota hai.
# d) Muscle relaxation mukhya roop se sodium ki uplabdhata par nirbhar karti hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The question is asking about the physiology of oculomotor muscles, specifically the mechanism of muscle contraction and relaxation.
#
# Option A is incorrect because muscle contraction is not independent of calcium. Calcium ions play a crucial role in the contraction of muscles.
#
# Option B is incorrect because muscle fibers are not single cells. They are composed of many cells that work together to produce movement.
#
# Option C is correct. Muscle contraction involves the formation and breakage of actin-myosin bridges, which are crucial for the movement of muscles. This process is also known as the sliding filament model.
#
# Option D is incorrect because muscle relaxation is not primarily dependent on sodium ions. Muscle relaxation occurs when the muscle fibers are no longer stimulated and return to their resting state.
# {'response': 'c'}
# Language: french
# Question:
# Concernant la physiologie des muscles oculomoteurs, cochez l'alternative correcte.
# a) La contraction musculaire est indépendante de la disponibilité du calcium.
# b) La fibre musculaire est une cellule multinucléée.
# c) Chaque contraction musculaire est le résultat d'un cycle unique de formation et de destruction des ponts actine-myosine.
# d) La relaxation musculaire dépend principalement de la disponibilité du sodium.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Chaque contraction musculaire est le résultat d'un cycle unique de formation et de destruction des ponts actine-myosine.
#
# The physiology of oculomotor muscles involves the contraction and relaxation of muscle fibers, which is mediated by the actin-myosin complex. Each contraction of the muscle fiber is the result of a unique cycle of formation and destruction of actin-myosin bridges. Therefore, option c is the correct answer.
#
# Option a is incorrect because the contraction of muscle fibers does require the availability of calcium ions.
#
# Option b is incorrect because muscle fibers are not multinucleated cells.
#
# Option d is incorrect because the relaxation of muscle fibers does not depend mainly on the availability of sodium ions.
# {'response': 'c'}
# **************************************************
# **************************************************
# Question 11:
# Language: hindi
# Question:
# Lens ke sambandh mein, sahi vikalp chinhit karein.
# a) Halanki iska aayatan umr ke sath badhta hai, iska vajan sthir rehta hai.
# b) Iske reshon ki proteolysis iska koshiya vruddhi ka mukhya mechanism hai.
# c) Iske proteins ka synthesis kosha ke fiber mein parivartan ke dauran hota hai.
# d) Iska protein synthesis jeevan bhar nirantar hota hai, jo bachpan se vruddhavastha tak sthir plasticity aur elasticity ko banaye rakhta hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The correct answer is b) Iske reshon ki proteolysis iska koshiya vruddhi ka mukhya mechanism hai.
#
# Proteolysis is the process of breaking down proteins into smaller peptides or amino acids. It is an important mechanism for regulating protein function and turnover in the body. Proteolysis can be triggered by various factors, including changes in pH, temperature, and the presence of proteases (enzymes that break down proteins).
#
# Option a) Halanki iska aayatan umr ke sath badhta hai, iska vajan sthir rehta hai is incorrect because while it is true that protein turnover increases with age, it is not the primary mechanism for protein synthesis.
#
# Option c) Iske proteins ka synthesis kosha ke fiber mein parivartan ke dauran hota hai is also incorrect because protein synthesis occurs in the ribosomes, not in the fibers.
#
# Option d) Iska protein synthesis jeevan bhar nirantar hota hai, jo bachpan se vruddhavastha tak sthir plasticity aur elasticity ko banaye rakhta hai is incorrect because while protein synthesis is a continuous process throughout life, it is not necessarily nirantar (uninterrupted) and does not necessarily maintain plasticity and elasticity.
# {'response': 'b'}
# Language: french
# Question:
# En ce qui concerne le cristallin, marquez l'alternative correcte.
# a) Bien que son volume augmente avec l'âge, son poids reste constant.
# b) La protéolyse de ses fibres est le principal mécanisme de sa croissance cellulaire.
# c) La synthèse de ses protéines a lieu pendant la différenciation de la cellule en fibre.
# d) La synthèse de ses protéines est continue tout au long de la vie, maintenant une plasticité et une élasticité stables de l'enfance à la vieillesse.
# Test #0:
# response
#   ```json
# {
# 	"response": "d"
# }
# ```
# La réponse correcte est la option d) La synthèse de ses protéines est continue tout au long de la vie, maintenant une plasticité et une élasticité stables de l'enfance à la vieillesse.
#
# Le cristallin est une protéine présente dans les cellules de la rétine et du cristallin humain, qui permet la vision en permettant la réflexion de la lumière. La synthèse de cette protéine est continue tout au long de la vie, ce qui permet de maintenir une plasticité et une élasticité stables de l'enfance à la vieillesse. Les autres options ne sont pas correctes car le cristallin ne subit pas de modifications de volume ou de poids avec l'âge, et sa croissance cellulaire ne dépend pas de la protéolyse de ses fibres.
# {'response': 'd'}
# **************************************************
# **************************************************
# Question 12:
# Language: hindi
# Question:
# Ek marīz jise arthrosis hai, varsho se chloroquine ki uchch matra ka upayog kar raha hai. Aisa mana jata hai ki yah dava retinal pigment epithelium ke malfunction ka karan ban sakti hai, kyunki:
# a) Yah melanin ki synthesis ko rokta hai.
# b) Yah photoreceptor ke outer segments ke disks ki phagocytosis ko rokta hai.
# c) Yah intracellular ions ke transport ko rokta hai.
# d) Yah photoreceptors aur choroid ke beech teevra garmi ka adan-pradan ko badhava deta hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
# Chloroquine is a drug that is used to treat malaria and rheumatoid arthritis. It works by interfering with the growth and reproduction of the malaria parasite in the red blood cells. However, it can also affect the retinal pigment epithelium (RPE) and cause a condition known as retinal toxicity.
#
# The correct answer is (b) Yah photoreceptor ke outer segments ke disks ki phagocytosis ko rokta hai. Chloroquine can cause the RPE to phagocytose the outer segments of the photoreceptors, leading to their degeneration and subsequent vision loss.
#
# Option (a) Yah melanin ki synthesis ko rokta hai is incorrect because chloroquine does not affect the synthesis of melanin.
#
# Option (c) Yah intracellular ions ke transport ko rokta hai is incorrect because chloroquine does not affect the transport of ions within the cells.
#
# Option (d) Yah photoreceptors aur choroid ke beech teevra garmi ka adan-pradan ko badhava deta hai is incorrect because chloroquine does not affect the growth and development of the photoreceptors or the choroid.
# {'response': 'b'}
# Language: french
# Question:
# Un patient atteint d'arthrose utilise des doses élevées de chloroquine depuis des années. On pense que ce médicament peut provoquer un dysfonctionnement de l'épithélium pigmentaire rétinien, car :
# a) Il entrave la synthèse de la mélanine.
# b) Il entrave la phagocytose des disques des segments externes des photorécepteurs.
# c) Il entrave le transport des ions intracellulaires.
# d) Il favorise un échange de chaleur intense entre les photorécepteurs et la choroïde.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# Chloroquine is a medication that has been used for decades to treat various conditions such as malaria, rheumatoid arthritis, and lupus. However, long-term use of chloroquine has been associated with retinal toxicity, which can lead to vision loss. The exact mechanism of this toxicity is not fully understood, but it is believed that chloroquine may disrupt the function of the retinal pigment epithelium (RPE), a layer of cells that plays a critical role in maintaining the health of the retina.
#
# Option b, "Il entrave la phagocytose des disques des segments externes des photorécepteurs," is the correct answer. Chloroquine has been shown to disrupt the phagocytosis of the outer segment of photoreceptors by the RPE, leading to the accumulation of toxic byproducts and ultimately causing damage to the retina.
#
# Option a, "Il entrave la synthèse de la mélanine," is incorrect. Chloroquine does not affect the synthesis of melanin, which is the pigment responsible for skin and hair color.
#
# Option c, "Il entrave le transport des ions intracellulaires," is also incorrect. Chloroquine does not affect the transport of ions within cells.
#
# Option d, "Il favorise un échange de chaleur intense entre les photorécepteurs et la choroïde," is incorrect. Chloroquine does not promote an intense heat exchange between photoreceptors and the choroid, which is the layer of blood vessels and connective tissue between the sclera and retina.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 13:
# Language: hindi
# Question:
# Choroid mein rakt pravah ke baare mein kaha ja sakta hai:
# a) Yeh retina ke sabhi poshan ke liye zimmedar hai.
# b) Yeh retina ke andar ke bhaag mein upbhog kiye gaye 95% glucose ke liye zimmedar hai.
# c) Photoreceptors ki thermal regulation mein bhaag leta hai.
# d) Pre-capillary sphincters macula jaise mahatvapurn kshetron mein rakt ke adhik pravah ko rokne ka kaam karte hain.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# Choroid is a layer of blood vessels between the sclera and retina in the eye. It supplies blood to the retina and plays a crucial role in maintaining the health and function of the retina.
#
# Option b is the correct answer. The choroid is responsible for supplying 95% of the glucose needed by the retina, which is essential for the metabolic needs of the retinal cells, including the photoreceptors.
#
# Option a is incorrect because while the choroid does play a role in the nutrition of the retina, it is not responsible for the absorption of all nutrients.
#
# Option c is incorrect because while the choroid does play a role in regulating the temperature of the retina, it is not the primary mechanism for thermal regulation of the photoreceptors.
#
# Option d is incorrect because while the pre-capillary sphincters in the macula do play a role in regulating blood flow to the retina, they are not the primary mechanism by which the choroid regulates the distribution of nutrients to the retina.
# {'response': 'b'}
# Language: french
# Question:
# Concernant le flux sanguin dans la choroïde, il est possible d'affirmer :
# a) Il est responsable de toute la nutrition de la rétine.
# b) Il est responsable de 95 % du glucose consommé dans la partie interne de la rétine.
# c) Participe à la régulation thermique des photorécepteurs.
# d) Les sphincters précapillaires empêchent l'hyperflux sanguin dans des zones nobles telles que la macula.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The question is asking about the role of choroidal blood flow in the retina.
#
# Option A is incorrect because while the choroidal blood flow does provide some nutrients to the retina, it is not responsible for all of the nutrition of the retina. The retina also receives nutrients from the retinal vessels.
#
# Option B is correct. The choroidal blood flow is responsible for providing 95% of the glucose consumed in the inner part of the retina.
#
# Option C is incorrect. While the choroidal blood flow does play a role in regulating the temperature of the retina, it does not participate in the regulation of thermic photoreceptors.
#
# Option D is incorrect. The sphincters precapillaries do not prevent hyperflux sanguin in noble areas such as the macula. Instead, they help regulate blood flow into the retina.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 14:
# Language: hindi
# Question:
# Choroid ke embryology ke baare mein yeh kehna sahi hai:
# a) Choriocapillaris sabse pehle banta hai, aur uske baad bade vessels bante hain.
# b) Basal lamina Bruch's membrane ko utpann karti hai, jo choriocapillaris aur Sattler's layer ke beech mein hoti hai.
# c) Intermediate vascular layer sabse aakhri mein banti hai aur yeh ciliary body se lekar equator tak vikasit hoti hai.
# d) Choroidal stroma mool roop se mesoderm cells se utpann hota hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer is b) Basal lamina Bruch's membrane ko utpann karti hai, jo choriocapillaris aur Sattler's layer ke beech mein hoti hai.
#
# Explanation:
#
# The basal lamina of Bruch's membrane is formed by the proliferation of the cells of the inner layer of the retina, specifically the photoreceptors and the retinal pigment epithelium. This layer then separates from the underlying tissue, forming a cavity known as the posterior chamber. The choriocapillaris, which is a specialized blood vessel layer, develops later and is located between the basal lamina of Bruch's membrane and the retinal pigment epithelium. Therefore, option b is the correct answer.
# {'response': 'b'}
# Language: french
# Question:
# Concernant l'embryologie de la choroïde, il est correct de dire :
# a) La choriocapillaire est la première à se former, suivie par la formation des grands vaisseaux.
# b) La lame basale donne naissance à la membrane de Bruch, qui se trouve entre la choriocapillaire et la couche de Sattler.
# c) La couche vasculaire intermédiaire est la dernière à se former et se développe du corps ciliaire vers l'équateur.
# d) Le stroma choroïdien est essentiellement produit à partir des cellules du mésoderme.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# La bonne réponse est la option b) La lame basale donne naissance à la membrane de Bruch, qui se trouve entre la choriocapillaire et la couche de Sattler.
#
# La membrane de Bruch est une fine couche de tissu conjonctif qui sépare la choriocapillaire de la couche de Sattler dans l'œil embryonnaire. Elle est formée à partir de la lame basale de l'embryon, qui est une couche de cellules qui recouvre la surface de l'embryon et qui donnera naissance à divers tissus, notamment le tissu conjonctif. La membrane de Bruch plays an important role dans le développement de la rétine et de la choroïde.
#
# Les autres options ne sont pas correctes :
#
# * La option a) est incorrect, car la formation des grands vaisseaux est précédée par la formation de la choriocapillaire.
# * La option c) est incorrect, car la couche vasculaire intermédiaire se développe du corps ciliaire vers l'équateur, mais elle n'est pas la dernière à se former.
# * La option d) est incorrect, car le stroma choroïdien est produit à partir des cellules de la neuroectoderme, et non du mésoderme.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 15:
# Language: hindi
# Question:
# Ocular embryology ke sambandh mein, yah kehna sahi hai:
# a) Corneal epithelium neural crest cells se utpann hota hai.
# b) Janm ke samay, cornea aur sclera ka curvature radius ek samaan hota hai.
# c) Bowman's layer garbhavastha ke pehle aur doosre mahine ke beech mein prakat hoti hai.
# d) Cornea ectodermal surface aur neural crest cells se vikasit hota hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The correct answer is c) Bowman's layer garbhavastha ke pehle aur doosre mahine ke beech mein prakat hoti hai.
#
# Bowman's layer is a layer of the cornea that forms during the embryonic development of the eye. It is formed from the invagination of the optic cup, which is a part of the developing eye. The invagination of the optic cup occurs during the first and second months of gestation, which is the period of garbhavastha or embryonic development. Therefore, option c is the correct answer.
#
# Option a is incorrect because the corneal epithelium is not derived from neural crest cells.
#
# Option b is incorrect because the curvature radius of the cornea and sclera is not the same at birth. The cornea is more curved than the sclera at birth.
#
# Option d is incorrect because the cornea is not derived from ectodermal surface and neural crest cells. The cornea is derived from the invagination of the optic cup, which is a part of the developing eye.
# {'response': 'c'}
# Language: french
# Question:
# En ce qui concerne l'embryologie oculaire, il est correct de dire :
# a) L'épithélium cornéen provient des cellules de la crête neurale.
# b) À la naissance, la cornée et la sclère ont le même rayon de courbure.
# c) La couche de Bowman apparaît entre le premier et le deuxième mois de grossesse.
# d) La cornée se développe à partir de la surface ectodermique et des cellules de la crête neurale.
# Test #0:
# response
#   ```json
# {
# 	"response": "d"
# }
# ```
# La réponse correcte est la option d) La cornée se développe à partir de la surface ectodermique et des cellules de la crête neurale.
#
# L'épithélium cornéen provient des cellules de la crête neurale, donc la option a est incorrecte.
#
# À la naissance, la cornée et la sclère ont des rayons de courbure différents, donc la option b est incorrecte.
#
# La couche de Bowman apparaît entre le premier et le deuxième mois de grossesse, donc la option c est incorrecte.
# {'response': 'd'}
# **************************************************
# **************************************************
# Question 16:
# Language: hindi
# Question:
# Autosomal dominant inheritance diseases ke baare mein yeh kehna sahi hai:
# a) Aam taur par, yeh kai garbhavasthaon mein dekhe jaate hain.
# b) Purush mahilaaon ke mukable zyada prabhavit hote hain.
# c) Bimari ki gambhirta hamesha ek hi parivaar ke prabhavit logon mein same hoti hai.
# d) Sirf mahilayen mutation ko transmit karti hain.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Autosomal dominant inheritance diseases are characterized by a single copy of a mutated gene, which is enough to cause the disease. This means that every individual who inherits the mutated gene will develop the disease. The mutation can be inherited from either parent, and can affect both males and females equally. Therefore, option c) The disease is always present in a single copy in affected individuals and is transmitted by a single copy of the mutated gene. is the correct answer.
# {'response': 'c'}
# Language: french
# Question:
# Concernant les maladies à hérédité autosomique dominante, il est correct de dire :
# a) En général, elles sont observées dans plusieurs gestations.
# b) Les hommes ont tendance à être plus affectés que les femmes.
# c) La gravité de la maladie est toujours la même chez les personnes affectées de la même famille.
# d) Seules les femmes transmettent la mutation.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# The statement "Les hommes ont tendance à être plus affectés que les femmes" is correct for diseases with autosomal dominant inheritance. This means that the mutated gene is expressed in every cell of the body, and the effect of the mutation is seen in both males and females. However, the severity of the disease may vary among individuals within the same family, which means that option c is incorrect. Option a is also incorrect because the disease may not always be observed in multiple generations, as the mutation may be inherited from a parent who does not display symptoms. Option d is incorrect because both males and females can transmit the mutation to their offspring.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 17:
# Language: hindi
# Question:
# Mitochondrial inheritance diseases ke baare mein kehna sahi hoga:
# a) Daltonism ek bimari ka udaharan hai jo mitochondrial DNA se judi hui hai.
# b) Viraasat sirf maatrik vansh se hoti hai.
# c) Bimari se prabhavit purush mareez apni santaan ko phenotype pradan karenge.
# d) Leber's hereditary optic neuropathy ek bimari ka udaharan hai jo mitochondrial DNA se judi hui hai, yeh aam taur par janm se andhapan ka kaaran banti hai aur dono ling ke mareezon ko ek hi anupaat mein prabhavit karti hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "d"
# }
# ```
#
# Explanation:
#
# Mitochondrial inheritance diseases are caused by mutations in the mitochondrial DNA, which is inherited from the mother. The mutations can cause a variety of symptoms, including muscle weakness, seizures, and vision loss. Leber's hereditary optic neuropathy is an example of a mitochondrial inheritance disease that affects the optic nerve and can cause blindness in both eyes. It is caused by a mutation in the mitochondrial DNA and is inherited in a maternal pattern, meaning that the mutation is passed from mother to child.
#
# Therefore, the correct answer is option d: Leber's hereditary optic neuropathy is a mitochondrial inheritance disease that affects the optic nerve and can cause blindness in both eyes. It is caused by a mutation in the mitochondrial DNA and is inherited in a maternal pattern.
# {'response': 'd'}
# Language: french
# Question:
# Concernant les maladies liées à l'hérédité mitochondriale, il est correct de dire :
# a) Le daltonisme est un exemple de maladie liée à l'ADN mitochondrial.
# b) L'hérédité se fait uniquement par la lignée maternelle.
# c) Les patients masculins affectés par la maladie transmettront le phénotype à toute leur descendance.
# d) La neuropathie optique héréditaire de Leber est un exemple de maladie liée à l'ADN mitochondrial, elle cause généralement la cécité congénitale et affecte les patients des deux sexes dans la même proportion.
# Test #0:
# response
#   ```json
# {
# 	"response": "d"
# }
# ```
#
# Explanation:
#
# The correct answer is d) La neuropathie optique héréditaire de Leber est un exemple de maladie liée à l'ADN mitochondrial, elle cause généralement la cécité congénitale et affecte les patients des deux sexes dans la même proportion.
#
# The other options are incorrect for the following reasons:
#
# a) Le daltonisme est un exemple de maladie liée à l'ADN mitochondrial. - This is incorrect because color blindness is not caused by a mitochondrial DNA mutation.
#
# b) L'hérédité se fait uniquement par la lignée maternelle. - This is incorrect because mitochondrial DNA is inherited from both parents, not just the mother.
#
# c) Les patients masculins affectés par la maladie transmettront le phénotype à toute leur descendance. - This is incorrect because mitochondrial DNA is not transmitted by males, only by females.
#
# Therefore, the correct answer is d) La neuropathie optique héréditaire de Leber est un exemple de maladie liée à l'ADN mitochondrial, elle cause généralement la cécité congénitale et affecte les patients des deux sexes dans la même proportion.
# {'response': 'd'}
# **************************************************
# **************************************************
# Question 18:
# Language: hindi
# Question:
# Neeche diye gaye lenson mein se kaunsa lens simple myopic astigmatism ko sabse achhe tareeke se correct karta hai?
# a) -3.00 spherical diopter + 1.00 cylindrical diopter X 90°.
# b) +1.00 spherical diopter -1.00 cylindrical diopter X 90°.
# c) -3.00 spherical diopter + 3.00 cylindrical diopter X 180°.
# d) 0.00 spherical diopter +1.00 cylindrical diopter X 180°.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer for the question in Hindi is option b: +1.00 spherical diopter -1.00 cylindrical diopter X 90°. This is the best correction for simple myopic astigmatism.
# {'response': 'b'}
# ...
# {'response': 'a'}
# Language: french
# Question:
# Après un bloc rétrobulbaire pour une chirurgie de phacoémulsification, le patient a évolué avec une perte progressive de conscience, des convulsions et un arrêt respiratoire cinq minutes après l'injection anesthésique. Choisissez l'alternative qui décrit correctement la complication la plus probable dans ce cas et une mesure préventive possible.
# a) Injection intraoculaire - observer le mouvement conjoint du globe oculaire et de l'aiguille avant d'injecter.
# b) Injection intravasculaire - suspendre les anticoagulants ou les agents antiplaquettaires avant la chirurgie.
# c) Injection dans l'espace sous-arachnoïdien - insérer l'aiguille à moins de 30 mm de profondeur.
# d) Hémorragie rétrobulbaire - aspirer et vérifier la présence de contenu hématique avant d'injecter.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer is b) Injection intravasculaire.
#
# In this scenario, the patient has developed a progressive loss of consciousness, convulsions, and respiratory arrest five minutes after the anesthetic injection. This suggests that the anesthetic has entered the bloodstream and caused a systemic reaction.
#
# The most probable complication in this case is an injection intravasculaire, which can occur when the anesthetic is injected into a blood vessel instead of the intended site, such as the subarachnoid space. This can cause a rapid onset of anesthesia and potentially life-threatening complications.
#
# A measure preventive possible in this case would be to suspend the anticoagulants or anti-platelet agents before the surgery, as these medications can increase the risk of bleeding and hematoma formation. Additionally, the anesthesiologist should use caution when injecting the anesthetic and ensure that the needle is properly positioned to avoid accidental intravascular injection.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 161:
# Language: hindi
# Question:
# Biometrics mein aankhon mein silicone oil ke saath sambandhit, yah kehna sahi hai:
# a) Ultrasound dwara maapi gayi axial lambai vastavik moolya ke tulna mein galat roop se kam hoti hai.
# b) Low coherence reflectometry ka istemal is sthiti mein nahi kiya ja sakta.
# c) Anterior chamber depth maapan ko supine sthiti mein kiya jana chahiye.
# d) Partial coherence interferometry in maamlon mein ultrasonography se uttam hai.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# Explanation:
#
# The question is asking about the relationship between silicone oil and the axial length of the eye in biometrics.
#
# Option A is incorrect because ultrasound does not use silicone oil to measure the axial length.
#
# Option B is incorrect because low coherence reflectometry is not a technique used to measure the axial length of the eye.
#
# Option C is correct because the anterior chamber depth needs to be measured in the supine position to get an accurate reading of the axial length.
#
# Option D is incorrect because partial coherence interferometry is not a technique used to measure the axial length of the eye, and it is not related to ultrasonography.
# {'response': 'c'}
# Language: french
# Question:
# Concernant les biométries des yeux couverts d'huile de silicone, il est correct de déclarer :
# a) La longueur axiale mesurée par échographie est faussement réduite par rapport à la valeur réelle.
# b) La réflectométrie à faible cohérence ne peut pas être utilisée dans cette situation.
# c) La mesure de la profondeur de la chambre antérieure doit être effectuée en position couchée.
# d) L'interférométrie à cohérence partielle est préférable à l'échographie dans ces cas.
# Test #0:
# response
#   ```json
# {
# 	"response": "a"
# }
# ```
#
# Explanation:
#
# In the case of silicone-covered eye biometrics, option a is the correct response. The axial length measured by ultrasound is falsely reduced compared to the real value. This is because the silicone covering the eye can cause artifacts that affect the accuracy of the measurement.
#
# Option b is incorrect because low-coherence reflectometry can be used in this situation to measure the thickness of the silicone covering the eye.
#
# Option c is incorrect because the measurement of the depth of the anterior chamber should be performed in the sitting position, not in the recumbent position.
#
# Option d is incorrect because partial coherence interferometry is not preferred over ultrasound in these cases. Ultrasound is the standard method for measuring axial length in ophthalmology.
# {'response': 'a'}
# **************************************************
# **************************************************
# Question 162:
# Language: hindi
# Question:
# Nimnlikhit mein se us vikalp ko chunein jo, kramashah, ek aisi dava ko darshata hai jo perioperative avadhi mein flaccid iris syndrome ke ghatit hone se judi hoti hai aur in maamlon mein mydriasis ko bahal karne ke liye ek uchit hastakshep hai.
# a) Chlorpromazine - iris retractors.
# b) Doxasozine - Beehler dilator.
# c) Tamsulosin - sphincterectomies.
# d) Atropine - iris expander ring.
# Test #0:
# response
#   ```json
# {
# 	"response": "a"
# }
# ```
#
# Explanation:
#
# The correct answer is a) Chlorpromazine - iris retractors.
#
# Chlorpromazine is an anticholinergic medication that can be used as an iris retractor during eye surgery, specifically in cases of flaccid iris syndrome. It helps to dilate the pupil and reduce the risk of complications during surgery.
#
# Doxasozine (b) is a vasodilator that can be used to dilate the pupil, but it is not typically used as an iris retractor.
#
# Tamsulosin (c) is an alpha-blocker that can be used to dilate the pupil, but it is not typically used as an iris retractor.
#
# Atropine (d) is a parasympatholytic medication that can be used to dilate the pupil, but it is not typically used as an iris expander ring.
# {'response': 'a'}
# Language: french
# Question:
# Vérifiez l'alternative qui contient, respectivement, un médicament associé à l'apparition du syndrome de l'iris flasque en période périopératoire et une intervention adéquate pour restaurer la mydriase dans ces cas.
# a) Chlorpromazine - rétracteurs d'iris.
# b) Doxazosine - dilatateur de Beehler.
# c) Tamsulosine - sphinctérectomies.
# d) Atropine - anneau d'expansion de l'iris.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# The correct answer is b) Doxazosine - dilatateur de Beehler.
#
# Doxazosine is a medication that can cause the iris to become flaccid, leading to a condition known as posterior synechiae, which can cause vision problems. In the perioperative period, it is important to monitor the patient's intraocular pressure and perform a dilated eye exam to check for any changes in the iris.
#
# Rétracteurs d'iris (a) are not typically used to treat posterior synechiae, but rather to retract the iris during cataract surgery. Sphinctérectomies (c) are a surgical procedure that can be used to treat posterior synechiae, but they are not typically performed in the perioperative period. Anneau d'expansion de l'iris (d) is not a recognized medical term.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 163:
# Language: hindi
# Question:
# Cataract surgery mein endophthalmitis ke prevention ke sambandh mein, sahi vikalp chunein.
# a) Povidone-iodine ke contraindication ke maamle mein, procedure se paanch din pehle topical antibiotic eye drops ka istemal kiya jaana chahiye.
# b) Mukhya risk factors mein immunosuppression, diabetes, blepharitis, conjunctivitis, posterior capsule ka rupture aur vitreous loss shaamil hain.
# c) Intracameral gentamicin ka istemal apnaaya jaana chahiye, khaaskar un maamlon mein jo pehle vitrectomy se jude hue hain.
# d) Sabse adhik paaye jaane waale etiological agents bacteria hain jo surgical materials aur intraocular lenses ki asamuchit sterilization se aate hain.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
#
# Explanation:
#
# Endophthalmitis is a serious complication of cataract surgery that can lead to vision loss. Prevention of endophthalmitis is crucial, and there are several measures that can be taken to reduce the risk.
#
# Option b is the correct answer. Mukhya risk factors for endophthalmitis include immunosuppression, diabetes, blepharitis, conjunctivitis, posterior capsule rupture, and vitreous loss. It is important to identify and manage these risk factors before and after surgery to minimize the risk of endophthalmitis.
#
# Option a is incorrect. While topical antibiotic eye drops may be used in the prevention of endophthalmitis, there is no contraindication for their use in patients with a history of povidone-iodine allergy.
#
# Option c is incorrect. Intracameral gentamicin is not recommended for the prevention of endophthalmitis in patients who have undergone vitrectomy.
#
# Option d is incorrect. While bacteria are a common cause of endophthalmitis, the etiological agents can also include viruses and fungi. Moreover, the sterilization of surgical materials and intraocular lenses is not the only measure to prevent endophthalmitis. Proper surgical technique, adequate sterilization and disinfection, and early detection and treatment of postoperative complications are also crucial in preventing this complication.
# {'response': 'b'}
# Language: french
# Question:
# Concernant la prévention de l'endophtalmie lors de la chirurgie de la cataracte, marquez l'alternative correcte.
# a) En cas de contre-indication à la povidone-iode, des gouttes ophtalmiques antibiotiques topiques doivent être utilisées pendant cinq jours avant l'intervention.
# b) Les principaux facteurs de risque incluent l'immunosuppression, le diabète, la blépharite, la conjonctivite, la rupture de la capsule postérieure et la perte de vitré.
# c) L'utilisation intracamérulaire de gentamicine doit être adoptée, surtout dans les cas associés à une vitrectomie antérieure.
# d) Les agents étiologiques les plus fréquents sont des bactéries provenant d'une stérilisation inadéquate des matériaux chirurgicaux et des lentilles intraoculaires.
# Test #0:
# response
#   ```json
# {
# 	"response": "b"
# }
# ```
# La réponse correcte est la option b) Les principaux facteurs de risque incluent l'immunosuppression, le diabète, la blépharite, la conjonctivite, la rupture de la capsule postérieure et la perte de vitré.
#
# La prévention de l'endophtalmie lors de la chirurgie de la cataracte est un sujet important, et il est essentiel de comprendre les facteurs de risque pour prendre des mesures preventives adéquates. Les facteurs de risque mentionnés dans l'option b) sont tous des facteurs bien établis qui peuvent augmenter le risque de développer une endophtalmie après une chirurgie de la cataracte.
#
# L'option a) concerne la prévention des infections oculaires et est donc inappropriée dans ce contexte. L'option c) mentionne l'utilisation intracamérulaire de gentamicine, qui est un traitement couramment utilisé pour prévenir les infections oculaires, mais ne concerne pas directement la prévention de l'endophtalmie. L'option d) mentionne les agents étiologiques les plus fréquents de l'endophtalmie, mais ne fournit pas de information sur les facteurs de risque.
# {'response': 'b'}
# **************************************************
# **************************************************
# Question 164:
# Language: hindi
# Question:
# Core fractures ko divide-and-conquer technique se perform karne ke baad, corneal incision ke lateral portion par ek safed hissa aur tissue ka contraction dekha ja sakta hai, jahan se irrigation solution gap ke through leak ho raha hai. Neeche diye gaye vikalpon mein se kaunsa vikalp varnit complication ke hone se rokne mein prabhavi hoga?
# a) Aspiration flow rate ko kam karein aur incision ko patla karein.
# b) Badi diameter tips aur chhoti diameter coaxial irrigation sleeves ka upyog karein.
# c) Tip ko incision walls se saman doori par rakhein aur pulsed ultrasound ka upyog karein.
# d) Anterior chamber ko cohesive viscoelastic se bhar dein aur continuous ultrasound ka upyog karein.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
#
# The correct answer is option c: Tip ko incision walls se saman doori par rakhein aur pulsed ultrasound ka upyog karein.
#
# After dividing and conquering the core fractures, it is possible to see a white, triangular-shaped area of tissue contraction on the lateral portion of the corneal incision, through which the irrigation solution is leaking. This is a complication that can occur with the use of the divide-and-conquer technique.
#
# Option c is the best answer because it describes a technique that can help to address this complication. By positioning the tip of the irrigation sleeve near the incision walls and using pulsed ultrasound, it is possible to disrupt the tissue contraction and improve the flow of irrigation solution.
#
# Option a is not a correct answer because reducing the aspiration flow rate and making the incision larger will not address the tissue contraction complication.
#
# Option b is not a correct answer because using larger diameter tips and coaxial irrigation sleeves will not necessarily improve the flow of irrigation solution in this situation.
#
# Option d is not a correct answer because filling the anterior chamber with cohesive viscoelastic and using continuous ultrasound will not address the tissue contraction complication.
# {'response': 'c'}
# Language: french
# Question:
# Après avoir effectué les fractures du noyau avec la technique de division et conquête, une portion blanchâtre et une contraction du tissu peuvent être observées sur la partie latérale de l'incision cornéenne, avec une fuite de la solution d'irrigation à travers l'écart formé. Parmi les alternatives ci-dessous, laquelle serait efficace pour prévenir la survenue de la complication décrite ?
# a) Réduire le débit d'aspiration et rendre l'incision plus étroite.
# b) Utiliser des embouts de plus grand diamètre et des manchons d'irrigation coaxiaux de plus petit diamètre.
# c) Garder l'embout équidistant des parois de l'incision et utiliser des ultrasons pulsés.
# d) Remplir la chambre antérieure avec un viscoélastique cohésif et utiliser des ultrasons continus.
# Test #0:
# response
#   ```json
# {
# 	"response": "c"
# }
# ```
# La réponse correcte est la option C : Garder l'embout équidistant des parois de l'incision et utiliser des ultrasons pulsés.
#
# L'explication est que l'utilisation d'ultrasons pulsés peut aider à réduire la fuite de la solution d'irrigation à travers l'écart formé lors de la division du noyau. En gardant l'embout équidistant des parois de l'incision, on peut réduire la pression sur la paroi de l'incision et diminuer le risque de fuite. Les ultrasons pulsés peuvent également aider à briser les débris cellulaires et à prévenir la formation de caillots, ce qui peut contribuer à réduire la survenue de complications.
#
# Les autres options ne sont pas efficaces pour prévenir la survenue de la complication décrite :
#
# * Option A : Réduire le débit d'aspiration et rendre l'incision plus étroite ne peut pas réduire la fuite de la solution d'irrigation, car cela peut augmenter la pression sur la paroi de l'incision et rendre la situation plus critique.
# * Option B : Utiliser des embouts de plus grand diamètre et des manchons d'irrigation coaxiaux de plus petit diamètre ne peut pas non plus réduire la fuite de la solution d'irrigation, car cela peut augmenter la pression sur la paroi de l'incision et rendre la situation plus critique.
# * Option D : Remplir la chambre antérieure avec un viscoélastique cohésif et utiliser des ultrasons continus peut aider à réduire la fuite de la solution d'irrigation, mais cela peut également augmenter la pression sur la paroi de l'incision et rendre la situation plus critique.
# {'response': 'c'}
# **************************************************

# %% [markdown]
# #### See the results

# %%
import os
MODEL = os.path.basename(MODEL)

if N_REPETITIONS > 1:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}_{N_REPETITIONS}Repetitions.csv")
else:
    df = pd.read_csv(f"responses/{MODEL}_Temperature{str(TEMPERATURE).replace('.', '_')}.csv")

df
# Out:
#       ID  year        test                theme subtheme  \
# 0      1  2022   Teórica I             Anatomia   cornea
# 1      2  2022   Teórica I             Anatomia   retina
# 2      3  2022   Teórica I             Anatomia   cornea
# 3      4  2022   Teórica I             Anatomia   cornea
# 4      5  2022   Teórica I             Anatomia   cornea
# ..   ...   ...         ...                  ...      ...
# 159  161  2022  Teórica II  Cristalino/Catarata      NaN
# 160  162  2022  Teórica II  Cristalino/Catarata      NaN
# 161  163  2022  Teórica II  Cristalino/Catarata      NaN
# 162  164  2022  Teórica II  Cristalino/Catarata      NaN
# 163  165  2022  Teórica II  Cristalino/Catarata      NaN
#
#                                             portuguese  \
# 0    Em qual região ocular células caliciformes são...
# 1    Assinale a alternativa que melhor correlaciona...
# 2    Ordene as três denominações celulares encontra...
# 3    Sobre a membrana de Descemet da córnea, é corr...
# 4    Sobre a camada lipídica do filme lacrimal, ass...
# ..                                                 ...
# 159  Após bloqueio retrobulbar para realização de c...
# 160  Sobre a biometria em olhos tamponados por óleo...
# 161  Assinale a alternativa que contém, respectivam...
# 162  Sobre a prevenção de endoftalmite em cirurgia ...
# 163  Após realizar as fraturas do núcleo com a técn...
#
#                                                spanish  \
# 0    ¿En qué región ocular se encuentran fisiológic...
# 1    Marque la alternativa que mejor correlaciona l...
# 2    Ordene los tres nombres de células que se encu...
# 3    Con respecto a la membrana de la córnea de Des...
# 4    Respecto a la capa lipídica de la película lag...
# ..                                                 ...
# 159  Tras el bloqueo retrobulbar para realizar la c...
# 160  Respecto a la biometría en ojos tamponados con...
# 161  Seleccionar la alternativa que contenga, respe...
# 162  En cuanto a la prevención de endoftalmitis en ...
# 163  Después de realizar las fracturas del núcleo c...
#
#                                                english  \
# 0    In which ocular region are caliciform cells ph...
# 1    Mark the alternative that best correlates the ...
# 2    Order the three cell names found in the cornea...
# 3    Regarding Descemet's membrane of the cornea, i...
# 4    About the lipidic layer of the lacrimal film, ...
# ..                                                 ...
# 159  After retrobulbar block for phacoemulsificatio...
# 160  Regarding biometrics in eyes covered with sili...
# 161  Check the alternative that contains, respectiv...
# 162  Regarding the prevention of endophthalmitis in...
# 163  After performing the core fractures with the d...
#
#                                                tagalog answer  \
# 0    Aling bahagi ng mata ay kung saan matatagpuan ...      D
# 1    Ipagpares ang bahagi ng retina sa Hanay B sa t...      B
# 2    Ipagsunud-sunod ang mga cells ng corneal epith...      A
# 3    Tama tungkol sa Descemet's membrane ng cornea:...      C
# 4    Piliin ang tamang sagot tungkol sa lipid layer...      B
# ..                                                 ...    ...
# 159  Matapos ang retrobulbar block para sa phacoemu...      C
# 160  Alin sa mga sumusunod na pahayag patungkol sa ...      D
# 161  Alin sa mga sumusunod na tambalan patungkol sa...      A
# 162  Alin sa mga sumusunod na pamamaraan upang mapi...      B
# 163  Matapos isagawa ang core fractures gamit ang d...      C
#
#                                                chinese  \
# 0    在哪个眼部区域生理上可以找到杯状细胞？\na) 角膜。\nb) 角膜巩膜缘。\nc) 灰线。...
# 1    将以下选项与相应的眼部组织的组织学特征进行匹配：\n\nI. 由连接复合体紧密连接在一起的单...
# 2    将角膜上皮中发现的三种细胞名称按顺序排列，从最表层的开始，然后是中间层，最后是深层。\na)...
# 3    关于角膜的Descemet膜，以下说法正确的是：\na) 内皮细胞不参与其形成。\nb) 成...
# 4    关于泪膜的脂质层，请选择正确的答案。\na) 其目的是稳定由睑板腺和Manz腺分泌的泪膜。\...
# ..                                                 ...
# 159  在白内障超声乳化手术中进行眼眶后阻滞后，患者在麻醉注射后五分钟内出现意识逐渐丧失、癫痫发作和...
# 160  关于用硅油覆盖的眼睛的生物测量学，可以正确地说：\na) 通过超声测量的轴向长度与实际值相比...
# 161  检查包含围手术期发生松弛性虹膜综合症的药物以及在这些情况下恢复散瞳的适当干预措施的选项。\n...
# 162  关于白内障手术中预防眼内炎的措施，请选择正确的选项。\na) 如果对碘伏有禁忌症，应在手术前...
# 163  在使用分离征服技术进行核心断裂后，可以看到角膜切口侧部有白色部分和组织收缩，并且灌注液通过形...
#
#                                               japanese  \
# 0    カリシフォルム細胞は生理的にどの眼部に存在しますか？\na) 角膜。\nb) 角膜強膜辺縁。...
# 1    以下の選択肢の中から、組織学的特徴とそれに対応する眼の組織を最もよく関連付けるものを選びなさ...
# 2    角膜上皮に見られる3つの細胞名を、最も表面的なものから始めて、中間のもの、深いものの順に並べ...
# 3    角膜のデスメ膜について、以下の記述が正しいと言えます：\na) 内皮細胞はその形成に関与して...
# 4    涙膜の脂質層について、正しい答えを選んでください。\na) その目的は、マイボーム腺とマンツ...
# ..                                                 ...
# 159  白内障乳化手術のための後眼窩ブロック後、患者は麻酔注射後5分で意識の進行性喪失、発作、呼吸停...
# 160  シリコンオイルで覆われた目の生体計測に関して、以下の記述が正しいと言えます：\na) 超音波...
# 161  選択肢の中で、術中に弛緩性虹彩症候群の発生に関連する薬剤と、これらの場合に散瞳を回復する適切...
# 162  白内障手術における眼内炎の予防について、正しい選択肢をマークしてください。\na) ポビドン...
# 163  コアフラクチャーを分割統治法で行った後、角膜切開の側部に白っぽい部分と組織の収縮が見られ、形...
#
#                                                 korean  \
# 0    어느 눈 부위에서 goblet 세포가 생리적으로 발견됩니까?\na) 각막.\nb) ...
# 1    조직학적 특성과 해당 안구 조직을 가장 잘 연관시키는 선택지를 표시하시오:\n\nI...
# 2    각막 상피에서 발견되는 세 가지 세포 이름을 가장 표면적인 것부터 시작하여 중간, ...
# 3    각막의 데스메막에 관하여 다음과 같이 말할 수 있습니다:\na) 내피세포는 그 형성...
# 4    눈물막의 지질층에 대해 올바른 답을 선택하십시오.\na) 그 목적은 마이봄샘과 만즈...
# ..                                                 ...
# 159  백내장 초음파 파쇄술을 위한 후안구 봉쇄 후, 환자는 마취 주사 후 5분 만에 의식...
# 160  실리콘 오일로 덮인 눈의 생체 인식에 관하여 다음과 같이 말할 수 있습니다:\na)...
# 161  수술 기간 동안 편평 홍채 증후군의 발생과 관련된 약물과 이러한 경우 동공 확대를 ...
# 162  백내장 수술에서 안내염 예방과 관련하여 올바른 대안을 표시하십시오.\na) 포비돈 ...
# 163  분할 정복 기법으로 핵 파절을 수행한 후, 각막 절개의 측면 부분에서 하얀 부분과 ...
#
#                                                 french  \
# 0    Dans quelle région oculaire trouve-t-on physio...
# 1    Marquez l'alternative qui corrèle le mieux les...
# 2    Classez les trois noms de cellules trouvés dan...
# 3    Concernant la membrane de Descemet de la corné...
# 4    À propos de la couche lipidique du film lacrym...
# ..                                                 ...
# 159  Après un bloc rétrobulbaire pour une chirurgie...
# 160  Concernant les biométries des yeux couverts d'...
# 161  Vérifiez l'alternative qui contient, respectiv...
# 162  Concernant la prévention de l'endophtalmie lor...
# 163  Après avoir effectué les fractures du noyau av...
#
#                                                  hindi        responses_hindi  \
# 0    Caliciform koṣikāeṁ kis netra kṣetra meṁ kriyā...                      b
# 1    Nimnlikhit path ka romanized hindi mein anuvaa...                      b
# 2    Corneal epithelium mein paayi jaane waali teen...  c) Basal, flat, wing.
# 3    Descemet's membrane ke sambandh mein, yah kehn...                      b
# 4    Lacrimal film ke lipidic layer ke baare mein, ...                      b
# ..                                                 ...                    ...
# 159  Retrobulbar block ke baad phacoemulsification ...                      a
# 160  Biometrics mein aankhon mein silicone oil ke s...                      c
# 161  Nimnlikhit mein se us vikalp ko chunein jo, kr...                      a
# 162  Cataract surgery mein endophthalmitis ke preve...                      b
# 163  Core fractures ko divide-and-conquer technique...                      c
#
#          responses_hindi_0            responses_french  \
# 0                        b                           b
# 1                        b                           b
# 2    c) Basal, flat, wing.  c) Basales, plates, ailes.
# 3                        b                           b
# 4                        b                           b
# ..                     ...                         ...
# 159                      a                           b
# 160                      c                           a
# 161                      a                           b
# 162                      b                           b
# 163                      c                           c
#
#              responses_french_0
# 0                             b
# 1                             b
# 2    c) Basales, plates, ailes.
# 3                             b
# 4                             b
# ..                          ...
# 159                           b
# 160                           a
# 161                           b
# 162                           b
# 163                           c
#
# [164 rows x 19 columns]

# %% [markdown]
# ### Data Analysis

# %%
TEMPERATURE = str(TEMPERATURE).replace('.', '_')

run_analysis(model=MODEL, temperature=TEMPERATURE, n_repetitions=N_REPETITIONS, languages=LANGUAGES)
# Out:
# n_repetitions should be a positive integer, not 0
# n_repetitions will be set to 1
# /Users/davidrestrepo/LLMs Bias/Language/src/data_analysis.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(languages, fontsize=16)
#      theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  anatomy            4             5     21               19.047619
#
#    french_ratio_percentage
# 0                23.809524
#     theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  cornea            2             4     10                    20.0
#
#    french_ratio_percentage
# 0                     40.0
#         theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  embryology            0             1      2                     0.0
#
#    french_ratio_percentage
# 0                     50.0
#       theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  genetics            0             0      2                     0.0
#
#    french_ratio_percentage
# 0                      0.0
#       theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  glaucoma            2             3      9               22.222222
#
#    french_ratio_percentage
# 0                33.333333
#       theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  oncology            0             0      1                     0.0
#
#    french_ratio_percentage
# 0                      0.0
#           theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  pharmacology            4             4      9               44.444444
#
#    french_ratio_percentage
# 0                44.444444
#         theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  refraction           10            12     31               32.258065
#
#    french_ratio_percentage
# 0                38.709677
#     theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  retina            2             5     12               16.666667
#
#    french_ratio_percentage
# 0                41.666667
#             theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  contact lenses            1             0      3               33.333333
#
#    french_ratio_percentage
# 0                      0.0
#     theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  cornea            2             4     10                    20.0
#
#    french_ratio_percentage
# 0                     40.0
#          theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  cornea/lens            1             1      1                   100.0
#
#    french_ratio_percentage
# 0                    100.0
#       theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  glaucoma            2             3      9               22.222222
#
#    french_ratio_percentage
# 0                33.333333
#               theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  glaucoma/uveitis            0             0      1                     0.0
#
#    french_ratio_percentage
# 0                      0.0
#            theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  lens/cataract            5             4      8                    62.5
#
#    french_ratio_percentage
# 0                     50.0
#         theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  low vision            1             1      1                   100.0
#
#    french_ratio_percentage
# 0                    100.0
#                  theme  match_hindi  match_french  Total  \
# 0  neuro-ophthalmology            3             3      7
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0               42.857143                42.857143
#                     theme  match_hindi  match_french  Total  \
# 0  ocular plastic surgery            6             3     16
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                    37.5                    18.75
#                              theme  match_hindi  match_french  Total  \
# 0  oncology/ocular plastic surgery            0             0      3
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                     0.0                      0.0
#     theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  optics            0             0      1                     0.0
#
#    french_ratio_percentage
# 0                      0.0
#                theme  match_hindi  match_french  Total  \
# 0  optics/refraction            0             0      1
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                     0.0                      0.0
#           theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  pharmacology            4             4      9               44.444444
#
#    french_ratio_percentage
# 0                44.444444
#                    theme  match_hindi  match_french  Total  \
# 0  pharmacology/glaucoma            0             0      1
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                     0.0                      0.0
#         theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  refraction           10            12     31               32.258065
#
#    french_ratio_percentage
# 0                38.709677
#                    theme  match_hindi  match_french  Total  \
# 0  refraction/low vision            0             0      2
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                     0.0                      0.0
#                 theme  match_hindi  match_french  Total  \
# 0  refractive surgery            2             1      2
#
#    hindi_ratio_percentage  french_ratio_percentage
# 0                   100.0                     50.0
#     theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  retina            2             5     12               16.666667
#
#    french_ratio_percentage
# 0                41.666667
#              theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  retina/oncology            0             0      1                     0.0
#
#    french_ratio_percentage
# 0                      0.0
#         theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  strabismus            3             6     11               27.272727
#
#    french_ratio_percentage
# 0                54.545455
#      theme  match_hindi  match_french  Total  hindi_ratio_percentage  \
# 0  uveitis            2             2      8                    25.0
#
#    french_ratio_percentage
# 0                     25.0

# %%
N_REPETITIONS = 1 if N_REPETITIONS < 1 else N_REPETITIONS
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv')
# Out:
#           test  year                            theme  match_hindi  \
# 0    Teórica I  2022                          anatomy            4
# 1    Teórica I  2022                           cornea            0
# 2    Teórica I  2022                       embryology            0
# 3    Teórica I  2022                         genetics            0
# 4    Teórica I  2022                         glaucoma            0
# 5    Teórica I  2022                         oncology            0
# 6    Teórica I  2022                     pharmacology            1
# 7    Teórica I  2022                       refraction            5
# 8    Teórica I  2022                           retina            0
# 9   Teórica II  2022                   contact lenses            1
# 10  Teórica II  2022                           cornea            2
# 11  Teórica II  2022                      cornea/lens            1
# 12  Teórica II  2022                         glaucoma            2
# 13  Teórica II  2022                 glaucoma/uveitis            0
# 14  Teórica II  2022                    lens/cataract            5
# 15  Teórica II  2022                       low vision            1
# 16  Teórica II  2022              neuro-ophthalmology            3
# 17  Teórica II  2022           ocular plastic surgery            6
# 18  Teórica II  2022  oncology/ocular plastic surgery            0
# 19  Teórica II  2022                           optics            0
# 20  Teórica II  2022                optics/refraction            0
# 21  Teórica II  2022                     pharmacology            3
# 22  Teórica II  2022            pharmacology/glaucoma            0
# 23  Teórica II  2022                       refraction            5
# 24  Teórica II  2022            refraction/low vision            0
# 25  Teórica II  2022               refractive surgery            2
# 26  Teórica II  2022                           retina            2
# 27  Teórica II  2022                  retina/oncology            0
# 28  Teórica II  2022                       strabismus            3
# 29  Teórica II  2022                          uveitis            2
#
#     match_french  Total
# 0              5     21
# 1              1      1
# 2              1      2
# 3              0      2
# 4              0      1
# 5              0      1
# 6              2      3
# 7              6     12
# 8              0      1
# 9              0      3
# 10             3      9
# 11             1      1
# 12             3      8
# 13             0      1
# 14             4      8
# 15             1      1
# 16             3      7
# 17             3     16
# 18             0      3
# 19             0      1
# 20             0      1
# 21             2      6
# 22             0      1
# 23             6     19
# 24             0      2
# 25             1      2
# 26             5     11
# 27             0      1
# 28             6     11
# 29             2      8

# %%
pd.read_csv(f'results/results_{MODEL}_Temperature{TEMPERATURE}_Repetitions{N_REPETITIONS}/matches_results_{MODEL}.csv').sum()
# Out:
# test            Teórica ITeórica ITeórica ITeórica ITeórica IT...
# year                                                        60660
# theme           anatomycorneaembryologygeneticsglaucomaoncolog...
# match_hindi                                                    48
# match_french                                                   55
# Total                                                         164
# dtype: object
